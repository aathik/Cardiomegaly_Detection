# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os 
from glob import glob 
import matplotlib.pyplot as plt
import keras
from skimage.util import montage as montage2d
from skimage.io import imread
import seaborn as sns
from keras.optimizers import Adam
import tensorflow as tf
from keras import Input
from keras.models import Model
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.applications import ResNet152V2, InceptionV3, EfficientNetB0, MobileNetV3Small
from keras.layers import Dense, Flatten, Activation, Conv2D, MaxPooling2D, Dropout, Conv2D,MaxPooling2D,GlobalAveragePooling2D,AvgPool2D,multiply, LocallyConnected2D, Lambda, AvgPool2D


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
        

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
base_dir = os.path.join('..', 'input', 'pulmonary-chest-xray-abnormalities')
all_xray_images_dataframe = pd.read_csv('../input/data/Data_Entry_2017.csv')
all_xray_images_dataframe.sample(5)
# Out:
#              Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 37715   00009925_013.png       Effusion           13        9925           55
# 111692  00030602_000.png     No Finding            0       30602           29
# 48790   00012364_057.png     No Finding           57       12364           53
# 26458   00006948_011.png  Effusion|Mass           11        6948           50
# 68012   00016796_008.png    Atelectasis            8       16796           64
#
#        Patient Gender View Position  OriginalImage[Width  Height]  \
# 37715               M            PA                 2992     2991
# 111692              M            PA                 3056     2544
# 48790               F            AP                 2500     2048
# 26458               F            PA                 2500     2048
# 68012               F            PA                 2358     2232
#
#         OriginalImagePixelSpacing[x     y]  Unnamed: 11
# 37715                         0.143  0.143          NaN
# 111692                        0.139  0.139          NaN
# 48790                         0.168  0.168          NaN
# 26458                         0.171  0.171          NaN
# 68012                         0.143  0.143          NaN

# %%
all_xray_images_dataframe['Finding Labels']
# Out:
# 0                   Cardiomegaly
# 1         Cardiomegaly|Emphysema
# 2          Cardiomegaly|Effusion
# 3                     No Finding
# 4                         Hernia
#                    ...
# 112115            Mass|Pneumonia
# 112116                No Finding
# 112117                No Finding
# 112118                No Finding
# 112119                No Finding
# Name: Finding Labels, Length: 112120, dtype: object

# %% [markdown]
# # Preprocessing
# Organize the files by cases with and without cardiomegaly

# %%
all_xray_images_dataframe = pd.read_csv('../input/data/Data_Entry_2017.csv')
all_images_paths = {os.path.basename(x): x for x in 
                   glob(os.path.join('..', 'input', 'data',  'images*', '*', '*.png'))}
print('Scans found:', len(all_images_paths), ', Total Headers', all_xray_images_dataframe.shape[0])
all_xray_images_dataframe['path'] = all_xray_images_dataframe['Image Index'].map(all_images_paths.get)
all_xray_images_dataframe['Cardiomegaly'] = all_xray_images_dataframe['Finding Labels'].map(lambda x: 'Cardiomegaly' in x)
all_xray_images_dataframe['Patient Age'] = np.clip(all_xray_images_dataframe['Patient Age'], 5, 100)
all_xray_images_dataframe['Patient Male'] = all_xray_images_dataframe['Patient Gender'].map(lambda x: x.upper()=='M').astype('float32')
all_xray_images_dataframe.sample(3)
# Out:
# Scans found: 112120 , Total Headers 112120
#              Image Index      Finding Labels  Follow-up #  Patient ID  \
# 109175  00029670_006.png  Edema|Infiltration            6       29670
# 75992   00018640_001.png                Mass            1       18640
# 19608   00005210_000.png          No Finding            0        5210
#
#         Patient Age Patient Gender View Position  OriginalImage[Width  \
# 109175           76              F            AP                 3056
# 75992            46              M            PA                 2992
# 19608            70              M            AP                 2500
#
#         Height]  OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 109175     2544                        0.139  0.139          NaN
# 75992      2991                        0.143  0.143          NaN
# 19608      2048                        0.171  0.171          NaN
#
#                                                     path  Cardiomegaly  \
# 109175  ../input/data/images_012/images/00029670_006.png         False
# 75992   ../input/data/images_009/images/00018640_001.png         False
# 19608   ../input/data/images_003/images/00005210_000.png         False
#
#         Patient Male
# 109175           0.0
# 75992            1.0
# 19608            1.0

# %% [markdown]
# # Examine the distributions
# Show how the data is distributed and why we need to balance it

# %%
sns.pairplot(all_xray_images_dataframe[['Patient Age', 'Patient Male', 'Cardiomegaly']], hue='Cardiomegaly')

# %% [markdown]
# # Split Data into Training and Validation

# %%
positive_cases = np.sum(all_xray_images_dataframe['Cardiomegaly']==True)//2
oversample_factor = 4 # maximum number of cases in negative group so it isn't super rare
more_balanced_df = all_xray_images_dataframe.groupby(['Patient Gender', 'Cardiomegaly']).apply(lambda x: x.sample(min(oversample_factor*positive_cases, x.shape[0]), 
                                                                                   replace = False)
                                                      ).reset_index(drop = True)

print(more_balanced_df['Cardiomegaly'].value_counts())
sns.pairplot(more_balanced_df[['Patient Age', 'Cardiomegaly']], hue='Cardiomegaly')
# Out:
# False    11104
# True      2776
# Name: Cardiomegaly, dtype: int64

# %%
more_balanced_df
# Out:
#             Image Index                            Finding Labels  \
# 0      00007044_003.png                                No Finding
# 1      00012642_000.png                                No Finding
# 2      00008522_015.png    Atelectasis|Consolidation|Infiltration
# 3      00023590_000.png                                No Finding
# 4      00001836_069.png                     Fibrosis|Infiltration
# ...                 ...                                       ...
# 13875  00028963_003.png                         Cardiomegaly|Mass
# 13876  00017753_013.png  Cardiomegaly|Effusion|Pleural_Thickening
# 13877  00016291_043.png                Cardiomegaly|Consolidation
# 13878  00029108_000.png                              Cardiomegaly
# 13879  00004533_008.png                Cardiomegaly|Consolidation
#
#        Follow-up #  Patient ID  Patient Age Patient Gender View Position  \
# 0                3        7044           50              F            PA
# 1                0       12642           37              F            PA
# 2               15        8522           61              F            AP
# 3                0       23590           35              F            PA
# 4               69        1836           50              F            AP
# ...            ...         ...          ...            ...           ...
# 13875            3       28963           32              M            PA
# 13876           13       17753           62              M            PA
# 13877           43       16291           54              M            AP
# 13878            0       29108           33              M            PA
# 13879            8        4533           30              M            AP
#
#        OriginalImage[Width  Height]  OriginalImagePixelSpacing[x        y]  \
# 0                     2048     2500                     0.168000  0.168000
# 1                     2674     2673                     0.143000  0.143000
# 2                     2500     2048                     0.168000  0.168000
# 3                     2048     2500                     0.168000  0.168000
# 4                     2500     2048                     0.168000  0.168000
# ...                    ...      ...                          ...       ...
# 13875                 2021     2021                     0.194311  0.194311
# 13876                 2710     2991                     0.143000  0.143000
# 13877                 2500     2048                     0.168000  0.168000
# 13878                 2021     2021                     0.194311  0.194311
# 13879                 2500     2048                     0.168000  0.168000
#
#        Unnamed: 11                                              path  \
# 0              NaN  ../input/data/images_004/images/00007044_003.png
# 1              NaN  ../input/data/images_006/images/00012642_000.png
# 2              NaN  ../input/data/images_004/images/00008522_015.png
# 3              NaN  ../input/data/images_010/images/00023590_000.png
# 4              NaN  ../input/data/images_002/images/00001836_069.png
# ...            ...                                               ...
# 13875          NaN  ../input/data/images_012/images/00028963_003.png
# 13876          NaN  ../input/data/images_008/images/00017753_013.png
# 13877          NaN  ../input/data/images_008/images/00016291_043.png
# 13878          NaN  ../input/data/images_012/images/00029108_000.png
# 13879          NaN  ../input/data/images_003/images/00004533_008.png
#
#        Cardiomegaly  Patient Male
# 0             False           0.0
# 1             False           0.0
# 2             False           0.0
# 3             False           0.0
# 4             False           0.0
# ...             ...           ...
# 13875          True           1.0
# 13876          True           1.0
# 13877          True           1.0
# 13878          True           1.0
# 13879          True           1.0
#
# [13880 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split
raw_train_df, test_valid_df = train_test_split(more_balanced_df, 
                                   test_size = 0.20, 
                                   random_state = 2018,
                                   stratify = more_balanced_df[['Cardiomegaly', 'Patient Gender']])
valid_df, test_df = train_test_split(test_valid_df, 
                                   test_size = 0.40, 
                                   random_state = 2018,
                                   stratify = test_valid_df[['Cardiomegaly', 'Patient Gender']])
print('train', raw_train_df.shape[0], 'validation', valid_df.shape[0], 'test', test_df.shape[0])
print('train', raw_train_df['Cardiomegaly'].value_counts())
print('test', test_df['Cardiomegaly'].value_counts())
raw_train_df.sample(1)
# Out:
# train 11104 validation 1665 test 1111
# train False    8884
# True     2220
# Name: Cardiomegaly, dtype: int64
# test False    888
# True     223
# Name: Cardiomegaly, dtype: int64
#            Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 4364  00023160_001.png           Mass            1       23160           43
#
#      Patient Gender View Position  OriginalImage[Width  Height]  \
# 4364              F            AP                 3056     2544
#
#       OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 4364                        0.139  0.139          NaN
#
#                                                   path  Cardiomegaly  \
# 4364  ../input/data/images_010/images/00023160_001.png         False
#
#       Patient Male
# 4364           0.0

# %%
from sklearn.model_selection import train_test_split
raw_train_df, test_valid_df = train_test_split(more_balanced_df, 
                                   test_size = 0.20, 
                                   random_state = 2018,
                                   stratify = more_balanced_df[['Cardiomegaly', 'Patient Gender']])
valid_df, test_df = train_test_split(test_valid_df, 
                                   test_size = 0.50, 
                                   random_state = 2018,
                                   stratify = test_valid_df[['Cardiomegaly', 'Patient Gender']])
print('train', raw_train_df.shape[0], 'validation', valid_df.shape[0], 'test', test_df.shape[0])
print('train', raw_train_df['Cardiomegaly'].value_counts())
print('test', test_df['Cardiomegaly'].value_counts())
raw_train_df.sample(1)
# Out:
# train 11104 validation 1388 test 1388
# train False    8884
# True     2220
# Name: Cardiomegaly, dtype: int64
# test False    1110
# True      278
# Name: Cardiomegaly, dtype: int64
#            Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 1835  00026768_001.png           Mass            1       26768           58
#
#      Patient Gender View Position  OriginalImage[Width  Height]  \
# 1835              F            PA                 2986     2869
#
#       OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 1835                        0.143  0.143          NaN
#
#                                                   path  Cardiomegaly  \
# 1835  ../input/data/images_011/images/00026768_001.png         False
#
#       Patient Male
# 1835           0.0

# %% [markdown]
# # Balance the distribution in the training set

# %%
train_df = raw_train_df.groupby(['Cardiomegaly']).apply(lambda x: x.sample(2220, replace = True)
                                                      ).reset_index(drop = True)
print('New Data Size:', train_df.shape[0], 'Old Size:', raw_train_df.shape[0])
# Out:
# New Data Size: 4440 Old Size: 11104

# %%
print('train', train_df['Cardiomegaly'].value_counts())
# Out:
# train False    2220
# True     2220
# Name: Cardiomegaly, dtype: int64

# %%
from keras.preprocessing.image import ImageDataGenerator
##from keras.applications.resnet_v2 import ResNet50 as PreTrainedModel, preprocess_input
#from keras.applications.resnet_v2 import ResNet152V2, preprocess_input
from keras.applications.efficientnet import EfficientNetB4 as PreTrainedModel, preprocess_input
IMG_SIZE = (224, 224) # size that EfficientNetB7 expects
image_data_generator = ImageDataGenerator(samplewise_center=False, 
                              samplewise_std_normalization=False, 
                              horizontal_flip=False, 
                              vertical_flip=False, 
                              height_shift_range=0.1, 
                              width_shift_range=0.1, 
                              brightness_range=[0.7, 1.5],
                              rotation_range=3, 
                              shear_range=0.01,
                              fill_mode='nearest',
                              zoom_range=0.125,
                             preprocessing_function=preprocess_input)

# %%
def flow_from_dataframe(img_data_gen, in_df, path_col, y_col, **dflow_args):
    df_gen = img_data_gen.flow_from_dataframe(in_df,
                                              x_col=path_col,
                                              y_col=y_col,
                                     class_mode = 'raw',
                                    **dflow_args)
    return df_gen

# %%
train_gen = flow_from_dataframe(image_data_generator, train_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 16)

valid_gen = flow_from_dataframe(image_data_generator, valid_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 256) 
test_X, test_Y = next(flow_from_dataframe(image_data_generator, 
                               valid_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 1388)) # one big batch
# used a fixed dataset for final evaluation
final_test_X, final_test_Y = next(flow_from_dataframe(image_data_generator, 
                               test_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 1388)) # one big batch
# Out:
# Found 4440 validated image filenames.
# Found 1388 validated image filenames.
# Found 1388 validated image filenames.
# Found 1388 validated image filenames.

# %%
t_x, t_y = next(train_gen)
t_y
# Out:
# array([False,  True,  True,  True, False,  True, False,  True,  True,
#         True, False,  True, False, False, False,  True])

# %%
t_x, t_y = next(train_gen)
print(t_x.shape)
print(t_y)
fig, m_axs = plt.subplots(4, 4, figsize = (16, 8))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone', vmin = -127, vmax = 127)
    c_ax.set_title('%s' % ('Cardiomegaly' if c_y else 'Healthy'))
    c_ax.axis('off')
# Out:
# (16, 224, 224, 3)
# [False  True  True  True  True  True False False  True False False  True
#   True False False  True]

# %%
base_pretrained_model = PreTrainedModel(input_shape =  t_x.shape[1:], 
                              include_top = False, weights = 'imagenet')
base_pretrained_model.trainable = False

# %%
base_pretrained_model.summary()
# Out:
# Model: "efficientnetb4"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling_4 (Rescaling)        (None, 224, 224, 3)  0           ['input_5[0][0]']
#
#  normalization_2 (Normalization  (None, 224, 224, 3)  7          ['rescaling_4[0][0]']
#  )
#
#  rescaling_5 (Rescaling)        (None, 224, 224, 3)  0           ['normalization_2[0][0]']
#
#  stem_conv_pad (ZeroPadding2D)  (None, 225, 225, 3)  0           ['rescaling_5[0][0]']
#
#  stem_conv (Conv2D)             (None, 112, 112, 48  1296        ['stem_conv_pad[0][0]']
#                                 )
#
#  stem_bn (BatchNormalization)   (None, 112, 112, 48  192         ['stem_conv[0][0]']
#                                 )
#
#  stem_activation (Activation)   (None, 112, 112, 48  0           ['stem_bn[0][0]']
#                                 )
#
#  block1a_dwconv (DepthwiseConv2  (None, 112, 112, 48  432        ['stem_activation[0][0]']
#  D)                             )
#
#  block1a_bn (BatchNormalization  (None, 112, 112, 48  192        ['block1a_dwconv[0][0]']
#  )                              )
#
#  block1a_activation (Activation  (None, 112, 112, 48  0          ['block1a_bn[0][0]']
#  )                              )
#
#  block1a_se_squeeze (GlobalAver  (None, 48)          0           ['block1a_activation[0][0]']
#  agePooling2D)
#
#  block1a_se_reshape (Reshape)   (None, 1, 1, 48)     0           ['block1a_se_squeeze[0][0]']
#
#  block1a_se_reduce (Conv2D)     (None, 1, 1, 12)     588         ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)     (None, 1, 1, 48)     624         ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multiply)   (None, 112, 112, 48  0           ['block1a_activation[0][0]',
#                                 )                                 'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv2D)  (None, 112, 112, 24  1152        ['block1a_se_excite[0][0]']
#                                 )
#
#  block1a_project_bn (BatchNorma  (None, 112, 112, 24  96         ['block1a_project_conv[0][0]']
#  lization)                      )
#
#  block1b_dwconv (DepthwiseConv2  (None, 112, 112, 24  216        ['block1a_project_bn[0][0]']
#  D)                             )
#
#  block1b_bn (BatchNormalization  (None, 112, 112, 24  96         ['block1b_dwconv[0][0]']
#  )                              )
#
#  block1b_activation (Activation  (None, 112, 112, 24  0          ['block1b_bn[0][0]']
#  )                              )
#
#  block1b_se_squeeze (GlobalAver  (None, 24)          0           ['block1b_activation[0][0]']
#  agePooling2D)
#
#  block1b_se_reshape (Reshape)   (None, 1, 1, 24)     0           ['block1b_se_squeeze[0][0]']
#
#  block1b_se_reduce (Conv2D)     (None, 1, 1, 6)      150         ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)     (None, 1, 1, 24)     168         ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multiply)   (None, 112, 112, 24  0           ['block1b_activation[0][0]',
#                                 )                                 'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv2D)  (None, 112, 112, 24  576         ['block1b_se_excite[0][0]']
#                                 )
#
#  block1b_project_bn (BatchNorma  (None, 112, 112, 24  96         ['block1b_project_conv[0][0]']
#  lization)                      )
#
#  block1b_drop (Dropout)         (None, 112, 112, 24  0           ['block1b_project_bn[0][0]']
#                                 )
#
#  block1b_add (Add)              (None, 112, 112, 24  0           ['block1b_drop[0][0]',
#                                 )                                 'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2D)   (None, 112, 112, 14  3456        ['block1b_add[0][0]']
#                                 4)
#
#  block2a_expand_bn (BatchNormal  (None, 112, 112, 14  576        ['block2a_expand_conv[0][0]']
#  ization)                       4)
#
#  block2a_expand_activation (Act  (None, 112, 112, 14  0          ['block2a_expand_bn[0][0]']
#  ivation)                       4)
#
#  block2a_dwconv_pad (ZeroPaddin  (None, 113, 113, 14  0          ['block2a_expand_activation[0][0]
#  g2D)                           4)                               ']
#
#  block2a_dwconv (DepthwiseConv2  (None, 56, 56, 144)  1296       ['block2a_dwconv_pad[0][0]']
#  D)
#
#  block2a_bn (BatchNormalization  (None, 56, 56, 144)  576        ['block2a_dwconv[0][0]']
#  )
#
#  block2a_activation (Activation  (None, 56, 56, 144)  0          ['block2a_bn[0][0]']
#  )
#
#  block2a_se_squeeze (GlobalAver  (None, 144)         0           ['block2a_activation[0][0]']
#  agePooling2D)
#
#  block2a_se_reshape (Reshape)   (None, 1, 1, 144)    0           ['block2a_se_squeeze[0][0]']
#
#  block2a_se_reduce (Conv2D)     (None, 1, 1, 6)      870         ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)     (None, 1, 1, 144)    1008        ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multiply)   (None, 56, 56, 144)  0           ['block2a_activation[0][0]',
#                                                                   'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv2D)  (None, 56, 56, 32)   4608        ['block2a_se_excite[0][0]']
#
#  block2a_project_bn (BatchNorma  (None, 56, 56, 32)  128         ['block2a_project_conv[0][0]']
#  lization)
#
#  block2b_expand_conv (Conv2D)   (None, 56, 56, 192)  6144        ['block2a_project_bn[0][0]']
#
#  block2b_expand_bn (BatchNormal  (None, 56, 56, 192)  768        ['block2b_expand_conv[0][0]']
#  ization)
#
#  block2b_expand_activation (Act  (None, 56, 56, 192)  0          ['block2b_expand_bn[0][0]']
#  ivation)
#
#  block2b_dwconv (DepthwiseConv2  (None, 56, 56, 192)  1728       ['block2b_expand_activation[0][0]
#  D)                                                              ']
#
#  block2b_bn (BatchNormalization  (None, 56, 56, 192)  768        ['block2b_dwconv[0][0]']
#  )
#
#  block2b_activation (Activation  (None, 56, 56, 192)  0          ['block2b_bn[0][0]']
#  )
#
#  block2b_se_squeeze (GlobalAver  (None, 192)         0           ['block2b_activation[0][0]']
#  agePooling2D)
#
#  block2b_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2b_se_squeeze[0][0]']
#
#  block2b_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multiply)   (None, 56, 56, 192)  0           ['block2b_activation[0][0]',
#                                                                   'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv2D)  (None, 56, 56, 32)   6144        ['block2b_se_excite[0][0]']
#
#  block2b_project_bn (BatchNorma  (None, 56, 56, 32)  128         ['block2b_project_conv[0][0]']
#  lization)
#
#  block2b_drop (Dropout)         (None, 56, 56, 32)   0           ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)              (None, 56, 56, 32)   0           ['block2b_drop[0][0]',
#                                                                   'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2D)   (None, 56, 56, 192)  6144        ['block2b_add[0][0]']
#
#  block2c_expand_bn (BatchNormal  (None, 56, 56, 192)  768        ['block2c_expand_conv[0][0]']
#  ization)
#
#  block2c_expand_activation (Act  (None, 56, 56, 192)  0          ['block2c_expand_bn[0][0]']
#  ivation)
#
#  block2c_dwconv (DepthwiseConv2  (None, 56, 56, 192)  1728       ['block2c_expand_activation[0][0]
#  D)                                                              ']
#
#  block2c_bn (BatchNormalization  (None, 56, 56, 192)  768        ['block2c_dwconv[0][0]']
#  )
#
#  block2c_activation (Activation  (None, 56, 56, 192)  0          ['block2c_bn[0][0]']
#  )
#
#  block2c_se_squeeze (GlobalAver  (None, 192)         0           ['block2c_activation[0][0]']
#  agePooling2D)
#
#  block2c_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2c_se_squeeze[0][0]']
#
#  block2c_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multiply)   (None, 56, 56, 192)  0           ['block2c_activation[0][0]',
#                                                                   'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv2D)  (None, 56, 56, 32)   6144        ['block2c_se_excite[0][0]']
#
#  block2c_project_bn (BatchNorma  (None, 56, 56, 32)  128         ['block2c_project_conv[0][0]']
#  lization)
#
#  block2c_drop (Dropout)         (None, 56, 56, 32)   0           ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)              (None, 56, 56, 32)   0           ['block2c_drop[0][0]',
#                                                                   'block2b_add[0][0]']
#
#  block2d_expand_conv (Conv2D)   (None, 56, 56, 192)  6144        ['block2c_add[0][0]']
#
#  block2d_expand_bn (BatchNormal  (None, 56, 56, 192)  768        ['block2d_expand_conv[0][0]']
#  ization)
#
#  block2d_expand_activation (Act  (None, 56, 56, 192)  0          ['block2d_expand_bn[0][0]']
#  ivation)
#
#  block2d_dwconv (DepthwiseConv2  (None, 56, 56, 192)  1728       ['block2d_expand_activation[0][0]
#  D)                                                              ']
#
#  block2d_bn (BatchNormalization  (None, 56, 56, 192)  768        ['block2d_dwconv[0][0]']
#  )
#
#  block2d_activation (Activation  (None, 56, 56, 192)  0          ['block2d_bn[0][0]']
#  )
#
#  block2d_se_squeeze (GlobalAver  (None, 192)         0           ['block2d_activation[0][0]']
#  agePooling2D)
#
#  block2d_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block2d_se_squeeze[0][0]']
#
#  block2d_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block2d_se_reshape[0][0]']
#
#  block2d_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block2d_se_reduce[0][0]']
#
#  block2d_se_excite (Multiply)   (None, 56, 56, 192)  0           ['block2d_activation[0][0]',
#                                                                   'block2d_se_expand[0][0]']
#
#  block2d_project_conv (Conv2D)  (None, 56, 56, 32)   6144        ['block2d_se_excite[0][0]']
#
#  block2d_project_bn (BatchNorma  (None, 56, 56, 32)  128         ['block2d_project_conv[0][0]']
#  lization)
#
#  block2d_drop (Dropout)         (None, 56, 56, 32)   0           ['block2d_project_bn[0][0]']
#
#  block2d_add (Add)              (None, 56, 56, 32)   0           ['block2d_drop[0][0]',
#                                                                   'block2c_add[0][0]']
#
#  block3a_expand_conv (Conv2D)   (None, 56, 56, 192)  6144        ['block2d_add[0][0]']
#
#  block3a_expand_bn (BatchNormal  (None, 56, 56, 192)  768        ['block3a_expand_conv[0][0]']
#  ization)
#
#  block3a_expand_activation (Act  (None, 56, 56, 192)  0          ['block3a_expand_bn[0][0]']
#  ivation)
#
#  block3a_dwconv_pad (ZeroPaddin  (None, 59, 59, 192)  0          ['block3a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block3a_dwconv (DepthwiseConv2  (None, 28, 28, 192)  4800       ['block3a_dwconv_pad[0][0]']
#  D)
#
#  block3a_bn (BatchNormalization  (None, 28, 28, 192)  768        ['block3a_dwconv[0][0]']
#  )
#
#  block3a_activation (Activation  (None, 28, 28, 192)  0          ['block3a_bn[0][0]']
#  )
#
#  block3a_se_squeeze (GlobalAver  (None, 192)         0           ['block3a_activation[0][0]']
#  agePooling2D)
#
#  block3a_se_reshape (Reshape)   (None, 1, 1, 192)    0           ['block3a_se_squeeze[0][0]']
#
#  block3a_se_reduce (Conv2D)     (None, 1, 1, 8)      1544        ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)     (None, 1, 1, 192)    1728        ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multiply)   (None, 28, 28, 192)  0           ['block3a_activation[0][0]',
#                                                                   'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv2D)  (None, 28, 28, 56)   10752       ['block3a_se_excite[0][0]']
#
#  block3a_project_bn (BatchNorma  (None, 28, 28, 56)  224         ['block3a_project_conv[0][0]']
#  lization)
#
#  block3b_expand_conv (Conv2D)   (None, 28, 28, 336)  18816       ['block3a_project_bn[0][0]']
#
#  block3b_expand_bn (BatchNormal  (None, 28, 28, 336)  1344       ['block3b_expand_conv[0][0]']
#  ization)
#
#  block3b_expand_activation (Act  (None, 28, 28, 336)  0          ['block3b_expand_bn[0][0]']
#  ivation)
#
#  block3b_dwconv (DepthwiseConv2  (None, 28, 28, 336)  8400       ['block3b_expand_activation[0][0]
#  D)                                                              ']
#
#  block3b_bn (BatchNormalization  (None, 28, 28, 336)  1344       ['block3b_dwconv[0][0]']
#  )
#
#  block3b_activation (Activation  (None, 28, 28, 336)  0          ['block3b_bn[0][0]']
#  )
#
#  block3b_se_squeeze (GlobalAver  (None, 336)         0           ['block3b_activation[0][0]']
#  agePooling2D)
#
#  block3b_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3b_se_squeeze[0][0]']
#
#  block3b_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multiply)   (None, 28, 28, 336)  0           ['block3b_activation[0][0]',
#                                                                   'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv2D)  (None, 28, 28, 56)   18816       ['block3b_se_excite[0][0]']
#
#  block3b_project_bn (BatchNorma  (None, 28, 28, 56)  224         ['block3b_project_conv[0][0]']
#  lization)
#
#  block3b_drop (Dropout)         (None, 28, 28, 56)   0           ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)              (None, 28, 28, 56)   0           ['block3b_drop[0][0]',
#                                                                   'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2D)   (None, 28, 28, 336)  18816       ['block3b_add[0][0]']
#
#  block3c_expand_bn (BatchNormal  (None, 28, 28, 336)  1344       ['block3c_expand_conv[0][0]']
#  ization)
#
#  block3c_expand_activation (Act  (None, 28, 28, 336)  0          ['block3c_expand_bn[0][0]']
#  ivation)
#
#  block3c_dwconv (DepthwiseConv2  (None, 28, 28, 336)  8400       ['block3c_expand_activation[0][0]
#  D)                                                              ']
#
#  block3c_bn (BatchNormalization  (None, 28, 28, 336)  1344       ['block3c_dwconv[0][0]']
#  )
#
#  block3c_activation (Activation  (None, 28, 28, 336)  0          ['block3c_bn[0][0]']
#  )
#
#  block3c_se_squeeze (GlobalAver  (None, 336)         0           ['block3c_activation[0][0]']
#  agePooling2D)
#
#  block3c_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3c_se_squeeze[0][0]']
#
#  block3c_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multiply)   (None, 28, 28, 336)  0           ['block3c_activation[0][0]',
#                                                                   'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv2D)  (None, 28, 28, 56)   18816       ['block3c_se_excite[0][0]']
#
#  block3c_project_bn (BatchNorma  (None, 28, 28, 56)  224         ['block3c_project_conv[0][0]']
#  lization)
#
#  block3c_drop (Dropout)         (None, 28, 28, 56)   0           ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)              (None, 28, 28, 56)   0           ['block3c_drop[0][0]',
#                                                                   'block3b_add[0][0]']
#
#  block3d_expand_conv (Conv2D)   (None, 28, 28, 336)  18816       ['block3c_add[0][0]']
#
#  block3d_expand_bn (BatchNormal  (None, 28, 28, 336)  1344       ['block3d_expand_conv[0][0]']
#  ization)
#
#  block3d_expand_activation (Act  (None, 28, 28, 336)  0          ['block3d_expand_bn[0][0]']
#  ivation)
#
#  block3d_dwconv (DepthwiseConv2  (None, 28, 28, 336)  8400       ['block3d_expand_activation[0][0]
#  D)                                                              ']
#
#  block3d_bn (BatchNormalization  (None, 28, 28, 336)  1344       ['block3d_dwconv[0][0]']
#  )
#
#  block3d_activation (Activation  (None, 28, 28, 336)  0          ['block3d_bn[0][0]']
#  )
#
#  block3d_se_squeeze (GlobalAver  (None, 336)         0           ['block3d_activation[0][0]']
#  agePooling2D)
#
#  block3d_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block3d_se_squeeze[0][0]']
#
#  block3d_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block3d_se_reshape[0][0]']
#
#  block3d_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block3d_se_reduce[0][0]']
#
#  block3d_se_excite (Multiply)   (None, 28, 28, 336)  0           ['block3d_activation[0][0]',
#                                                                   'block3d_se_expand[0][0]']
#
#  block3d_project_conv (Conv2D)  (None, 28, 28, 56)   18816       ['block3d_se_excite[0][0]']
#
#  block3d_project_bn (BatchNorma  (None, 28, 28, 56)  224         ['block3d_project_conv[0][0]']
#  lization)
#
#  block3d_drop (Dropout)         (None, 28, 28, 56)   0           ['block3d_project_bn[0][0]']
#
#  block3d_add (Add)              (None, 28, 28, 56)   0           ['block3d_drop[0][0]',
#                                                                   'block3c_add[0][0]']
#
#  block4a_expand_conv (Conv2D)   (None, 28, 28, 336)  18816       ['block3d_add[0][0]']
#
#  block4a_expand_bn (BatchNormal  (None, 28, 28, 336)  1344       ['block4a_expand_conv[0][0]']
#  ization)
#
#  block4a_expand_activation (Act  (None, 28, 28, 336)  0          ['block4a_expand_bn[0][0]']
#  ivation)
#
#  block4a_dwconv_pad (ZeroPaddin  (None, 29, 29, 336)  0          ['block4a_expand_activation[0][0]
#  g2D)                                                            ']
#
#  block4a_dwconv (DepthwiseConv2  (None, 14, 14, 336)  3024       ['block4a_dwconv_pad[0][0]']
#  D)
#
#  block4a_bn (BatchNormalization  (None, 14, 14, 336)  1344       ['block4a_dwconv[0][0]']
#  )
#
#  block4a_activation (Activation  (None, 14, 14, 336)  0          ['block4a_bn[0][0]']
#  )
#
#  block4a_se_squeeze (GlobalAver  (None, 336)         0           ['block4a_activation[0][0]']
#  agePooling2D)
#
#  block4a_se_reshape (Reshape)   (None, 1, 1, 336)    0           ['block4a_se_squeeze[0][0]']
#
#  block4a_se_reduce (Conv2D)     (None, 1, 1, 14)     4718        ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)     (None, 1, 1, 336)    5040        ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multiply)   (None, 14, 14, 336)  0           ['block4a_activation[0][0]',
#                                                                   'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv2D)  (None, 14, 14, 112)  37632       ['block4a_se_excite[0][0]']
#
#  block4a_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block4a_project_conv[0][0]']
#  lization)
#
#  block4b_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block4a_project_bn[0][0]']
#
#  block4b_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block4b_expand_conv[0][0]']
#  ization)
#
#  block4b_expand_activation (Act  (None, 14, 14, 672)  0          ['block4b_expand_bn[0][0]']
#  ivation)
#
#  block4b_dwconv (DepthwiseConv2  (None, 14, 14, 672)  6048       ['block4b_expand_activation[0][0]
#  D)                                                              ']
#
#  block4b_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block4b_dwconv[0][0]']
#  )
#
#  block4b_activation (Activation  (None, 14, 14, 672)  0          ['block4b_bn[0][0]']
#  )
#
#  block4b_se_squeeze (GlobalAver  (None, 672)         0           ['block4b_activation[0][0]']
#  agePooling2D)
#
#  block4b_se_reshape (Reshape)   (None, 1, 1, 672)    0           ['block4b_se_squeeze[0][0]']
#
#  block4b_se_reduce (Conv2D)     (None, 1, 1, 28)     18844       ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)     (None, 1, 1, 672)    19488       ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multiply)   (None, 14, 14, 672)  0           ['block4b_activation[0][0]',
#                                                                   'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv2D)  (None, 14, 14, 112)  75264       ['block4b_se_excite[0][0]']
#
#  block4b_project_bn (BatchNorma  (None, 14, 14, 112)  448        ['block4b_project_conv[0][0]']
#  lization)
#
#  block4b_drop (Dropout)         (None, 14, 14, 112)  0           ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)              (None, 14, 14, 112)  0           ['block4b_drop[0][0]',
#                                                                   'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2D)   (None, 14, 14, 672)  75264       ['block4b_add[0][0]']
#
#  block4c_expand_bn (BatchNormal  (None, 14, 14, 672)  2688       ['block4c_expand_conv[0][0]']
#  ization)
#
#  block4c_expand_activation (Act  (None, 14, 14, 672)  0          ['block4c_expand_bn[0][0]']
#  ivation)
#
#  block4c_dwconv (DepthwiseConv2  (None, 14, 14, 672)  6048       ['block4c_expand_activation[0][0]
#  D)                                                              ']
#
#  block4c_bn (BatchNormalization  (None, 14, 14, 672)  2688       ['block4c_dwconv[0][0]']
#  )
#
#  block4c_activation (Activation  (None, 14, 14, 672)  0          ['block4c_bn[0][0]']
# ...
#
#  block6g_expand_conv (Conv2D)   (None, 7, 7, 1632)   443904      ['block6f_add[0][0]']
#
#  block6g_expand_bn (BatchNormal  (None, 7, 7, 1632)  6528        ['block6g_expand_conv[0][0]']
#  ization)
#
#  block6g_expand_activation (Act  (None, 7, 7, 1632)  0           ['block6g_expand_bn[0][0]']
#  ivation)
#
#  block6g_dwconv (DepthwiseConv2  (None, 7, 7, 1632)  40800       ['block6g_expand_activation[0][0]
#  D)                                                              ']
#
#  block6g_bn (BatchNormalization  (None, 7, 7, 1632)  6528        ['block6g_dwconv[0][0]']
#  )
#
#  block6g_activation (Activation  (None, 7, 7, 1632)  0           ['block6g_bn[0][0]']
#  )
#
#  block6g_se_squeeze (GlobalAver  (None, 1632)        0           ['block6g_activation[0][0]']
#  agePooling2D)
#
#  block6g_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block6g_se_squeeze[0][0]']
#
#  block6g_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block6g_se_reshape[0][0]']
#
#  block6g_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block6g_se_reduce[0][0]']
#
#  block6g_se_excite (Multiply)   (None, 7, 7, 1632)   0           ['block6g_activation[0][0]',
#                                                                   'block6g_se_expand[0][0]']
#
#  block6g_project_conv (Conv2D)  (None, 7, 7, 272)    443904      ['block6g_se_excite[0][0]']
#
#  block6g_project_bn (BatchNorma  (None, 7, 7, 272)   1088        ['block6g_project_conv[0][0]']
#  lization)
#
#  block6g_drop (Dropout)         (None, 7, 7, 272)    0           ['block6g_project_bn[0][0]']
#
#  block6g_add (Add)              (None, 7, 7, 272)    0           ['block6g_drop[0][0]',
#                                                                   'block6f_add[0][0]']
#
#  block6h_expand_conv (Conv2D)   (None, 7, 7, 1632)   443904      ['block6g_add[0][0]']
#
#  block6h_expand_bn (BatchNormal  (None, 7, 7, 1632)  6528        ['block6h_expand_conv[0][0]']
#  ization)
#
#  block6h_expand_activation (Act  (None, 7, 7, 1632)  0           ['block6h_expand_bn[0][0]']
#  ivation)
#
#  block6h_dwconv (DepthwiseConv2  (None, 7, 7, 1632)  40800       ['block6h_expand_activation[0][0]
#  D)                                                              ']
#
#  block6h_bn (BatchNormalization  (None, 7, 7, 1632)  6528        ['block6h_dwconv[0][0]']
#  )
#
#  block6h_activation (Activation  (None, 7, 7, 1632)  0           ['block6h_bn[0][0]']
#  )
#
#  block6h_se_squeeze (GlobalAver  (None, 1632)        0           ['block6h_activation[0][0]']
#  agePooling2D)
#
#  block6h_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block6h_se_squeeze[0][0]']
#
#  block6h_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block6h_se_reshape[0][0]']
#
#  block6h_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block6h_se_reduce[0][0]']
#
#  block6h_se_excite (Multiply)   (None, 7, 7, 1632)   0           ['block6h_activation[0][0]',
#                                                                   'block6h_se_expand[0][0]']
#
#  block6h_project_conv (Conv2D)  (None, 7, 7, 272)    443904      ['block6h_se_excite[0][0]']
#
#  block6h_project_bn (BatchNorma  (None, 7, 7, 272)   1088        ['block6h_project_conv[0][0]']
#  lization)
#
#  block6h_drop (Dropout)         (None, 7, 7, 272)    0           ['block6h_project_bn[0][0]']
#
#  block6h_add (Add)              (None, 7, 7, 272)    0           ['block6h_drop[0][0]',
#                                                                   'block6g_add[0][0]']
#
#  block7a_expand_conv (Conv2D)   (None, 7, 7, 1632)   443904      ['block6h_add[0][0]']
#
#  block7a_expand_bn (BatchNormal  (None, 7, 7, 1632)  6528        ['block7a_expand_conv[0][0]']
#  ization)
#
#  block7a_expand_activation (Act  (None, 7, 7, 1632)  0           ['block7a_expand_bn[0][0]']
#  ivation)
#
#  block7a_dwconv (DepthwiseConv2  (None, 7, 7, 1632)  14688       ['block7a_expand_activation[0][0]
#  D)                                                              ']
#
#  block7a_bn (BatchNormalization  (None, 7, 7, 1632)  6528        ['block7a_dwconv[0][0]']
#  )
#
#  block7a_activation (Activation  (None, 7, 7, 1632)  0           ['block7a_bn[0][0]']
#  )
#
#  block7a_se_squeeze (GlobalAver  (None, 1632)        0           ['block7a_activation[0][0]']
#  agePooling2D)
#
#  block7a_se_reshape (Reshape)   (None, 1, 1, 1632)   0           ['block7a_se_squeeze[0][0]']
#
#  block7a_se_reduce (Conv2D)     (None, 1, 1, 68)     111044      ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)     (None, 1, 1, 1632)   112608      ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multiply)   (None, 7, 7, 1632)   0           ['block7a_activation[0][0]',
#                                                                   'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv2D)  (None, 7, 7, 448)    731136      ['block7a_se_excite[0][0]']
#
#  block7a_project_bn (BatchNorma  (None, 7, 7, 448)   1792        ['block7a_project_conv[0][0]']
#  lization)
#
#  block7b_expand_conv (Conv2D)   (None, 7, 7, 2688)   1204224     ['block7a_project_bn[0][0]']
#
#  block7b_expand_bn (BatchNormal  (None, 7, 7, 2688)  10752       ['block7b_expand_conv[0][0]']
#  ization)
#
#  block7b_expand_activation (Act  (None, 7, 7, 2688)  0           ['block7b_expand_bn[0][0]']
#  ivation)
#
#  block7b_dwconv (DepthwiseConv2  (None, 7, 7, 2688)  24192       ['block7b_expand_activation[0][0]
#  D)                                                              ']
#
#  block7b_bn (BatchNormalization  (None, 7, 7, 2688)  10752       ['block7b_dwconv[0][0]']
#  )
#
#  block7b_activation (Activation  (None, 7, 7, 2688)  0           ['block7b_bn[0][0]']
#  )
#
#  block7b_se_squeeze (GlobalAver  (None, 2688)        0           ['block7b_activation[0][0]']
#  agePooling2D)
#
#  block7b_se_reshape (Reshape)   (None, 1, 1, 2688)   0           ['block7b_se_squeeze[0][0]']
#
#  block7b_se_reduce (Conv2D)     (None, 1, 1, 112)    301168      ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)     (None, 1, 1, 2688)   303744      ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multiply)   (None, 7, 7, 2688)   0           ['block7b_activation[0][0]',
#                                                                   'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv2D)  (None, 7, 7, 448)    1204224     ['block7b_se_excite[0][0]']
#
#  block7b_project_bn (BatchNorma  (None, 7, 7, 448)   1792        ['block7b_project_conv[0][0]']
#  lization)
#
#  block7b_drop (Dropout)         (None, 7, 7, 448)    0           ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)              (None, 7, 7, 448)    0           ['block7b_drop[0][0]',
#                                                                   'block7a_project_bn[0][0]']
#
#  top_conv (Conv2D)              (None, 7, 7, 1792)   802816      ['block7b_add[0][0]']
#
#  top_bn (BatchNormalization)    (None, 7, 7, 1792)   7168        ['top_conv[0][0]']
#
#  top_activation (Activation)    (None, 7, 7, 1792)   0           ['top_bn[0][0]']
#
# ==================================================================================================
# Total params: 17,673,823
# Trainable params: 0
# Non-trainable params: 17,673,823
# __________________________________________________________________________________________________

# %%
model = keras.models.Sequential()
model.add(base_pretrained_model)
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(100, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(optimizer = Adam(learning_rate = 1e-3), loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb4 (Functional)  (None, 7, 7, 1792)       17673823
#
#  flatten (Flatten)           (None, 87808)             0
#
#  dropout_2 (Dropout)         (None, 87808)             0
#
#  dense_2 (Dense)             (None, 100)               8780900
#
#  dropout_3 (Dropout)         (None, 100)               0
#
#  dense_3 (Dense)             (None, 10)                1010
#
#  dense_4 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 26,455,744
# Trainable params: 8,781,921
# Non-trainable params: 17,673,823
# _________________________________________________________________

# %%
from keras.utils.vis_utils import model_to_dot
from IPython.display import Image
Image(model_to_dot(model, show_shapes=True).create_png())

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cardio_attn_test_valid')

modelCheckPoint = ModelCheckpoint(weight_path, monitor='val_binary_accuracy', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)


reduceLROnPlateau = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=10, verbose=1, mode='auto', epsilon=0.0001, cooldown=5, min_lr=0.0001)
early = EarlyStopping(monitor="val_binary_accuracy", 
                      mode="max", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [modelCheckPoint, early, reduceLROnPlateau]

# %% [markdown]
# # No improvement in learning

# %% [markdown]
# ## Attention Model

# %% [markdown]
# The basic idea is that a Global Average Pooling is too simplistic since some of the regions are more relevant than others. So we build an attention mechanism to turn pixels in the GAP on an off before the pooling and then rescale (Lambda layer) the results based on the number of pixels. The model could be seen as a sort of 'global weighted average' pooling. There is probably something published about it and it is very similar to the kind of attention models used in NLP. It is largely based on the insight that the winning solution annotated and trained a UNET model to segmenting the hand and transforming it. This seems very tedious if we could just learn attention.

# %% [markdown]
# ## Basic Preprocessing
# Here we take the output of the pretrained model and apply BatchNormalization

# %%
t_x.shape[1:]
# Out:
# (224, 224, 3)

# %%
base_pretrained_model(tf.keras.Input(t_x.shape[1:]))
# Out:
# <KerasTensor: shape=(None, 7, 7, 1792) dtype=float32 (created by layer 'efficientnetb4')>

# %%
pretrained_features = Input(base_pretrained_model.get_output_shape_at(0)[1:], name = 'feature_input')
pretrained_depth = base_pretrained_model.get_output_shape_at(0)[-1]
from keras.layers import BatchNormalization
batchNormalised_features = BatchNormalization(name='Features_BN')(pretrained_features)

# %%
attention_layer = Conv2D(128, kernel_size = (1,1), padding = 'same', activation = 'elu')(batchNormalised_features)
attention_layer = Conv2D(32, kernel_size = (1,1), padding = 'same', activation = 'elu')(attention_layer)
attention_layer = Conv2D(16, kernel_size = (1,1), padding = 'same', activation = 'elu')(attention_layer)
attention_layer = AvgPool2D((2,2), strides = (1,1), padding = 'same')(attention_layer) # smooth results
attention_layer = Conv2D(1, 
                    kernel_size = (1,1), 
                    padding = 'valid', 
                    activation = 'sigmoid',
                   name='AttentionMap2D')(attention_layer)

# %% [markdown]
# ## Rescale Attention
# We rescale the feature dimension back out to the original number of features (instead of just 1) by using a hard-coded convolution.

# %%
up_c2_w = np.ones((1, 1, 1, pretrained_depth))
up_c2 = Conv2D(pretrained_depth, kernel_size = (1,1), padding = 'same', name='UpscaleAttention',
               activation = 'linear', use_bias = False, weights = [up_c2_w])
up_c2.trainable = False
attention_layer = up_c2(attention_layer)

# %% [markdown]
# # Global Weighted Average Pooling
# We now want to use the attention layer to weight the regions we want during the average pooling. A standard average pooling layer is poorly suited to this task since many of the values (presumably) will be zero and they will be counted. So we hand-rig a 'weighted average pooling' where we multiply the attention by the features and then divide by the sum of the attention
# The formula for weighted average from [Wikipedia](https://en.wikipedia.org/wiki/Weighted_arithmetic_mean)
# $$ \bar{x} = \frac{ \sum\limits_{i=1}^n w_i x_i}{\sum\limits_{i=1}^n w_i} $$
# What we do is
# $$ \text{GWAP}(x, y, d) = \frac{ \sum\limits_{x}\sum\limits_{y} \text{Attention}(x,y,d) \text{Feature}(x,y,d)} {\sum\limits_{x}\sum\limits_{y} \text{Attention}(x,y,d)} $$

# %%
mask_features = multiply([attention_layer, batchNormalised_features])
gap_features = GlobalAveragePooling2D()(mask_features)
gap_mask = GlobalAveragePooling2D()(attention_layer)
# to account for missing values from the attention model
gap = Lambda(lambda x: x[0]/x[1], name = 'RescaleGAP')([gap_features, gap_mask])

# %% [markdown]
# ## Dropout and Classification
# We know take the output of this global weighted-average pooling and go to a classification with dropout and two fully connected layers

# %%
gap_dr = Dropout(0.5)(gap)
dr_steps = Dropout(0.5)(Dense(128, activation = 'elu')(gap_dr))
out_layer = Dense(1, activation = 'sigmoid')(dr_steps)

attention_model = Model(inputs = [pretrained_features], outputs = [out_layer], name = 'attention_model')

attention_model.compile(optimizer = 'adam', loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy'])

attention_model.summary()
# Out:
# Model: "attention_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  feature_input (InputLayer)     [(None, 7, 7, 1792)  0           []
#                                 ]
#
#  Features_BN (BatchNormalizatio  (None, 7, 7, 1792)  7168        ['feature_input[0][0]']
#  n)
#
#  conv2d_6 (Conv2D)              (None, 7, 7, 128)    229504      ['Features_BN[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 7, 7, 32)     4128        ['conv2d_6[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 7, 7, 16)     528         ['conv2d_7[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 7, 7, 16)    0           ['conv2d_8[0][0]']
#  oling2D)
#
#  AttentionMap2D (Conv2D)        (None, 7, 7, 1)      17          ['average_pooling2d_2[0][0]']
#
#  UpscaleAttention (Conv2D)      (None, 7, 7, 1792)   1792        ['AttentionMap2D[0][0]']
#
#  multiply_1 (Multiply)          (None, 7, 7, 1792)   0           ['UpscaleAttention[0][0]',
#                                                                   'Features_BN[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 1792)        0           ['multiply_1[0][0]']
#  obalAveragePooling2D)
#
#  global_average_pooling2d_3 (Gl  (None, 1792)        0           ['UpscaleAttention[0][0]']
#  obalAveragePooling2D)
#
#  RescaleGAP (Lambda)            (None, 1792)         0           ['global_average_pooling2d_2[0][0
#                                                                  ]',
#                                                                   'global_average_pooling2d_3[0][0
#                                                                  ]']
#
#  dropout_4 (Dropout)            (None, 1792)         0           ['RescaleGAP[0][0]']
#
#  dense_5 (Dense)                (None, 128)          229504      ['dropout_4[0][0]']
#
#  dropout_5 (Dropout)            (None, 128)          0           ['dense_5[0][0]']
#
#  dense_6 (Dense)                (None, 1)            129         ['dropout_5[0][0]']
#
# ==================================================================================================
# Total params: 472,770
# Trainable params: 467,394
# Non-trainable params: 5,376
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model Architecture
# We can show the whole model below

# %%
from keras.utils.vis_utils import model_to_dot
from IPython.display import Image
Image(model_to_dot(attention_model, show_shapes=True).create_png())

# %% [markdown]
# ## Build the whole model
# We build the whole model and fine-tune the results (much lower learning rate)

# %%
from keras.models import Sequential
from keras.optimizers import Adam
combined_Model = Sequential(name = 'combined_model')
base_pretrained_model.trainable = False
combined_Model.add(base_pretrained_model)
combined_Model.add(attention_model)
combined_Model.compile(optimizer = Adam(learning_rate = 1e-3), loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy'])
combined_Model.summary()
# Out:
# Model: "combined_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb4 (Functional)  (None, 7, 7, 1792)       17673823
#
#  attention_model (Functional  (None, 1)                472770
#  )
#
# =================================================================
# Total params: 18,146,593
# Trainable params: 467,394
# Non-trainable params: 17,679,199
# _________________________________________________________________

# %% [markdown]
# # Image Size & training set manipulation to see if it has any effect

# %%
train_gen.batch_size = 24
history = combined_Model.fit_generator(train_gen, 
                      validation_data = (test_X, test_Y), 
                       steps_per_epoch=train_gen.n//train_gen.batch_size,
                      epochs = 100, 
                      callbacks = callbacks_list,
                      workers = 3)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/100
# 2023-03-12 00:20:31.519378: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape incombined_model/efficientnetb4/block1b_drop/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 185/185 [==============================] - ETA: 0s - loss: 0.7948 - binary_accuracy: 0.5680
# Epoch 1: val_binary_accuracy improved from -inf to 0.58862, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 121s 581ms/step - loss: 0.7948 - binary_accuracy: 0.5680 - val_loss: 0.6666 - val_binary_accuracy: 0.5886 - lr: 0.0010
# Epoch 2/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6977 - binary_accuracy: 0.6005
# Epoch 2: val_binary_accuracy improved from 0.58862 to 0.63977, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 96s 511ms/step - loss: 0.6977 - binary_accuracy: 0.6005 - val_loss: 0.6243 - val_binary_accuracy: 0.6398 - lr: 0.0010
# Epoch 3/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6597 - binary_accuracy: 0.6250
# Epoch 3: val_binary_accuracy did not improve from 0.63977
# 185/185 [==============================] - 95s 506ms/step - loss: 0.6597 - binary_accuracy: 0.6250 - val_loss: 0.6488 - val_binary_accuracy: 0.6146 - lr: 0.0010
# Epoch 4/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6491 - binary_accuracy: 0.6291
# Epoch 4: val_binary_accuracy improved from 0.63977 to 0.67363, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 96s 509ms/step - loss: 0.6491 - binary_accuracy: 0.6291 - val_loss: 0.5947 - val_binary_accuracy: 0.6736 - lr: 0.0010
# Epoch 5/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6290 - binary_accuracy: 0.6432
# Epoch 5: val_binary_accuracy did not improve from 0.67363
# 185/185 [==============================] - 94s 503ms/step - loss: 0.6290 - binary_accuracy: 0.6432 - val_loss: 0.6648 - val_binary_accuracy: 0.5865 - lr: 0.0010
# Epoch 6/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6285 - binary_accuracy: 0.6412
# Epoch 6: val_binary_accuracy did not improve from 0.67363
# 185/185 [==============================] - 93s 500ms/step - loss: 0.6285 - binary_accuracy: 0.6412 - val_loss: 0.6028 - val_binary_accuracy: 0.6549 - lr: 0.0010
# Epoch 7/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6340 - binary_accuracy: 0.6430
# Epoch 7: val_binary_accuracy did not improve from 0.67363
# 185/185 [==============================] - 94s 501ms/step - loss: 0.6340 - binary_accuracy: 0.6430 - val_loss: 0.6130 - val_binary_accuracy: 0.6347 - lr: 0.0010
# Epoch 8/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6172 - binary_accuracy: 0.6482
# Epoch 8: val_binary_accuracy did not improve from 0.67363
# 185/185 [==============================] - 95s 502ms/step - loss: 0.6172 - binary_accuracy: 0.6482 - val_loss: 0.6331 - val_binary_accuracy: 0.6174 - lr: 0.0010
# Epoch 9/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6116 - binary_accuracy: 0.6635
# Epoch 9: val_binary_accuracy did not improve from 0.67363
# 185/185 [==============================] - 93s 496ms/step - loss: 0.6116 - binary_accuracy: 0.6635 - val_loss: 0.5896 - val_binary_accuracy: 0.6614 - lr: 0.0010
# Epoch 10/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6146 - binary_accuracy: 0.6550
# Epoch 10: val_binary_accuracy did not improve from 0.67363
# 185/185 [==============================] - 94s 500ms/step - loss: 0.6146 - binary_accuracy: 0.6550 - val_loss: 0.6160 - val_binary_accuracy: 0.6275 - lr: 0.0010
# Epoch 11/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6174 - binary_accuracy: 0.6613
# Epoch 11: val_binary_accuracy improved from 0.67363 to 0.69813, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 95s 506ms/step - loss: 0.6174 - binary_accuracy: 0.6613 - val_loss: 0.5482 - val_binary_accuracy: 0.6981 - lr: 0.0010
# Epoch 12/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6109 - binary_accuracy: 0.6581
# Epoch 12: val_binary_accuracy did not improve from 0.69813
# 185/185 [==============================] - 95s 500ms/step - loss: 0.6109 - binary_accuracy: 0.6581 - val_loss: 0.6585 - val_binary_accuracy: 0.5915 - lr: 0.0010
# Epoch 13/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6126 - binary_accuracy: 0.6568
# Epoch 13: val_binary_accuracy did not improve from 0.69813
# 185/185 [==============================] - 94s 500ms/step - loss: 0.6126 - binary_accuracy: 0.6568 - val_loss: 0.6277 - val_binary_accuracy: 0.6131 - lr: 0.0010
# Epoch 14/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6123 - binary_accuracy: 0.6646
# Epoch 14: val_binary_accuracy did not improve from 0.69813
# 185/185 [==============================] - 95s 504ms/step - loss: 0.6123 - binary_accuracy: 0.6646 - val_loss: 0.6206 - val_binary_accuracy: 0.6275 - lr: 0.0010
# Epoch 15/100
#  35/185 [====>.........................] - ETA: 1:08 - loss: 0.6113 - binary_accuracy: 0.6571Epoch 16/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5966 - binary_accuracy: 0.6777
# Epoch 16: val_binary_accuracy did not improve from 0.69813
# 185/185 [==============================] - 94s 503ms/step - loss: 0.5966 - binary_accuracy: 0.6777 - val_loss: 0.6109 - val_binary_accuracy: 0.6275 - lr: 0.0010
# Epoch 17/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5986 - binary_accuracy: 0.6759
# Epoch 17: val_binary_accuracy did not improve from 0.69813
# 185/185 [==============================] - 93s 496ms/step - loss: 0.5986 - binary_accuracy: 0.6759 - val_loss: 0.6421 - val_binary_accuracy: 0.6059 - lr: 0.0010
# Epoch 18/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5923 - binary_accuracy: 0.6824
# Epoch 18: val_binary_accuracy did not improve from 0.69813
# 185/185 [==============================] - 94s 501ms/step - loss: 0.5923 - binary_accuracy: 0.6824 - val_loss: 0.6309 - val_binary_accuracy: 0.6059 - lr: 0.0010
# Epoch 19/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5925 - binary_accuracy: 0.6795
# Epoch 19: val_binary_accuracy did not improve from 0.69813
# 185/185 [==============================] - 95s 502ms/step - loss: 0.5925 - binary_accuracy: 0.6795 - val_loss: 0.5974 - val_binary_accuracy: 0.6362 - lr: 0.0010
# Epoch 20/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5911 - binary_accuracy: 0.6730
# Epoch 20: val_binary_accuracy did not improve from 0.69813
# 185/185 [==============================] - 95s 503ms/step - loss: 0.5911 - binary_accuracy: 0.6730 - val_loss: 0.6276 - val_binary_accuracy: 0.6138 - lr: 0.0010
# Epoch 21/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5831 - binary_accuracy: 0.6869
# Epoch 21: val_binary_accuracy did not improve from 0.69813
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 185/185 [==============================] - 95s 502ms/step - loss: 0.5831 - binary_accuracy: 0.6869 - val_loss: 0.5819 - val_binary_accuracy: 0.6643 - lr: 0.0010
# Epoch 22/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5771 - binary_accuracy: 0.6941
# Epoch 22: val_binary_accuracy did not improve from 0.69813
# 185/185 [==============================] - 92s 494ms/step - loss: 0.5771 - binary_accuracy: 0.6941 - val_loss: 0.5826 - val_binary_accuracy: 0.6477 - lr: 8.0000e-04
# Epoch 23/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5892 - binary_accuracy: 0.6806
# Epoch 23: val_binary_accuracy improved from 0.69813 to 0.70389, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 96s 508ms/step - loss: 0.5892 - binary_accuracy: 0.6806 - val_loss: 0.5180 - val_binary_accuracy: 0.7039 - lr: 8.0000e-04
# Epoch 24/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5755 - binary_accuracy: 0.6953
# Epoch 24: val_binary_accuracy did not improve from 0.70389
# 185/185 [==============================] - 94s 501ms/step - loss: 0.5755 - binary_accuracy: 0.6953 - val_loss: 0.5672 - val_binary_accuracy: 0.6729 - lr: 8.0000e-04
# Epoch 25/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5751 - binary_accuracy: 0.6953
# Epoch 25: val_binary_accuracy did not improve from 0.70389
# 185/185 [==============================] - 94s 498ms/step - loss: 0.5751 - binary_accuracy: 0.6953 - val_loss: 0.5545 - val_binary_accuracy: 0.6808 - lr: 8.0000e-04
# Epoch 26/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5689 - binary_accuracy: 0.7027
# Epoch 26: val_binary_accuracy did not improve from 0.70389
# 185/185 [==============================] - 93s 497ms/step - loss: 0.5689 - binary_accuracy: 0.7027 - val_loss: 0.5662 - val_binary_accuracy: 0.6664 - lr: 8.0000e-04
# Epoch 27/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5722 - binary_accuracy: 0.7095
# Epoch 27: val_binary_accuracy did not improve from 0.70389
# 185/185 [==============================] - 94s 497ms/step - loss: 0.5722 - binary_accuracy: 0.7095 - val_loss: 0.6740 - val_binary_accuracy: 0.5620 - lr: 8.0000e-04
# Epoch 28/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5689 - binary_accuracy: 0.7095
# Epoch 28: val_binary_accuracy did not improve from 0.70389
# 185/185 [==============================] - 93s 493ms/step - loss: 0.5689 - binary_accuracy: 0.7095 - val_loss: 0.5889 - val_binary_accuracy: 0.6463 - lr: 8.0000e-04
# Epoch 29/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5688 - binary_accuracy: 0.7043
# Epoch 29: val_binary_accuracy did not improve from 0.70389
# 185/185 [==============================] - 94s 499ms/step - loss: 0.5688 - binary_accuracy: 0.7043 - val_loss: 0.5445 - val_binary_accuracy: 0.6866 - lr: 8.0000e-04
# Epoch 30/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5582 - binary_accuracy: 0.7117
# Epoch 30: val_binary_accuracy did not improve from 0.70389
# 185/185 [==============================] - 92s 491ms/step - loss: 0.5582 - binary_accuracy: 0.7117 - val_loss: 0.5483 - val_binary_accuracy: 0.6967 - lr: 8.0000e-04
# Epoch 31/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5538 - binary_accuracy: 0.7218
# Epoch 31: val_binary_accuracy did not improve from 0.70389
# 185/185 [==============================] - 93s 499ms/step - loss: 0.5538 - binary_accuracy: 0.7218 - val_loss: 0.6177 - val_binary_accuracy: 0.6311 - lr: 8.0000e-04
# Epoch 32/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5534 - binary_accuracy: 0.7171
# Epoch 32: val_binary_accuracy did not improve from 0.70389
# 185/185 [==============================] - 94s 501ms/step - loss: 0.5534 - binary_accuracy: 0.7171 - val_loss: 0.5737 - val_binary_accuracy: 0.6643 - lr: 8.0000e-04
# Epoch 33/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5447 - binary_accuracy: 0.7255
# Epoch 33: val_binary_accuracy did not improve from 0.70389
# 185/185 [==============================] - 93s 496ms/step - loss: 0.5447 - binary_accuracy: 0.7255 - val_loss: 0.6190 - val_binary_accuracy: 0.6376 - lr: 8.0000e-04
# Epoch 34/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5392 - binary_accuracy: 0.7311
# Epoch 34: val_binary_accuracy did not improve from 0.70389
# 185/185 [==============================] - 94s 498ms/step - loss: 0.5392 - binary_accuracy: 0.7311 - val_loss: 0.5605 - val_binary_accuracy: 0.6837 - lr: 8.0000e-04
# Epoch 35/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5450 - binary_accuracy: 0.7241
# Epoch 35: val_binary_accuracy improved from 0.70389 to 0.71182, saving model to cardio_attn_test_valid_weights.best.hdf5
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 185/185 [==============================] - 96s 512ms/step - loss: 0.5450 - binary_accuracy: 0.7241 - val_loss: 0.5265 - val_binary_accuracy: 0.7118 - lr: 8.0000e-04
# Epoch 36/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5322 - binary_accuracy: 0.7324
# Epoch 36: val_binary_accuracy did not improve from 0.71182
# 185/185 [==============================] - 94s 498ms/step - loss: 0.5322 - binary_accuracy: 0.7324 - val_loss: 0.6241 - val_binary_accuracy: 0.6376 - lr: 6.4000e-04
# Epoch 37/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5276 - binary_accuracy: 0.7318
# Epoch 37: val_binary_accuracy did not improve from 0.71182
# 185/185 [==============================] - 92s 493ms/step - loss: 0.5276 - binary_accuracy: 0.7318 - val_loss: 0.6096 - val_binary_accuracy: 0.6398 - lr: 6.4000e-04
# Epoch 38/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5239 - binary_accuracy: 0.7401
# Epoch 38: val_binary_accuracy improved from 0.71182 to 0.73055, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 96s 510ms/step - loss: 0.5239 - binary_accuracy: 0.7401 - val_loss: 0.5104 - val_binary_accuracy: 0.7305 - lr: 6.4000e-04
# Epoch 39/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5230 - binary_accuracy: 0.7363
# Epoch 39: val_binary_accuracy did not improve from 0.73055
# 185/185 [==============================] - 92s 493ms/step - loss: 0.5230 - binary_accuracy: 0.7363 - val_loss: 0.6102 - val_binary_accuracy: 0.6470 - lr: 6.4000e-04
# Epoch 40/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5142 - binary_accuracy: 0.7505
# Epoch 40: val_binary_accuracy did not improve from 0.73055
# 185/185 [==============================] - 93s 498ms/step - loss: 0.5142 - binary_accuracy: 0.7505 - val_loss: 0.5985 - val_binary_accuracy: 0.6765 - lr: 6.4000e-04
# Epoch 41/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5131 - binary_accuracy: 0.7532
# Epoch 41: val_binary_accuracy did not improve from 0.73055
# 185/185 [==============================] - 94s 497ms/step - loss: 0.5131 - binary_accuracy: 0.7532 - val_loss: 0.5351 - val_binary_accuracy: 0.6988 - lr: 6.4000e-04
# Epoch 42/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5164 - binary_accuracy: 0.7529
# Epoch 42: val_binary_accuracy did not improve from 0.73055
# 185/185 [==============================] - 92s 493ms/step - loss: 0.5164 - binary_accuracy: 0.7529 - val_loss: 0.5701 - val_binary_accuracy: 0.6751 - lr: 6.4000e-04
# Epoch 43/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5138 - binary_accuracy: 0.7423
# Epoch 43: val_binary_accuracy did not improve from 0.73055
# 185/185 [==============================] - 92s 493ms/step - loss: 0.5138 - binary_accuracy: 0.7423 - val_loss: 0.5782 - val_binary_accuracy: 0.6830 - lr: 6.4000e-04
# Epoch 44/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5060 - binary_accuracy: 0.7543
# Epoch 44: val_binary_accuracy did not improve from 0.73055
# 185/185 [==============================] - 93s 497ms/step - loss: 0.5060 - binary_accuracy: 0.7543 - val_loss: 0.5736 - val_binary_accuracy: 0.6715 - lr: 6.4000e-04
# Epoch 45/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4986 - binary_accuracy: 0.7601
# Epoch 45: val_binary_accuracy did not improve from 0.73055
# 185/185 [==============================] - 94s 499ms/step - loss: 0.4986 - binary_accuracy: 0.7601 - val_loss: 0.5810 - val_binary_accuracy: 0.6751 - lr: 6.4000e-04
# Epoch 46/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5074 - binary_accuracy: 0.7516
# Epoch 46: val_binary_accuracy did not improve from 0.73055
# 185/185 [==============================] - 93s 495ms/step - loss: 0.5074 - binary_accuracy: 0.7516 - val_loss: 0.5445 - val_binary_accuracy: 0.6945 - lr: 6.4000e-04
# Epoch 47/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4959 - binary_accuracy: 0.7626
# Epoch 47: val_binary_accuracy did not improve from 0.73055
# 185/185 [==============================] - 93s 496ms/step - loss: 0.4959 - binary_accuracy: 0.7626 - val_loss: 0.5956 - val_binary_accuracy: 0.6657 - lr: 6.4000e-04
# Epoch 48/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4844 - binary_accuracy: 0.7662
# Epoch 48: val_binary_accuracy did not improve from 0.73055
# 185/185 [==============================] - 93s 493ms/step - loss: 0.4844 - binary_accuracy: 0.7662 - val_loss: 0.5323 - val_binary_accuracy: 0.7248 - lr: 6.4000e-04
# Epoch 49/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4829 - binary_accuracy: 0.7660
# Epoch 49: val_binary_accuracy did not improve from 0.73055
#
# Epoch 49: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# 185/185 [==============================] - 93s 500ms/step - loss: 0.4829 - binary_accuracy: 0.7660 - val_loss: 0.5998 - val_binary_accuracy: 0.6988 - lr: 6.4000e-04
# Epoch 50/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4865 - binary_accuracy: 0.7649
# Epoch 50: val_binary_accuracy improved from 0.73055 to 0.74568, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 96s 507ms/step - loss: 0.4865 - binary_accuracy: 0.7649 - val_loss: 0.5062 - val_binary_accuracy: 0.7457 - lr: 5.1200e-04
# Epoch 51/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4798 - binary_accuracy: 0.7766
# Epoch 51: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 93s 494ms/step - loss: 0.4798 - binary_accuracy: 0.7766 - val_loss: 0.5350 - val_binary_accuracy: 0.7082 - lr: 5.1200e-04
# Epoch 52/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4727 - binary_accuracy: 0.7867
# Epoch 52: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 93s 500ms/step - loss: 0.4727 - binary_accuracy: 0.7867 - val_loss: 0.6290 - val_binary_accuracy: 0.6484 - lr: 5.1200e-04
# Epoch 53/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4542 - binary_accuracy: 0.7921
# Epoch 53: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 92s 494ms/step - loss: 0.4542 - binary_accuracy: 0.7921 - val_loss: 0.5996 - val_binary_accuracy: 0.6859 - lr: 5.1200e-04
# Epoch 54/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4620 - binary_accuracy: 0.7838
# Epoch 54: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 92s 493ms/step - loss: 0.4620 - binary_accuracy: 0.7838 - val_loss: 0.6508 - val_binary_accuracy: 0.6376 - lr: 5.1200e-04
# Epoch 55/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4596 - binary_accuracy: 0.7883
# Epoch 55: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 93s 495ms/step - loss: 0.4596 - binary_accuracy: 0.7883 - val_loss: 0.6033 - val_binary_accuracy: 0.6780 - lr: 5.1200e-04
# Epoch 56/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4591 - binary_accuracy: 0.7851
# Epoch 56: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 93s 496ms/step - loss: 0.4591 - binary_accuracy: 0.7851 - val_loss: 0.6076 - val_binary_accuracy: 0.6873 - lr: 5.1200e-04
# Epoch 57/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4493 - binary_accuracy: 0.7941
# Epoch 57: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 92s 491ms/step - loss: 0.4493 - binary_accuracy: 0.7941 - val_loss: 0.5849 - val_binary_accuracy: 0.7061 - lr: 5.1200e-04
# Epoch 58/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4598 - binary_accuracy: 0.7854
# Epoch 58: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 94s 495ms/step - loss: 0.4598 - binary_accuracy: 0.7854 - val_loss: 0.5642 - val_binary_accuracy: 0.7097 - lr: 5.1200e-04
# Epoch 59/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4485 - binary_accuracy: 0.7921
# Epoch 59: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 92s 489ms/step - loss: 0.4485 - binary_accuracy: 0.7921 - val_loss: 0.5474 - val_binary_accuracy: 0.7277 - lr: 5.1200e-04
# Epoch 60/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4457 - binary_accuracy: 0.7939
# Epoch 60: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 93s 495ms/step - loss: 0.4457 - binary_accuracy: 0.7939 - val_loss: 0.5922 - val_binary_accuracy: 0.7097 - lr: 5.1200e-04
# Epoch 61/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4514 - binary_accuracy: 0.7896
# Epoch 61: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 94s 500ms/step - loss: 0.4514 - binary_accuracy: 0.7896 - val_loss: 0.5972 - val_binary_accuracy: 0.6837 - lr: 5.1200e-04
# Epoch 62/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4281 - binary_accuracy: 0.8063
# Epoch 62: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 94s 497ms/step - loss: 0.4281 - binary_accuracy: 0.8063 - val_loss: 0.5222 - val_binary_accuracy: 0.7341 - lr: 5.1200e-04
# Epoch 63/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4385 - binary_accuracy: 0.8032
# Epoch 63: val_binary_accuracy did not improve from 0.74568
#
# Epoch 63: ReduceLROnPlateau reducing learning rate to 0.00040960004553198815.
# 185/185 [==============================] - 93s 493ms/step - loss: 0.4385 - binary_accuracy: 0.8032 - val_loss: 0.5652 - val_binary_accuracy: 0.7111 - lr: 5.1200e-04
# Epoch 64/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4290 - binary_accuracy: 0.8020
# Epoch 64: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 94s 498ms/step - loss: 0.4290 - binary_accuracy: 0.8020 - val_loss: 0.5305 - val_binary_accuracy: 0.7370 - lr: 4.0960e-04
# Epoch 65/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4283 - binary_accuracy: 0.8020
# Epoch 65: val_binary_accuracy did not improve from 0.74568
# 185/185 [==============================] - 93s 496ms/step - loss: 0.4283 - binary_accuracy: 0.8020 - val_loss: 0.5760 - val_binary_accuracy: 0.6988 - lr: 4.0960e-04

# %%
np.save('history.npy',history.history)

# %%
combined_Model.load_weights(weight_path)

# %%
history1=np.load('/kaggle/working/history.npy',allow_pickle='TRUE').item()

# %%
pred_Y = combined_Model.predict(test_X, 
                          batch_size = 32, 
                          verbose = True)
# Out:
# 44/44 [==============================] - 4s 93ms/step

# %%
plt.matshow(confusion_matrix(test_Y, pred_Y>0.5))
print(classification_report(test_Y, pred_Y>0.5, target_names = ['Healthy', 'Cardiomegaly']))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.91      0.76      0.83      1110
# Cardiomegaly       0.42      0.69      0.52       278
#
#     accuracy                           0.75      1388
#    macro avg       0.66      0.73      0.67      1388
# weighted avg       0.81      0.75      0.77      1388

# %%
plt.plot(history1['binary_accuracy'])
plt.plot(history1['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history1['loss'])
plt.plot(history1['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## Test Results

# %%
final_pred_Y = combined_Model.predict(final_test_X, 
                                verbose = True, 
                                batch_size = 4)
# Out:
# 347/347 [==============================] - 7s 21ms/step

# %%
plt.matshow(confusion_matrix(final_test_Y, final_pred_Y>0.5))
print(classification_report(final_test_Y, final_pred_Y>0.5, target_names = ['Healthy', 'Cardiomegaly']))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.90      0.76      0.82      1110
# Cardiomegaly       0.40      0.65      0.50       278
#
#     accuracy                           0.73      1388
#    macro avg       0.65      0.70      0.66      1388
# weighted avg       0.80      0.73      0.76      1388

# %%
def getPerformanceMetrics(real_values,pred_values,format):
    CM = confusion_matrix(real_values,pred_values)
    TN = CM[0][0]
    FN = CM[1][0] 
    TP = CM[1][1]
    FP = CM[0][1]
    Population = TN+FN+TP+FP
    Accuracy   = round( (TP+TN) / Population,4)
    PPV        = round( TP / (TP+FP),4 )
    NPV        = round( TN / (TN+FN),4 )
    Sensitivity= round( TP / (TP+FN),4 )
    Specificity= round( TN / (TN+FP),4 )
    if format==1:
        performance_metrics = pd.DataFrame({'Metric': ['Accuracy','PPV','NPV','Sensitivity','Specificity'],
                                            'Value':[Accuracy,PPV,NPV,Sensitivity,Specificity]})
    else:
        performance_metrics = pd.DataFrame({'Accuracy':[Accuracy],'PPV':[PPV],'NPV':[NPV],'Sensitivity':[Sensitivity],'Specificity':[Specificity]})
        
    return performance_metrics

# %% [markdown]
# ## Validation Metrics

# %%
print(getPerformanceMetrics(test_Y, pred_Y>0.5,2))
# Out:
#    Accuracy     PPV     NPV  Sensitivity  Specificity
# 0    0.7457  0.4187  0.9083       0.6942       0.7586

# %% [markdown]
# ## Test Metrics

# %%
print(getPerformanceMetrics(final_test_Y,final_pred_Y>0.5,2))
# Out:
#    Accuracy     PPV     NPV  Sensitivity  Specificity
# 0    0.7349  0.4004  0.8964       0.6511       0.7559
