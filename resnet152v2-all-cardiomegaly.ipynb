# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os 
from glob import glob 
import matplotlib.pyplot as plt
import keras
from skimage.util import montage as montage2d
from skimage.io import imread
import seaborn as sns
from keras.optimizers import Adam
import tensorflow as tf
from keras import Input
from keras.models import Model
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.applications import ResNet152V2, InceptionV3, EfficientNetB7, MobileNetV3Small
from keras.layers import Dense, Flatten, Activation, Conv2D, MaxPooling2D, Dropout, Conv2D,MaxPooling2D,GlobalAveragePooling2D,AvgPool2D,multiply, LocallyConnected2D, Lambda, AvgPool2D


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
        

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
base_dir = os.path.join('..', 'input', 'pulmonary-chest-xray-abnormalities')
all_xray_images_dataframe = pd.read_csv('../input/data/Data_Entry_2017.csv')
all_xray_images_dataframe.sample(5)
# Out:
#              Image Index                   Finding Labels  Follow-up #  \
# 21280   00005681_034.png  Effusion|Emphysema|Pneumothorax           34
# 49873   00012633_000.png                       No Finding            0
# 54799   00013708_003.png             Atelectasis|Effusion            3
# 103434  00027593_000.png                       No Finding            0
# 35987   00009496_002.png                       No Finding            2
#
#         Patient ID  Patient Age Patient Gender View Position  \
# 21280         5681           46              M            AP
# 49873        12633           46              M            PA
# 54799        13708           57              F            PA
# 103434       27593           25              M            PA
# 35987         9496           34              M            AP
#
#         OriginalImage[Width  Height]  OriginalImagePixelSpacing[x     y]  \
# 21280                  3056     2544                        0.139  0.139
# 49873                  2992     2991                        0.143  0.143
# 54799                  2850     2742                        0.143  0.143
# 103434                 2992     2991                        0.143  0.143
# 35987                  2500     2048                        0.168  0.168
#
#         Unnamed: 11
# 21280           NaN
# 49873           NaN
# 54799           NaN
# 103434          NaN
# 35987           NaN

# %%
all_xray_images_dataframe['Finding Labels']
# Out:
# 0                   Cardiomegaly
# 1         Cardiomegaly|Emphysema
# 2          Cardiomegaly|Effusion
# 3                     No Finding
# 4                         Hernia
#                    ...
# 112115            Mass|Pneumonia
# 112116                No Finding
# 112117                No Finding
# 112118                No Finding
# 112119                No Finding
# Name: Finding Labels, Length: 112120, dtype: object

# %% [markdown]
# # Preprocessing
# Organize the files by cases with and without cardiomegaly

# %%
all_xray_images_dataframe = pd.read_csv('../input/data/Data_Entry_2017.csv')
all_images_paths = {os.path.basename(x): x for x in 
                   glob(os.path.join('..', 'input', 'data',  'images*', '*', '*.png'))}
print('Scans found:', len(all_images_paths), ', Total Headers', all_xray_images_dataframe.shape[0])
all_xray_images_dataframe['path'] = all_xray_images_dataframe['Image Index'].map(all_images_paths.get)
all_xray_images_dataframe['Cardiomegaly'] = all_xray_images_dataframe['Finding Labels'].map(lambda x: 'Cardiomegaly' in x)
all_xray_images_dataframe['Patient Age'] = np.clip(all_xray_images_dataframe['Patient Age'], 5, 100)
all_xray_images_dataframe['Patient Male'] = all_xray_images_dataframe['Patient Gender'].map(lambda x: x.upper()=='M').astype('float32')
all_xray_images_dataframe.sample(3)
# Out:
# Scans found: 112120 , Total Headers 112120
#              Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 110298  00030038_010.png       Effusion           10       30038           28
# 28028   00007309_000.png       Fibrosis            0        7309           46
# 101025  00026825_012.png     No Finding           12       26825           35
#
#        Patient Gender View Position  OriginalImage[Width  Height]  \
# 110298              F            AP                 3056     2544
# 28028               M            PA                 2500     2048
# 101025              F            PA                 2990     2991
#
#         OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 110298                        0.139  0.139          NaN
# 28028                         0.168  0.168          NaN
# 101025                        0.143  0.143          NaN
#
#                                                     path  Cardiomegaly  \
# 110298  ../input/data/images_012/images/00030038_010.png         False
# 28028   ../input/data/images_004/images/00007309_000.png         False
# 101025  ../input/data/images_011/images/00026825_012.png         False
#
#         Patient Male
# 110298           0.0
# 28028            1.0
# 101025           0.0

# %% [markdown]
# # Examine the distributions
# Show how the data is distributed and why we need to balance it

# %%
sns.pairplot(all_xray_images_dataframe[['Patient Age', 'Patient Male', 'Cardiomegaly']], hue='Cardiomegaly')

# %% [markdown]
# # Split Data into Training and Validation

# %%
positive_cases = np.sum(all_xray_images_dataframe['Cardiomegaly']==True)//2
oversample_factor = 4 # maximum number of cases in negative group so it isn't super rare
more_balanced_df = all_xray_images_dataframe.groupby(['Patient Gender', 'Cardiomegaly']).apply(lambda x: x.sample(min(oversample_factor*positive_cases, x.shape[0]), 
                                                                                   replace = False)
                                                      ).reset_index(drop = True)

print(more_balanced_df['Cardiomegaly'].value_counts())
sns.pairplot(more_balanced_df[['Patient Age', 'Cardiomegaly']], hue='Cardiomegaly')
# Out:
# False    11104
# True      2776
# Name: Cardiomegaly, dtype: int64

# %%
more_balanced_df
# Out:
#             Image Index                     Finding Labels  Follow-up #  \
# 0      00002178_000.png                         No Finding            0
# 1      00003363_000.png                         No Finding            0
# 2      00006663_004.png  Atelectasis|Effusion|Infiltration            4
# 3      00000623_002.png                       Infiltration            2
# 4      00011935_000.png            Mass|Pleural_Thickening            0
# ...                 ...                                ...          ...
# 13875  00006481_015.png                       Cardiomegaly           15
# 13876  00028467_000.png          Cardiomegaly|Infiltration            0
# 13877  00013257_002.png                       Cardiomegaly            2
# 13878  00012741_004.png           Atelectasis|Cardiomegaly            4
# 13879  00004893_061.png              Cardiomegaly|Effusion           61
#
#        Patient ID  Patient Age Patient Gender View Position  \
# 0            2178           20              F            PA
# 1            3363           52              F            PA
# 2            6663           48              F            AP
# 3             623           61              F            PA
# 4           11935           74              F            PA
# ...           ...          ...            ...           ...
# 13875        6481           52              M            AP
# 13876       28467           58              M            PA
# 13877       13257           58              M            PA
# 13878       12741           43              M            AP
# 13879        4893           32              M            AP
#
#        OriginalImage[Width  Height]  OriginalImagePixelSpacing[x        y]  \
# 0                     2048     2500                     0.171000  0.171000
# 1                     2048     2500                     0.171000  0.171000
# 2                     2500     2048                     0.171000  0.171000
# 3                     1705     2021                     0.194311  0.194311
# 4                     2750     2421                     0.143000  0.143000
# ...                    ...      ...                          ...       ...
# 13875                 2500     2048                     0.168000  0.168000
# 13876                 2020     2021                     0.194311  0.194311
# 13877                 2990     2991                     0.143000  0.143000
# 13878                 2500     2048                     0.168000  0.168000
# 13879                 2500     2048                     0.168000  0.168000
#
#        Unnamed: 11                                              path  \
# 0              NaN  ../input/data/images_002/images/00002178_000.png
# 1              NaN  ../input/data/images_002/images/00003363_000.png
# 2              NaN  ../input/data/images_004/images/00006663_004.png
# 3              NaN  ../input/data/images_001/images/00000623_002.png
# 4              NaN  ../input/data/images_006/images/00011935_000.png
# ...            ...                                               ...
# 13875          NaN  ../input/data/images_003/images/00006481_015.png
# 13876          NaN  ../input/data/images_012/images/00028467_000.png
# 13877          NaN  ../input/data/images_006/images/00013257_002.png
# 13878          NaN  ../input/data/images_006/images/00012741_004.png
# 13879          NaN  ../input/data/images_003/images/00004893_061.png
#
#        Cardiomegaly  Patient Male
# 0             False           0.0
# 1             False           0.0
# 2             False           0.0
# 3             False           0.0
# 4             False           0.0
# ...             ...           ...
# 13875          True           1.0
# 13876          True           1.0
# 13877          True           1.0
# 13878          True           1.0
# 13879          True           1.0
#
# [13880 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split
raw_train_df, test_valid_df = train_test_split(more_balanced_df, 
                                   test_size = 0.20, 
                                   random_state = 2018,
                                   stratify = more_balanced_df[['Cardiomegaly', 'Patient Gender']])
valid_df, test_df = train_test_split(test_valid_df, 
                                   test_size = 0.40, 
                                   random_state = 2018,
                                   stratify = test_valid_df[['Cardiomegaly', 'Patient Gender']])
print('train', raw_train_df.shape[0], 'validation', valid_df.shape[0], 'test', test_df.shape[0])
print('train', raw_train_df['Cardiomegaly'].value_counts())
print('test', test_df['Cardiomegaly'].value_counts())
raw_train_df.sample(1)
# Out:
# train 11104 validation 1665 test 1111
# train False    8884
# True     2220
# Name: Cardiomegaly, dtype: int64
# test False    888
# True     223
# Name: Cardiomegaly, dtype: int64
#           Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 286  00027213_078.png     No Finding           78       27213           73
#
#     Patient Gender View Position  OriginalImage[Width  Height]  \
# 286              F            AP                 3056     2544
#
#      OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 286                        0.139  0.139          NaN
#
#                                                  path  Cardiomegaly  \
# 286  ../input/data/images_011/images/00027213_078.png         False
#
#      Patient Male
# 286           0.0

# %%
from sklearn.model_selection import train_test_split
raw_train_df, test_valid_df = train_test_split(more_balanced_df, 
                                   test_size = 0.20, 
                                   random_state = 2018,
                                   stratify = more_balanced_df[['Cardiomegaly', 'Patient Gender']])
valid_df, test_df = train_test_split(test_valid_df, 
                                   test_size = 0.50, 
                                   random_state = 2018,
                                   stratify = test_valid_df[['Cardiomegaly', 'Patient Gender']])
print('train', raw_train_df.shape[0], 'validation', valid_df.shape[0], 'test', test_df.shape[0])
print('train', raw_train_df['Cardiomegaly'].value_counts())
print('test', test_df['Cardiomegaly'].value_counts())
raw_train_df.sample(1)
# Out:
# train 11104 validation 1388 test 1388
# train False    8884
# True     2220
# Name: Cardiomegaly, dtype: int64
# test False    1110
# True      278
# Name: Cardiomegaly, dtype: int64
#            Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 4290  00022251_000.png     No Finding            0       22251           47
#
#      Patient Gender View Position  OriginalImage[Width  Height]  \
# 4290              F            PA                 2992     2991
#
#       OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 4290                        0.143  0.143          NaN
#
#                                                   path  Cardiomegaly  \
# 4290  ../input/data/images_010/images/00022251_000.png         False
#
#       Patient Male
# 4290           0.0

# %% [markdown]
# # Balance the distribution in the training set

# %%
train_df = raw_train_df.groupby(['Cardiomegaly']).apply(lambda x: x.sample(2220, replace = True)
                                                      ).reset_index(drop = True)
print('New Data Size:', train_df.shape[0], 'Old Size:', raw_train_df.shape[0])
# Out:
# New Data Size: 4440 Old Size: 11104

# %%
train_df = raw_train_df

# %%
print('train', train_df['Cardiomegaly'].value_counts())
# Out:
# train False    8884
# True     2220
# Name: Cardiomegaly, dtype: int64

# %%
from keras.preprocessing.image import ImageDataGenerator
##from keras.applications.resnet_v2 import ResNet50 as PreTrainedModel, preprocess_input
#from keras.applications.resnet_v2 import ResNet152V2, preprocess_input
from keras.applications.resnet_v2 import ResNet152V2 as PreTrainedModel, preprocess_input
IMG_SIZE = (224, 224) # size that ResNet152V2 expects
image_data_generator = ImageDataGenerator(samplewise_center=False, 
                              samplewise_std_normalization=False, 
                              horizontal_flip=False, 
                              vertical_flip=False, 
                              height_shift_range=0.1, 
                              width_shift_range=0.1, 
                              brightness_range=[0.7, 1.5],
                              rotation_range=3, 
                              shear_range=0.01,
                              fill_mode='nearest',
                              zoom_range=0.125,
                             preprocessing_function=preprocess_input)

# %%
def flow_from_dataframe(img_data_gen, in_df, path_col, y_col, **dflow_args):
    df_gen = img_data_gen.flow_from_dataframe(in_df,
                                              x_col=path_col,
                                              y_col=y_col,
                                     class_mode = 'raw',
                                    **dflow_args)
    return df_gen

# %%
train_gen = flow_from_dataframe(image_data_generator, train_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 16)

valid_gen = flow_from_dataframe(image_data_generator, valid_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 256) 
test_X, test_Y = next(flow_from_dataframe(image_data_generator, 
                               valid_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 1388)) # one big batch
# used a fixed dataset for final evaluation
final_test_X, final_test_Y = next(flow_from_dataframe(image_data_generator, 
                               test_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 1388)) # one big batch
# Out:
# Found 11104 validated image filenames.
# Found 1388 validated image filenames.
# Found 1388 validated image filenames.
# Found 1388 validated image filenames.

# %%
t_x, t_y = next(train_gen)
t_y
# Out:
# array([False, False,  True, False, False,  True, False, False, False,
#        False, False,  True, False, False, False,  True])

# %%
t_x, t_y = next(train_gen)
print(t_x.shape)
print(t_y)
fig, m_axs = plt.subplots(4, 4, figsize = (16, 8))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone', vmin = -127, vmax = 127)
    c_ax.set_title('%s' % ('Cardiomegaly' if c_y else 'Healthy'))
    c_ax.axis('off')
# Out:
# (16, 224, 224, 3)
# [False False  True False False False False False False  True False False
#  False False False  True]

# %%
base_pretrained_model = PreTrainedModel(input_shape =  t_x.shape[1:], 
                              include_top = False, weights = 'imagenet')
base_pretrained_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet152v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 234545216/234545216 [==============================] - 2s 0us/step

# %%
base_pretrained_model.summary()
# Out:
# Model: "resnet152v2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_conv[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_preact_bn (BatchN  (None, 56, 56, 64)  256         ['pool1_pool[0][0]']
#  ormalization)
#
#  conv2_block1_preact_relu (Acti  (None, 56, 56, 64)  0           ['conv2_block1_preact_bn[0][0]']
#  vation)
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4096        ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block1_1_relu[0][0]']
#  g2D)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block1_2_pad[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_conv[0][0]',
#                                                                   'conv2_block1_3_conv[0][0]']
#
#  conv2_block2_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block1_out[0][0]']
#  ormalization)
#
#  conv2_block2_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block2_preact_bn[0][0]']
#  vation)
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block2_1_relu[0][0]']
#  g2D)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36864       ['conv2_block2_2_pad[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_out (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_conv[0][0]']
#
#  conv2_block3_preact_bn (BatchN  (None, 56, 56, 256)  1024       ['conv2_block2_out[0][0]']
#  ormalization)
#
#  conv2_block3_preact_relu (Acti  (None, 56, 56, 256)  0          ['conv2_block3_preact_bn[0][0]']
#  vation)
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16384       ['conv2_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_pad (ZeroPaddin  (None, 58, 58, 64)  0           ['conv2_block3_1_relu[0][0]']
#  g2D)
#
#  conv2_block3_2_conv (Conv2D)   (None, 28, 28, 64)   36864       ['conv2_block3_2_pad[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 28, 28, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 28, 28, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  max_pooling2d (MaxPooling2D)   (None, 28, 28, 256)  0           ['conv2_block2_out[0][0]']
#
#  conv2_block3_3_conv (Conv2D)   (None, 28, 28, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_out (Add)         (None, 28, 28, 256)  0           ['max_pooling2d[0][0]',
#                                                                   'conv2_block3_3_conv[0][0]']
#
#  conv3_block1_preact_bn (BatchN  (None, 28, 28, 256)  1024       ['conv2_block3_out[0][0]']
#  ormalization)
#
#  conv3_block1_preact_relu (Acti  (None, 28, 28, 256)  0          ['conv3_block1_preact_bn[0][0]']
#  vation)
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32768       ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block1_1_relu[0][0]']
#  g2D)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block1_2_pad[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv3_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_conv[0][0]',
#                                                                   'conv3_block1_3_conv[0][0]']
#
#  conv3_block2_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block1_out[0][0]']
#  ormalization)
#
#  conv3_block2_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block2_preact_bn[0][0]']
#  vation)
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block2_1_relu[0][0]']
#  g2D)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block2_2_pad[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_out (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_conv[0][0]']
#
#  conv3_block3_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block2_out[0][0]']
#  ormalization)
#
#  conv3_block3_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block3_preact_bn[0][0]']
#  vation)
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block3_1_relu[0][0]']
#  g2D)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block3_2_pad[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_out (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_conv[0][0]']
#
#  conv3_block4_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block3_out[0][0]']
#  ormalization)
#
#  conv3_block4_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block4_preact_bn[0][0]']
#  vation)
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block4_1_relu[0][0]']
#  g2D)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block4_2_pad[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_out (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_conv[0][0]']
#
#  conv3_block5_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block4_out[0][0]']
#  ormalization)
#
#  conv3_block5_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block5_preact_bn[0][0]']
#  vation)
#
#  conv3_block5_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block5_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block5_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_1_conv[0][0]']
#  ization)
#
#  conv3_block5_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_1_bn[0][0]']
#  n)
#
#  conv3_block5_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block5_1_relu[0][0]']
#  g2D)
#
#  conv3_block5_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block5_2_pad[0][0]']
#
#  conv3_block5_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block5_2_conv[0][0]']
#  ization)
#
#  conv3_block5_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block5_2_bn[0][0]']
#  n)
#
#  conv3_block5_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block5_2_relu[0][0]']
#
#  conv3_block5_out (Add)         (None, 28, 28, 512)  0           ['conv3_block4_out[0][0]',
#                                                                   'conv3_block5_3_conv[0][0]']
#
#  conv3_block6_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block5_out[0][0]']
#  ormalization)
#
#  conv3_block6_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block6_preact_bn[0][0]']
#  vation)
#
#  conv3_block6_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block6_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block6_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_1_conv[0][0]']
#  ization)
#
#  conv3_block6_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_1_bn[0][0]']
#  n)
#
#  conv3_block6_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block6_1_relu[0][0]']
#  g2D)
#
#  conv3_block6_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block6_2_pad[0][0]']
#
#  conv3_block6_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block6_2_conv[0][0]']
#  ization)
#
#  conv3_block6_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block6_2_bn[0][0]']
#  n)
#
#  conv3_block6_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block6_2_relu[0][0]']
#
#  conv3_block6_out (Add)         (None, 28, 28, 512)  0           ['conv3_block5_out[0][0]',
#                                                                   'conv3_block6_3_conv[0][0]']
#
#  conv3_block7_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block6_out[0][0]']
#  ormalization)
#
#  conv3_block7_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block7_preact_bn[0][0]']
#  vation)
#
#  conv3_block7_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block7_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block7_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_1_conv[0][0]']
#  ization)
#
#  conv3_block7_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_1_bn[0][0]']
#  n)
#
#  conv3_block7_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block7_1_relu[0][0]']
#  g2D)
#
#  conv3_block7_2_conv (Conv2D)   (None, 28, 28, 128)  147456      ['conv3_block7_2_pad[0][0]']
#
#  conv3_block7_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block7_2_conv[0][0]']
#  ization)
#
#  conv3_block7_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block7_2_bn[0][0]']
#  n)
#
#  conv3_block7_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block7_2_relu[0][0]']
#
#  conv3_block7_out (Add)         (None, 28, 28, 512)  0           ['conv3_block6_out[0][0]',
#                                                                   'conv3_block7_3_conv[0][0]']
#
#  conv3_block8_preact_bn (BatchN  (None, 28, 28, 512)  2048       ['conv3_block7_out[0][0]']
#  ormalization)
#
#  conv3_block8_preact_relu (Acti  (None, 28, 28, 512)  0          ['conv3_block8_preact_bn[0][0]']
#  vation)
#
#  conv3_block8_1_conv (Conv2D)   (None, 28, 28, 128)  65536       ['conv3_block8_preact_relu[0][0]'
#                                                                  ]
#
#  conv3_block8_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block8_1_conv[0][0]']
#  ization)
#
#  conv3_block8_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block8_1_bn[0][0]']
#  n)
#
#  conv3_block8_2_pad (ZeroPaddin  (None, 30, 30, 128)  0          ['conv3_block8_1_relu[0][0]']
#  g2D)
#
#  conv3_block8_2_conv (Conv2D)   (None, 14, 14, 128)  147456      ['conv3_block8_2_pad[0][0]']
#
#  conv3_block8_2_bn (BatchNormal  (None, 14, 14, 128)  512        ['conv3_block8_2_conv[0][0]']
#  ization)
#
#  conv3_block8_2_relu (Activatio  (None, 14, 14, 128)  0          ['conv3_block8_2_bn[0][0]']
#  n)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 14, 14, 512)  0          ['conv3_block7_out[0][0]']
#
#  conv3_block8_3_conv (Conv2D)   (None, 14, 14, 512)  66048       ['conv3_block8_2_relu[0][0]']
#
#  conv3_block8_out (Add)         (None, 14, 14, 512)  0           ['max_pooling2d_1[0][0]',
#                                                                   'conv3_block8_3_conv[0][0]']
#
#  conv4_block1_preact_bn (BatchN  (None, 14, 14, 512)  2048       ['conv3_block8_out[0][0]']
#  ormalization)
#
#  conv4_block1_preact_relu (Acti  (None, 14, 14, 512)  0          ['conv4_block1_preact_bn[0][0]']
#  vation)
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131072      ['conv4_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block1_1_relu[0][0]']
#  g2D)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block1_2_pad[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv4_block1_preact_relu[0][0]'
#                                 )                                ]
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_conv[0][0]',
#                                 )                                 'conv4_block1_3_conv[0][0]']
#
#  conv4_block2_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block1_out[0][0]']
#  ormalization)                  )
#
#  conv4_block2_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block2_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block2_1_relu[0][0]']
#  g2D)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block2_2_pad[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_out (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_conv[0][0]']
#
#  conv4_block3_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block2_out[0][0]']
#  ormalization)                  )
#
#  conv4_block3_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block3_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block3_1_relu[0][0]']
#  g2D)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  589824      ['conv4_block3_2_pad[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_out (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_conv[0][0]']
#
#  conv4_block4_preact_bn (BatchN  (None, 14, 14, 1024  4096       ['conv4_block3_out[0][0]']
#  ormalization)                  )
#
#  conv4_block4_preact_relu (Acti  (None, 14, 14, 1024  0          ['conv4_block4_preact_bn[0][0]']
#  vation)                        )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262144      ['conv4_block4_preact_relu[0][0]'
#                                                                  ]
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_pad (ZeroPaddin  (None, 16, 16, 256)  0          ['conv4_block4_1_relu[0][0]']
#  g2D)
#
# ...
#                                                                  ']
#
#  conv4_block35_1_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block35_1_conv[0][0]']
#  lization)
#
#  conv4_block35_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block35_1_bn[0][0]']
#  on)
#
#  conv4_block35_2_pad (ZeroPaddi  (None, 16, 16, 256)  0          ['conv4_block35_1_relu[0][0]']
#  ng2D)
#
#  conv4_block35_2_conv (Conv2D)  (None, 14, 14, 256)  589824      ['conv4_block35_2_pad[0][0]']
#
#  conv4_block35_2_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block35_2_conv[0][0]']
#  lization)
#
#  conv4_block35_2_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block35_2_bn[0][0]']
#  on)
#
#  conv4_block35_3_conv (Conv2D)  (None, 14, 14, 1024  263168      ['conv4_block35_2_relu[0][0]']
#                                 )
#
#  conv4_block35_out (Add)        (None, 14, 14, 1024  0           ['conv4_block34_out[0][0]',
#                                 )                                 'conv4_block35_3_conv[0][0]']
#
#  conv4_block36_preact_bn (Batch  (None, 14, 14, 1024  4096       ['conv4_block35_out[0][0]']
#  Normalization)                 )
#
#  conv4_block36_preact_relu (Act  (None, 14, 14, 1024  0          ['conv4_block36_preact_bn[0][0]']
#  ivation)                       )
#
#  conv4_block36_1_conv (Conv2D)  (None, 14, 14, 256)  262144      ['conv4_block36_preact_relu[0][0]
#                                                                  ']
#
#  conv4_block36_1_bn (BatchNorma  (None, 14, 14, 256)  1024       ['conv4_block36_1_conv[0][0]']
#  lization)
#
#  conv4_block36_1_relu (Activati  (None, 14, 14, 256)  0          ['conv4_block36_1_bn[0][0]']
#  on)
#
#  conv4_block36_2_pad (ZeroPaddi  (None, 16, 16, 256)  0          ['conv4_block36_1_relu[0][0]']
#  ng2D)
#
#  conv4_block36_2_conv (Conv2D)  (None, 7, 7, 256)    589824      ['conv4_block36_2_pad[0][0]']
#
#  conv4_block36_2_bn (BatchNorma  (None, 7, 7, 256)   1024        ['conv4_block36_2_conv[0][0]']
#  lization)
#
#  conv4_block36_2_relu (Activati  (None, 7, 7, 256)   0           ['conv4_block36_2_bn[0][0]']
#  on)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 7, 7, 1024)  0           ['conv4_block35_out[0][0]']
#
#  conv4_block36_3_conv (Conv2D)  (None, 7, 7, 1024)   263168      ['conv4_block36_2_relu[0][0]']
#
#  conv4_block36_out (Add)        (None, 7, 7, 1024)   0           ['max_pooling2d_2[0][0]',
#                                                                   'conv4_block36_3_conv[0][0]']
#
#  conv5_block1_preact_bn (BatchN  (None, 7, 7, 1024)  4096        ['conv4_block36_out[0][0]']
#  ormalization)
#
#  conv5_block1_preact_relu (Acti  (None, 7, 7, 1024)  0           ['conv5_block1_preact_bn[0][0]']
#  vation)
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524288      ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block1_1_relu[0][0]']
#  g2D)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block1_2_pad[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv5_block1_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_conv[0][0]',
#                                                                   'conv5_block1_3_conv[0][0]']
#
#  conv5_block2_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block1_out[0][0]']
#  ormalization)
#
#  conv5_block2_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block2_preact_bn[0][0]']
#  vation)
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block2_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block2_1_relu[0][0]']
#  g2D)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block2_2_pad[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_conv[0][0]']
#
#  conv5_block3_preact_bn (BatchN  (None, 7, 7, 2048)  8192        ['conv5_block2_out[0][0]']
#  ormalization)
#
#  conv5_block3_preact_relu (Acti  (None, 7, 7, 2048)  0           ['conv5_block3_preact_bn[0][0]']
#  vation)
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1048576     ['conv5_block3_preact_relu[0][0]'
#                                                                  ]
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_pad (ZeroPaddin  (None, 9, 9, 512)   0           ['conv5_block3_1_relu[0][0]']
#  g2D)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359296     ['conv5_block3_2_pad[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_out (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_conv[0][0]']
#
#  post_bn (BatchNormalization)   (None, 7, 7, 2048)   8192        ['conv5_block3_out[0][0]']
#
#  post_relu (Activation)         (None, 7, 7, 2048)   0           ['post_bn[0][0]']
#
# ==================================================================================================
# Total params: 58,331,648
# Trainable params: 0
# Non-trainable params: 58,331,648
# __________________________________________________________________________________________________

# %%
model = keras.models.Sequential()
model.add(base_pretrained_model)
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(100, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(optimizer = Adam(learning_rate = 1e-3), loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152v2 (Functional)    (None, 7, 7, 2048)        58331648
#
#  flatten (Flatten)           (None, 100352)            0
#
#  dropout (Dropout)           (None, 100352)            0
#
#  dense (Dense)               (None, 100)               10035300
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 10)                1010
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 68,367,969
# Trainable params: 10,036,321
# Non-trainable params: 58,331,648
# _________________________________________________________________

# %%
from keras.utils.vis_utils import model_to_dot
from IPython.display import Image
Image(model_to_dot(model, show_shapes=True).create_png())

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cardio_attn_test_valid')

modelCheckPoint = ModelCheckpoint(weight_path, monitor='val_binary_accuracy', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)


reduceLROnPlateau = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=10, verbose=1, mode='auto', epsilon=0.0001, cooldown=5, min_lr=0.0001)
early = EarlyStopping(monitor="val_binary_accuracy", 
                      mode="max", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [modelCheckPoint, early, reduceLROnPlateau]

# %%
train_gen.batch_size = 24
model.fit_generator(train_gen, 
                      validation_data = (test_X, test_Y), 
                       steps_per_epoch=train_gen.n//train_gen.batch_size,
                      epochs = 30, 
                      callbacks = callbacks_list,
                      workers = 3)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/30
# 185/185 [==============================] - ETA: 0s - loss: 244.8985 - binary_accuracy: 0.5052
# Epoch 1: val_loss improved from inf to 0.67746, saving model to cardio_attn_weights.best.hdf5
# 185/185 [==============================] - 127s 577ms/step - loss: 244.8985 - binary_accuracy: 0.5052 - val_loss: 0.6775 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 2/30
# 185/185 [==============================] - ETA: 0s - loss: 37.0525 - binary_accuracy: 0.4910
# Epoch 2: val_loss did not improve from 0.67746
# 185/185 [==============================] - 97s 518ms/step - loss: 37.0525 - binary_accuracy: 0.4910 - val_loss: 0.7624 - val_binary_accuracy: 0.5225 - lr: 0.0010
# Epoch 3/30
# 185/185 [==============================] - ETA: 0s - loss: 20.7749 - binary_accuracy: 0.4930
# Epoch 3: val_loss improved from 0.67746 to 0.67483, saving model to cardio_attn_weights.best.hdf5
# 185/185 [==============================] - 100s 533ms/step - loss: 20.7749 - binary_accuracy: 0.4930 - val_loss: 0.6748 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 4/30
# 185/185 [==============================] - ETA: 0s - loss: 11.9248 - binary_accuracy: 0.5027
# Epoch 4: val_loss did not improve from 0.67483
# 185/185 [==============================] - 97s 518ms/step - loss: 11.9248 - binary_accuracy: 0.5027 - val_loss: 0.6751 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 5/30
# 185/185 [==============================] - ETA: 0s - loss: 4.5053 - binary_accuracy: 0.5002
# Epoch 5: val_loss did not improve from 0.67483
# 185/185 [==============================] - 96s 516ms/step - loss: 4.5053 - binary_accuracy: 0.5002 - val_loss: 0.6759 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 6/30
# 185/185 [==============================] - ETA: 0s - loss: 4.1105 - binary_accuracy: 0.5149
# Epoch 6: val_loss improved from 0.67483 to 0.67401, saving model to cardio_attn_weights.best.hdf5
# 185/185 [==============================] - 100s 533ms/step - loss: 4.1105 - binary_accuracy: 0.5149 - val_loss: 0.6740 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 7/30
# 185/185 [==============================] - ETA: 0s - loss: 2.2054 - binary_accuracy: 0.5020
# Epoch 7: val_loss did not improve from 0.67401
# 185/185 [==============================] - 97s 514ms/step - loss: 2.2054 - binary_accuracy: 0.5020 - val_loss: 0.6748 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 8/30
# 185/185 [==============================] - ETA: 0s - loss: 0.9909 - binary_accuracy: 0.5014
# Epoch 8: val_loss did not improve from 0.67401
# 185/185 [==============================] - 97s 518ms/step - loss: 0.9909 - binary_accuracy: 0.5014 - val_loss: 0.6768 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 9/30
# 185/185 [==============================] - ETA: 0s - loss: 0.8845 - binary_accuracy: 0.5011
# Epoch 9: val_loss did not improve from 0.67401
# 185/185 [==============================] - 98s 521ms/step - loss: 0.8845 - binary_accuracy: 0.5011 - val_loss: 0.6777 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 10/30
# 185/185 [==============================] - ETA: 0s - loss: 0.8227 - binary_accuracy: 0.4950
# Epoch 10: val_loss did not improve from 0.67401
# 185/185 [==============================] - 97s 520ms/step - loss: 0.8227 - binary_accuracy: 0.4950 - val_loss: 0.6803 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 11/30
# 185/185 [==============================] - ETA: 0s - loss: 0.8030 - binary_accuracy: 0.5027
# Epoch 11: val_loss did not improve from 0.67401
# 185/185 [==============================] - 97s 518ms/step - loss: 0.8030 - binary_accuracy: 0.5027 - val_loss: 0.6815 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 12/30
# 185/185 [==============================] - ETA: 0s - loss: 0.8327 - binary_accuracy: 0.5047
# Epoch 12: val_loss did not improve from 0.67401
# 185/185 [==============================] - 97s 517ms/step - loss: 0.8327 - binary_accuracy: 0.5047 - val_loss: 0.6841 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 13/30
# 185/185 [==============================] - ETA: 0s - loss: 0.7633 - binary_accuracy: 0.4980
# Epoch 13: val_loss did not improve from 0.67401
# 185/185 [==============================] - 98s 522ms/step - loss: 0.7633 - binary_accuracy: 0.4980 - val_loss: 0.6847 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 14/30
# 185/185 [==============================] - ETA: 0s - loss: 0.7338 - binary_accuracy: 0.4957
# Epoch 14: val_loss did not improve from 0.67401
# 185/185 [==============================] - 97s 517ms/step - loss: 0.7338 - binary_accuracy: 0.4957 - val_loss: 0.6900 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 15/30
# 185/185 [==============================] - ETA: 0s - loss: 0.7235 - binary_accuracy: 0.5027
# Epoch 15: val_loss did not improve from 0.67401
# 185/185 [==============================] - 99s 523ms/step - loss: 0.7235 - binary_accuracy: 0.5027 - val_loss: 0.6909 - val_binary_accuracy: 0.8075 - lr: 0.0010
# Epoch 16/30
# 185/185 [==============================] - ETA: 0s - loss: 0.7369 - binary_accuracy: 0.4964
# Epoch 16: val_loss did not improve from 0.67401
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 185/185 [==============================] - 98s 523ms/step - loss: 0.7369 - binary_accuracy: 0.4964 - val_loss: 0.6901 - val_binary_accuracy: 0.8075 - lr: 0.0010

# %% [markdown]
# # No improvement in learning

# %% [markdown]
# ## Attention Model

# %% [markdown]
# The basic idea is that a Global Average Pooling is too simplistic since some of the regions are more relevant than others. So we build an attention mechanism to turn pixels in the GAP on an off before the pooling and then rescale (Lambda layer) the results based on the number of pixels. The model could be seen as a sort of 'global weighted average' pooling. There is probably something published about it and it is very similar to the kind of attention models used in NLP. It is largely based on the insight that the winning solution annotated and trained a UNET model to segmenting the hand and transforming it. This seems very tedious if we could just learn attention.

# %% [markdown]
# ## Basic Preprocessing
# Here we take the output of the pretrained model and apply BatchNormalization

# %%
t_x.shape[1:]
# Out:
# (224, 224, 3)

# %%
base_pretrained_model(tf.keras.Input(t_x.shape[1:]))
# Out:
# <KerasTensor: shape=(None, 7, 7, 2048) dtype=float32 (created by layer 'resnet152v2')>

# %%
pretrained_features = Input(base_pretrained_model.get_output_shape_at(0)[1:], name = 'feature_input')
pretrained_depth = base_pretrained_model.get_output_shape_at(0)[-1]
from keras.layers import BatchNormalization
batchNormalised_features = BatchNormalization(name='Features_BN')(pretrained_features)

# %%
attention_layer = Conv2D(128, kernel_size = (1,1), padding = 'same', activation = 'elu')(batchNormalised_features)
attention_layer = Conv2D(32, kernel_size = (1,1), padding = 'same', activation = 'elu')(attention_layer)
attention_layer = Conv2D(16, kernel_size = (1,1), padding = 'same', activation = 'elu')(attention_layer)
attention_layer = AvgPool2D((2,2), strides = (1,1), padding = 'same')(attention_layer) # smooth results
attention_layer = Conv2D(1, 
                    kernel_size = (1,1), 
                    padding = 'valid', 
                    activation = 'sigmoid',
                   name='AttentionMap2D')(attention_layer)

# %% [markdown]
# ## Rescale Attention
# We rescale the feature dimension back out to the original number of features (instead of just 1) by using a hard-coded convolution.

# %%
up_c2_w = np.ones((1, 1, 1, pretrained_depth))
up_c2 = Conv2D(pretrained_depth, kernel_size = (1,1), padding = 'same', name='UpscaleAttention',
               activation = 'linear', use_bias = False, weights = [up_c2_w])
up_c2.trainable = False
attention_layer = up_c2(attention_layer)

# %% [markdown]
# # Global Weighted Average Pooling
# We now want to use the attention layer to weight the regions we want during the average pooling. A standard average pooling layer is poorly suited to this task since many of the values (presumably) will be zero and they will be counted. So we hand-rig a 'weighted average pooling' where we multiply the attention by the features and then divide by the sum of the attention
# The formula for weighted average from [Wikipedia](https://en.wikipedia.org/wiki/Weighted_arithmetic_mean)
# $$ \bar{x} = \frac{ \sum\limits_{i=1}^n w_i x_i}{\sum\limits_{i=1}^n w_i} $$
# What we do is
# $$ \text{GWAP}(x, y, d) = \frac{ \sum\limits_{x}\sum\limits_{y} \text{Attention}(x,y,d) \text{Feature}(x,y,d)} {\sum\limits_{x}\sum\limits_{y} \text{Attention}(x,y,d)} $$

# %%
mask_features = multiply([attention_layer, batchNormalised_features])
gap_features = GlobalAveragePooling2D()(mask_features)
gap_mask = GlobalAveragePooling2D()(attention_layer)
# to account for missing values from the attention model
gap = Lambda(lambda x: x[0]/x[1], name = 'RescaleGAP')([gap_features, gap_mask])

# %% [markdown]
# ## Dropout and Classification
# We know take the output of this global weighted-average pooling and go to a classification with dropout and two fully connected layers

# %%
gap_dr = Dropout(0.5)(gap)
dr_steps = Dropout(0.5)(Dense(128, activation = 'elu')(gap_dr))
out_layer = Dense(1, activation = 'sigmoid')(dr_steps)

attention_model = Model(inputs = [pretrained_features], outputs = [out_layer], name = 'attention_model')

attention_model.compile(optimizer = 'adam', loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy'])

attention_model.summary()
# Out:
# Model: "attention_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  feature_input (InputLayer)     [(None, 7, 7, 2048)  0           []
#                                 ]
#
#  Features_BN (BatchNormalizatio  (None, 7, 7, 2048)  8192        ['feature_input[0][0]']
#  n)
#
#  conv2d (Conv2D)                (None, 7, 7, 128)    262272      ['Features_BN[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 32)     4128        ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 7, 7, 16)     528         ['conv2d_1[0][0]']
#
#  average_pooling2d (AveragePool  (None, 7, 7, 16)    0           ['conv2d_2[0][0]']
#  ing2D)
#
#  AttentionMap2D (Conv2D)        (None, 7, 7, 1)      17          ['average_pooling2d[0][0]']
#
#  UpscaleAttention (Conv2D)      (None, 7, 7, 2048)   2048        ['AttentionMap2D[0][0]']
#
#  multiply (Multiply)            (None, 7, 7, 2048)   0           ['UpscaleAttention[0][0]',
#                                                                   'Features_BN[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['multiply[0][0]']
#  alAveragePooling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['UpscaleAttention[0][0]']
#  obalAveragePooling2D)
#
#  RescaleGAP (Lambda)            (None, 2048)         0           ['global_average_pooling2d[0][0]'
#                                                                  , 'global_average_pooling2d_1[0][
#                                                                  0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['RescaleGAP[0][0]']
#
#  dense (Dense)                  (None, 128)          262272      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1)            129         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 539,586
# Trainable params: 533,442
# Non-trainable params: 6,144
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model Architecture
# We can show the whole model below

# %%
from keras.utils.vis_utils import model_to_dot
from IPython.display import Image
Image(model_to_dot(attention_model, show_shapes=True).create_png())

# %% [markdown]
# ## Build the whole model
# We build the whole model and fine-tune the results (much lower learning rate)

# %%
from keras.models import Sequential
from keras.optimizers import Adam
combined_Model = Sequential(name = 'combined_model')
base_pretrained_model.trainable = False
combined_Model.add(base_pretrained_model)
combined_Model.add(attention_model)
combined_Model.compile(optimizer = Adam(learning_rate = 1e-3), loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy'])
combined_Model.summary()
# Out:
# Model: "combined_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet152v2 (Functional)    (None, 7, 7, 2048)        58331648
#
#  attention_model (Functional  (None, 1)                539586
#  )
#
# =================================================================
# Total params: 58,871,234
# Trainable params: 533,442
# Non-trainable params: 58,337,792
# _________________________________________________________________

# %%
combined_Model.fit_generator(train_gen, 
                      validation_data = (test_X, test_Y), 
                       steps_per_epoch=train_gen.n//train_gen.batch_size,
                      epochs = 2, 
                      callbacks = callbacks_list,
                      workers = 3)

# %% [markdown]
# # Image Size & training set manipulation to see if it has any effect

# %%
train_gen.batch_size = 24
history = combined_Model.fit_generator(train_gen, 
                      validation_data = (test_X, test_Y), 
                       steps_per_epoch=train_gen.n//train_gen.batch_size,
                      epochs = 100, 
                      callbacks = callbacks_list,
                      workers = 3)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/100
# 462/462 [==============================] - ETA: 0s - loss: 0.5086 - binary_accuracy: 0.7791
# Epoch 1: val_binary_accuracy improved from -inf to 0.80620, saving model to cardio_attn_test_valid_weights.best.hdf5
# 462/462 [==============================] - 280s 567ms/step - loss: 0.5086 - binary_accuracy: 0.7791 - val_loss: 0.4435 - val_binary_accuracy: 0.8062 - lr: 0.0010
# Epoch 2/100
# 462/462 [==============================] - ETA: 0s - loss: 0.4526 - binary_accuracy: 0.8042
# Epoch 2: val_binary_accuracy improved from 0.80620 to 0.81124, saving model to cardio_attn_test_valid_weights.best.hdf5
# 462/462 [==============================] - 244s 527ms/step - loss: 0.4526 - binary_accuracy: 0.8042 - val_loss: 0.4428 - val_binary_accuracy: 0.8112 - lr: 0.0010
# Epoch 3/100
# 462/462 [==============================] - ETA: 0s - loss: 0.4354 - binary_accuracy: 0.8101
# Epoch 3: val_binary_accuracy did not improve from 0.81124
# 462/462 [==============================] - 244s 524ms/step - loss: 0.4354 - binary_accuracy: 0.8101 - val_loss: 0.4339 - val_binary_accuracy: 0.8062 - lr: 0.0010
# Epoch 4/100
# 462/462 [==============================] - ETA: 0s - loss: 0.4313 - binary_accuracy: 0.8086
# Epoch 4: val_binary_accuracy improved from 0.81124 to 0.81412, saving model to cardio_attn_test_valid_weights.best.hdf5
# 462/462 [==============================] - 239s 515ms/step - loss: 0.4313 - binary_accuracy: 0.8086 - val_loss: 0.4276 - val_binary_accuracy: 0.8141 - lr: 0.0010
# Epoch 5/100
# 462/462 [==============================] - ETA: 0s - loss: 0.4317 - binary_accuracy: 0.8091
# Epoch 5: val_binary_accuracy did not improve from 0.81412
# 462/462 [==============================] - 236s 508ms/step - loss: 0.4317 - binary_accuracy: 0.8091 - val_loss: 0.4274 - val_binary_accuracy: 0.8120 - lr: 0.0010
# Epoch 6/100
# 462/462 [==============================] - ETA: 0s - loss: 0.4202 - binary_accuracy: 0.8171
# Epoch 6: val_binary_accuracy improved from 0.81412 to 0.81556, saving model to cardio_attn_test_valid_weights.best.hdf5
# 462/462 [==============================] - 242s 522ms/step - loss: 0.4202 - binary_accuracy: 0.8171 - val_loss: 0.4197 - val_binary_accuracy: 0.8156 - lr: 0.0010
# Epoch 7/100
# 462/462 [==============================] - ETA: 0s - loss: 0.4174 - binary_accuracy: 0.8189
# Epoch 7: val_binary_accuracy did not improve from 0.81556
# 462/462 [==============================] - 240s 517ms/step - loss: 0.4174 - binary_accuracy: 0.8189 - val_loss: 0.4243 - val_binary_accuracy: 0.8098 - lr: 0.0010
# Epoch 8/100
# 462/462 [==============================] - ETA: 0s - loss: 0.4129 - binary_accuracy: 0.8210
# Epoch 8: val_binary_accuracy improved from 0.81556 to 0.82277, saving model to cardio_attn_test_valid_weights.best.hdf5
# 462/462 [==============================] - 240s 515ms/step - loss: 0.4129 - binary_accuracy: 0.8210 - val_loss: 0.4078 - val_binary_accuracy: 0.8228 - lr: 0.0010
# Epoch 9/100
# 462/462 [==============================] - ETA: 0s - loss: 0.4087 - binary_accuracy: 0.8208
# Epoch 9: val_binary_accuracy did not improve from 0.82277
# 462/462 [==============================] - 240s 517ms/step - loss: 0.4087 - binary_accuracy: 0.8208 - val_loss: 0.4261 - val_binary_accuracy: 0.8148 - lr: 0.0010
# Epoch 10/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3994 - binary_accuracy: 0.8237
# Epoch 10: val_binary_accuracy did not improve from 0.82277
# 462/462 [==============================] - 241s 519ms/step - loss: 0.3994 - binary_accuracy: 0.8237 - val_loss: 0.4118 - val_binary_accuracy: 0.8170 - lr: 0.0010
# Epoch 11/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3985 - binary_accuracy: 0.8257
# Epoch 11: val_binary_accuracy did not improve from 0.82277
# 462/462 [==============================] - 237s 512ms/step - loss: 0.3985 - binary_accuracy: 0.8257 - val_loss: 0.4207 - val_binary_accuracy: 0.8120 - lr: 0.0010
# Epoch 12/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3910 - binary_accuracy: 0.8282
# Epoch 12: val_binary_accuracy did not improve from 0.82277
# 462/462 [==============================] - 236s 508ms/step - loss: 0.3910 - binary_accuracy: 0.8282 - val_loss: 0.4188 - val_binary_accuracy: 0.8120 - lr: 0.0010
# Epoch 13/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3883 - binary_accuracy: 0.8320
# Epoch 13: val_binary_accuracy did not improve from 0.82277
# 462/462 [==============================] - 236s 508ms/step - loss: 0.3883 - binary_accuracy: 0.8320 - val_loss: 0.3995 - val_binary_accuracy: 0.8213 - lr: 0.0010
# Epoch 14/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3826 - binary_accuracy: 0.8319
# Epoch 14: val_binary_accuracy did not improve from 0.82277
# 462/462 [==============================] - 240s 518ms/step - loss: 0.3826 - binary_accuracy: 0.8319 - val_loss: 0.4081 - val_binary_accuracy: 0.8163 - lr: 0.0010
# Epoch 15/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3775 - binary_accuracy: 0.8362
# Epoch 15: val_binary_accuracy did not improve from 0.82277
# 462/462 [==============================] - 243s 524ms/step - loss: 0.3775 - binary_accuracy: 0.8362 - val_loss: 0.4042 - val_binary_accuracy: 0.8170 - lr: 0.0010
# Epoch 16/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3687 - binary_accuracy: 0.8402
# Epoch 16: val_binary_accuracy did not improve from 0.82277
# 462/462 [==============================] - 242s 521ms/step - loss: 0.3687 - binary_accuracy: 0.8402 - val_loss: 0.4094 - val_binary_accuracy: 0.8213 - lr: 0.0010
# Epoch 17/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3750 - binary_accuracy: 0.8358
# Epoch 17: val_binary_accuracy improved from 0.82277 to 0.82349, saving model to cardio_attn_test_valid_weights.best.hdf5
# 462/462 [==============================] - 239s 515ms/step - loss: 0.3750 - binary_accuracy: 0.8358 - val_loss: 0.3993 - val_binary_accuracy: 0.8235 - lr: 0.0010
# Epoch 18/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3648 - binary_accuracy: 0.8399
# Epoch 18: val_binary_accuracy did not improve from 0.82349
# 462/462 [==============================] - 237s 509ms/step - loss: 0.3648 - binary_accuracy: 0.8399 - val_loss: 0.4134 - val_binary_accuracy: 0.8177 - lr: 0.0010
# Epoch 19/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3582 - binary_accuracy: 0.8436
# Epoch 19: val_binary_accuracy improved from 0.82349 to 0.82709, saving model to cardio_attn_test_valid_weights.best.hdf5
# 462/462 [==============================] - 241s 519ms/step - loss: 0.3582 - binary_accuracy: 0.8436 - val_loss: 0.4002 - val_binary_accuracy: 0.8271 - lr: 0.0010
# Epoch 20/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3606 - binary_accuracy: 0.8408
# Epoch 20: val_binary_accuracy did not improve from 0.82709
# 462/462 [==============================] - 241s 520ms/step - loss: 0.3606 - binary_accuracy: 0.8408 - val_loss: 0.4260 - val_binary_accuracy: 0.8170 - lr: 0.0010
# Epoch 21/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3591 - binary_accuracy: 0.8423
# Epoch 21: val_binary_accuracy did not improve from 0.82709
# 462/462 [==============================] - 240s 517ms/step - loss: 0.3591 - binary_accuracy: 0.8423 - val_loss: 0.4116 - val_binary_accuracy: 0.8177 - lr: 0.0010
# Epoch 22/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3531 - binary_accuracy: 0.8482
# Epoch 22: val_binary_accuracy did not improve from 0.82709
# 462/462 [==============================] - 236s 509ms/step - loss: 0.3531 - binary_accuracy: 0.8482 - val_loss: 0.4036 - val_binary_accuracy: 0.8213 - lr: 0.0010
# Epoch 23/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3527 - binary_accuracy: 0.8511
# Epoch 23: val_binary_accuracy did not improve from 0.82709
# 462/462 [==============================] - 236s 508ms/step - loss: 0.3527 - binary_accuracy: 0.8511 - val_loss: 0.4103 - val_binary_accuracy: 0.8177 - lr: 0.0010
# Epoch 24/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3443 - binary_accuracy: 0.8449
# Epoch 24: val_binary_accuracy did not improve from 0.82709
# 462/462 [==============================] - 238s 510ms/step - loss: 0.3443 - binary_accuracy: 0.8449 - val_loss: 0.4155 - val_binary_accuracy: 0.8271 - lr: 0.0010
# Epoch 25/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3466 - binary_accuracy: 0.8500
# Epoch 25: val_binary_accuracy did not improve from 0.82709
# 462/462 [==============================] - 237s 510ms/step - loss: 0.3466 - binary_accuracy: 0.8500 - val_loss: 0.4080 - val_binary_accuracy: 0.8192 - lr: 0.0010
# Epoch 26/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3412 - binary_accuracy: 0.8499
# Epoch 26: val_binary_accuracy did not improve from 0.82709
# 462/462 [==============================] - 236s 507ms/step - loss: 0.3412 - binary_accuracy: 0.8499 - val_loss: 0.4174 - val_binary_accuracy: 0.8192 - lr: 0.0010
# Epoch 27/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3386 - binary_accuracy: 0.8542
# Epoch 27: val_binary_accuracy did not improve from 0.82709
#
# Epoch 27: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 462/462 [==============================] - 237s 509ms/step - loss: 0.3386 - binary_accuracy: 0.8542 - val_loss: 0.4086 - val_binary_accuracy: 0.8256 - lr: 0.0010
# Epoch 28/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3361 - binary_accuracy: 0.8556
# Epoch 28: val_binary_accuracy improved from 0.82709 to 0.83357, saving model to cardio_attn_test_valid_weights.best.hdf5
# 462/462 [==============================] - 238s 513ms/step - loss: 0.3361 - binary_accuracy: 0.8556 - val_loss: 0.3953 - val_binary_accuracy: 0.8336 - lr: 8.0000e-04
# Epoch 29/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3272 - binary_accuracy: 0.8564
# Epoch 29: val_binary_accuracy improved from 0.83357 to 0.83501, saving model to cardio_attn_test_valid_weights.best.hdf5
# 462/462 [==============================] - 239s 512ms/step - loss: 0.3272 - binary_accuracy: 0.8564 - val_loss: 0.4034 - val_binary_accuracy: 0.8350 - lr: 8.0000e-04
# Epoch 30/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3324 - binary_accuracy: 0.8537
# Epoch 30: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 235s 507ms/step - loss: 0.3324 - binary_accuracy: 0.8537 - val_loss: 0.3937 - val_binary_accuracy: 0.8314 - lr: 8.0000e-04
# Epoch 31/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3157 - binary_accuracy: 0.8631
# Epoch 31: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 240s 517ms/step - loss: 0.3157 - binary_accuracy: 0.8631 - val_loss: 0.4271 - val_binary_accuracy: 0.8285 - lr: 8.0000e-04
# Epoch 32/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3226 - binary_accuracy: 0.8588
# Epoch 32: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 243s 525ms/step - loss: 0.3226 - binary_accuracy: 0.8588 - val_loss: 0.4217 - val_binary_accuracy: 0.8220 - lr: 8.0000e-04
# Epoch 33/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3192 - binary_accuracy: 0.8606
# Epoch 33: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 236s 508ms/step - loss: 0.3192 - binary_accuracy: 0.8606 - val_loss: 0.4146 - val_binary_accuracy: 0.8242 - lr: 8.0000e-04
# Epoch 34/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3185 - binary_accuracy: 0.8614
# Epoch 34: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 237s 510ms/step - loss: 0.3185 - binary_accuracy: 0.8614 - val_loss: 0.4099 - val_binary_accuracy: 0.8163 - lr: 8.0000e-04
# Epoch 35/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3097 - binary_accuracy: 0.8676
# Epoch 35: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 235s 506ms/step - loss: 0.3097 - binary_accuracy: 0.8676 - val_loss: 0.4157 - val_binary_accuracy: 0.8285 - lr: 8.0000e-04
# Epoch 36/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3124 - binary_accuracy: 0.8649
# Epoch 36: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 238s 511ms/step - loss: 0.3124 - binary_accuracy: 0.8649 - val_loss: 0.4054 - val_binary_accuracy: 0.8256 - lr: 8.0000e-04
# Epoch 37/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3063 - binary_accuracy: 0.8662
# Epoch 37: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 238s 513ms/step - loss: 0.3063 - binary_accuracy: 0.8662 - val_loss: 0.4298 - val_binary_accuracy: 0.8307 - lr: 8.0000e-04
# Epoch 38/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3097 - binary_accuracy: 0.8678
# Epoch 38: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 234s 504ms/step - loss: 0.3097 - binary_accuracy: 0.8678 - val_loss: 0.4122 - val_binary_accuracy: 0.8278 - lr: 8.0000e-04
# Epoch 39/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3037 - binary_accuracy: 0.8668
# Epoch 39: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 238s 513ms/step - loss: 0.3037 - binary_accuracy: 0.8668 - val_loss: 0.4135 - val_binary_accuracy: 0.8336 - lr: 8.0000e-04
# Epoch 40/100
# 462/462 [==============================] - ETA: 0s - loss: 0.3089 - binary_accuracy: 0.8666
# Epoch 40: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 239s 516ms/step - loss: 0.3089 - binary_accuracy: 0.8666 - val_loss: 0.4424 - val_binary_accuracy: 0.8278 - lr: 8.0000e-04
# Epoch 41/100
# 462/462 [==============================] - ETA: 0s - loss: 0.2951 - binary_accuracy: 0.8700
# Epoch 41: val_binary_accuracy did not improve from 0.83501
#
# Epoch 41: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 462/462 [==============================] - 237s 511ms/step - loss: 0.2951 - binary_accuracy: 0.8700 - val_loss: 0.4177 - val_binary_accuracy: 0.8285 - lr: 8.0000e-04
# Epoch 42/100
# 462/462 [==============================] - ETA: 0s - loss: 0.2868 - binary_accuracy: 0.8740
# Epoch 42: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 239s 515ms/step - loss: 0.2868 - binary_accuracy: 0.8740 - val_loss: 0.4361 - val_binary_accuracy: 0.8314 - lr: 6.4000e-04
# Epoch 43/100
# 462/462 [==============================] - ETA: 0s - loss: 0.2929 - binary_accuracy: 0.8734
# Epoch 43: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 237s 510ms/step - loss: 0.2929 - binary_accuracy: 0.8734 - val_loss: 0.4540 - val_binary_accuracy: 0.8264 - lr: 6.4000e-04
# Epoch 44/100
# 462/462 [==============================] - ETA: 0s - loss: 0.2910 - binary_accuracy: 0.8718
# Epoch 44: val_binary_accuracy did not improve from 0.83501
# 462/462 [==============================] - 240s 519ms/step - loss: 0.2910 - binary_accuracy: 0.8718 - val_loss: 0.4452 - val_binary_accuracy: 0.8206 - lr: 6.4000e-04

# %%
np.save('history.npy',history.history)

# %%
combined_Model.load_weights(weight_path)

# %%
history1=np.load('/kaggle/working/history.npy',allow_pickle='TRUE').item()

# %%
pred_Y = combined_Model.predict(test_X, 
                          batch_size = 32, 
                          verbose = True)
# Out:
# 44/44 [==============================] - 8s 127ms/step

# %%
plt.matshow(confusion_matrix(test_Y, pred_Y>0.5))
print(classification_report(test_Y, pred_Y>0.5, target_names = ['Healthy', 'Cardiomegaly']))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.85      0.96      0.90      1110
# Cardiomegaly       0.69      0.32      0.44       278
#
#     accuracy                           0.84      1388
#    macro avg       0.77      0.64      0.67      1388
# weighted avg       0.82      0.84      0.81      1388

# %%
plt.plot(history.history['binary_accuracy'])
plt.plot(history.history['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## Test Results

# %%
final_pred_Y = combined_Model.predict(final_test_X, 
                                verbose = True, 
                                batch_size = 4)
# Out:
# 347/347 [==============================] - 12s 33ms/step

# %%
plt.matshow(confusion_matrix(final_test_Y, final_pred_Y>0.5))
print(classification_report(final_test_Y, final_pred_Y>0.5, target_names = ['Healthy', 'Cardiomegaly']))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.86      0.96      0.91      1110
# Cardiomegaly       0.69      0.36      0.47       278
#
#     accuracy                           0.84      1388
#    macro avg       0.78      0.66      0.69      1388
# weighted avg       0.82      0.84      0.82      1388

# %%
def getPerformanceMetrics(real_values,pred_values,format):
    CM = confusion_matrix(real_values,pred_values)
    TN = CM[0][0]
    FN = CM[1][0] 
    TP = CM[1][1]
    FP = CM[0][1]
    Population = TN+FN+TP+FP
    Accuracy   = round( (TP+TN) / Population,4)
    PPV        = round( TP / (TP+FP),4 )
    NPV        = round( TN / (TN+FN),4 )
    Sensitivity= round( TP / (TP+FN),4 )
    Specificity= round( TN / (TN+FP),4 )
    if format==1:
        performance_metrics = pd.DataFrame({'Metric': ['Accuracy','PPV','NPV','Sensitivity','Specificity'],
                                            'Value':[Accuracy,PPV,NPV,Sensitivity,Specificity]})
    else:
        performance_metrics = pd.DataFrame({'Accuracy':[Accuracy],'PPV':[PPV],'NPV':[NPV],'Sensitivity':[Sensitivity],'Specificity':[Specificity]})
        
    return performance_metrics

# %% [markdown]
# ## Validation Metrics

# %%
print(getPerformanceMetrics(test_Y, pred_Y>0.5,2))
# Out:
#    Accuracy     PPV     NPV  Sensitivity  Specificity
# 0     0.835  0.6899  0.8499       0.3201        0.964

# %% [markdown]
# ## Test Metrics

# %%
print(getPerformanceMetrics(final_test_Y,final_pred_Y>0.5,2))
# Out:
#    Accuracy     PPV     NPV  Sensitivity  Specificity
# 0    0.8401  0.6944  0.8569       0.3597       0.9604
