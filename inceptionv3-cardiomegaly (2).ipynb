# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os 
from glob import glob 
import matplotlib.pyplot as plt
import keras
from skimage.util import montage as montage2d
from skimage.io import imread
import seaborn as sns
from keras.optimizers import Adam
import tensorflow as tf
from keras import Input
from keras.models import Model
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.applications import ResNet152V2, InceptionV3, EfficientNetB7, MobileNetV3Small
from keras.layers import Dense, Flatten, Activation, Conv2D, MaxPooling2D, Dropout, Conv2D,MaxPooling2D,GlobalAveragePooling2D,AvgPool2D,multiply, LocallyConnected2D, Lambda, AvgPool2D


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
        

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
base_dir = os.path.join('..', 'input', 'pulmonary-chest-xray-abnormalities')
all_xray_images_dataframe = pd.read_csv('../input/data/Data_Entry_2017.csv')
all_xray_images_dataframe.sample(5)
# Out:
#             Image Index        Finding Labels  Follow-up #  Patient ID  \
# 1066   00000256_000.png          Infiltration            0         256
# 69607  00017151_011.png            No Finding           11       17151
# 58880  00014571_003.png          Infiltration            3       14571
# 55382  00013885_000.png                Nodule            0       13885
# 46178  00011814_021.png  Atelectasis|Effusion           21       11814
#
#        Patient Age Patient Gender View Position  OriginalImage[Width  Height]  \
# 1066            46              F            PA                 2806     2991
# 69607           31              M            PA                 2500     2048
# 58880           78              M            AP                 2500     2048
# 55382           65              F            PA                 2992     2991
# 46178           70              M            PA                 2992     2991
#
#        OriginalImagePixelSpacing[x     y]  Unnamed: 11
# 1066                         0.143  0.143          NaN
# 69607                        0.168  0.168          NaN
# 58880                        0.168  0.168          NaN
# 55382                        0.143  0.143          NaN
# 46178                        0.143  0.143          NaN

# %%
all_xray_images_dataframe['Finding Labels']
# Out:
# 0                   Cardiomegaly
# 1         Cardiomegaly|Emphysema
# 2          Cardiomegaly|Effusion
# 3                     No Finding
# 4                         Hernia
#                    ...
# 112115            Mass|Pneumonia
# 112116                No Finding
# 112117                No Finding
# 112118                No Finding
# 112119                No Finding
# Name: Finding Labels, Length: 112120, dtype: object

# %% [markdown]
# # Preprocessing
# Organize the files by cases with and without cardiomegaly

# %%
all_xray_images_dataframe = pd.read_csv('../input/data/Data_Entry_2017.csv')
all_images_paths = {os.path.basename(x): x for x in 
                   glob(os.path.join('..', 'input', 'data',  'images*', '*', '*.png'))}
print('Scans found:', len(all_images_paths), ', Total Headers', all_xray_images_dataframe.shape[0])
all_xray_images_dataframe['path'] = all_xray_images_dataframe['Image Index'].map(all_images_paths.get)
all_xray_images_dataframe['Cardiomegaly'] = all_xray_images_dataframe['Finding Labels'].map(lambda x: 'Cardiomegaly' in x)
all_xray_images_dataframe['Patient Age'] = np.clip(all_xray_images_dataframe['Patient Age'], 5, 100)
all_xray_images_dataframe['Patient Male'] = all_xray_images_dataframe['Patient Gender'].map(lambda x: x.upper()=='M').astype('float32')
all_xray_images_dataframe.sample(3)
# Out:
# Scans found: 112120 , Total Headers 112120
#              Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 66022   00016308_005.png  Effusion|Mass            5       16308           46
# 79304   00019475_000.png           Mass            0       19475           44
# 102689  00027378_001.png     No Finding            1       27378           45
#
#        Patient Gender View Position  OriginalImage[Width  Height]  \
# 66022               M            AP                 2500     2048
# 79304               M            AP                 2500     2048
# 102689              F            PA                 3056     2544
#
#         OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 66022                         0.168  0.168          NaN
# 79304                         0.168  0.168          NaN
# 102689                        0.139  0.139          NaN
#
#                                                     path  Cardiomegaly  \
# 66022   ../input/data/images_008/images/00016308_005.png         False
# 79304   ../input/data/images_009/images/00019475_000.png         False
# 102689  ../input/data/images_011/images/00027378_001.png         False
#
#         Patient Male
# 66022            1.0
# 79304            1.0
# 102689           0.0

# %% [markdown]
# # Examine the distributions
# Show how the data is distributed and why we need to balance it

# %%
sns.pairplot(all_xray_images_dataframe[['Patient Age', 'Patient Male', 'Cardiomegaly']], hue='Cardiomegaly')

# %% [markdown]
# # Split Data into Training and Validation

# %%
positive_cases = np.sum(all_xray_images_dataframe['Cardiomegaly']==True)//2
oversample_factor = 4 # maximum number of cases in negative group so it isn't super rare
more_balanced_df = all_xray_images_dataframe.groupby(['Patient Gender', 'Cardiomegaly']).apply(lambda x: x.sample(min(oversample_factor*positive_cases, x.shape[0]), 
                                                                                   replace = False)
                                                      ).reset_index(drop = True)

print(more_balanced_df['Cardiomegaly'].value_counts())
sns.pairplot(more_balanced_df[['Patient Age', 'Cardiomegaly']], hue='Cardiomegaly')
# Out:
# False    11104
# True      2776
# Name: Cardiomegaly, dtype: int64

# %%
more_balanced_df
# Out:
#             Image Index                       Finding Labels  Follow-up #  \
# 0      00012158_005.png                           No Finding            5
# 1      00005456_005.png                               Nodule            5
# 2      00022857_007.png                           No Finding            7
# 3      00025303_022.png  Atelectasis|Effusion|Emphysema|Mass           22
# 4      00008112_000.png                      Effusion|Nodule            0
# ...                 ...                                  ...          ...
# 13875  00008129_000.png                         Cardiomegaly            0
# 13876  00005270_007.png                         Cardiomegaly            7
# 13877  00018598_002.png           Cardiomegaly|Effusion|Mass            2
# 13878  00010007_087.png   Cardiomegaly|Effusion|Infiltration           87
# 13879  00011208_001.png                         Cardiomegaly            1
#
#        Patient ID  Patient Age Patient Gender View Position  \
# 0           12158           44              F            AP
# 1            5456           63              F            PA
# 2           22857           37              F            PA
# 3           25303           67              F            AP
# 4            8112           30              F            PA
# ...           ...          ...            ...           ...
# 13875        8129           61              M            PA
# 13876        5270           39              M            PA
# 13877       18598           41              M            AP
# 13878       10007           58              M            AP
# 13879       11208           75              M            PA
#
#        OriginalImage[Width  Height]  OriginalImagePixelSpacing[x        y]  \
# 0                     2500     2048                     0.168000  0.168000
# 1                     2992     2991                     0.143000  0.143000
# 2                     2021     2021                     0.194311  0.194311
# 3                     3056     2544                     0.139000  0.139000
# 4                     2048     2500                     0.168000  0.168000
# ...                    ...      ...                          ...       ...
# 13875                 2500     2048                     0.168000  0.168000
# 13876                 2992     2991                     0.143000  0.143000
# 13877                 2500     2048                     0.168000  0.168000
# 13878                 2500     2048                     0.168000  0.168000
# 13879                 2992     2985                     0.143000  0.143000
#
#        Unnamed: 11                                              path  \
# 0              NaN  ../input/data/images_006/images/00012158_005.png
# 1              NaN  ../input/data/images_003/images/00005456_005.png
# 2              NaN  ../input/data/images_010/images/00022857_007.png
# 3              NaN  ../input/data/images_011/images/00025303_022.png
# 4              NaN  ../input/data/images_004/images/00008112_000.png
# ...            ...                                               ...
# 13875          NaN  ../input/data/images_004/images/00008129_000.png
# 13876          NaN  ../input/data/images_003/images/00005270_007.png
# 13877          NaN  ../input/data/images_009/images/00018598_002.png
# 13878          NaN  ../input/data/images_005/images/00010007_087.png
# 13879          NaN  ../input/data/images_005/images/00011208_001.png
#
#        Cardiomegaly  Patient Male
# 0             False           0.0
# 1             False           0.0
# 2             False           0.0
# 3             False           0.0
# 4             False           0.0
# ...             ...           ...
# 13875          True           1.0
# 13876          True           1.0
# 13877          True           1.0
# 13878          True           1.0
# 13879          True           1.0
#
# [13880 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split
raw_train_df, test_valid_df = train_test_split(more_balanced_df, 
                                   test_size = 0.20, 
                                   random_state = 2018,
                                   stratify = more_balanced_df[['Cardiomegaly', 'Patient Gender']])
valid_df, test_df = train_test_split(test_valid_df, 
                                   test_size = 0.40, 
                                   random_state = 2018,
                                   stratify = test_valid_df[['Cardiomegaly', 'Patient Gender']])
print('train', raw_train_df.shape[0], 'validation', valid_df.shape[0], 'test', test_df.shape[0])
print('train', raw_train_df['Cardiomegaly'].value_counts())
print('test', test_df['Cardiomegaly'].value_counts())
raw_train_df.sample(1)
# Out:
# train 11104 validation 1665 test 1111
# train False    8884
# True     2220
# Name: Cardiomegaly, dtype: int64
# test False    888
# True     223
# Name: Cardiomegaly, dtype: int64
#            Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 3794  00009628_004.png       Effusion            4        9628           68
#
#      Patient Gender View Position  OriginalImage[Width  Height]  \
# 3794              F            AP                 2500     2048
#
#       OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 3794                        0.168  0.168          NaN
#
#                                                   path  Cardiomegaly  \
# 3794  ../input/data/images_005/images/00009628_004.png         False
#
#       Patient Male
# 3794           0.0

# %%
from sklearn.model_selection import train_test_split
raw_train_df, test_valid_df = train_test_split(more_balanced_df, 
                                   test_size = 0.20, 
                                   random_state = 2018,
                                   stratify = more_balanced_df[['Cardiomegaly', 'Patient Gender']])
valid_df, test_df = train_test_split(test_valid_df, 
                                   test_size = 0.50, 
                                   random_state = 2018,
                                   stratify = test_valid_df[['Cardiomegaly', 'Patient Gender']])
print('train', raw_train_df.shape[0], 'validation', valid_df.shape[0], 'test', test_df.shape[0])
print('train', raw_train_df['Cardiomegaly'].value_counts())
print('test', test_df['Cardiomegaly'].value_counts())
raw_train_df.sample(1)
# Out:
# train 11104 validation 1388 test 1388
# train False    8884
# True     2220
# Name: Cardiomegaly, dtype: int64
# test False    1110
# True      278
# Name: Cardiomegaly, dtype: int64
#             Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 11897  00025443_006.png     No Finding            6       25443           45
#
#       Patient Gender View Position  OriginalImage[Width  Height]  \
# 11897              M            PA                 2992     2991
#
#        OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 11897                        0.143  0.143          NaN
#
#                                                    path  Cardiomegaly  \
# 11897  ../input/data/images_011/images/00025443_006.png         False
#
#        Patient Male
# 11897           1.0

# %% [markdown]
# # Balance the distribution in the training set

# %%
train_df = raw_train_df.groupby(['Cardiomegaly']).apply(lambda x: x.sample(2220, replace = True)
                                                      ).reset_index(drop = True)
print('New Data Size:', train_df.shape[0], 'Old Size:', raw_train_df.shape[0])
# Out:
# New Data Size: 4440 Old Size: 11104

# %%
print('train', train_df['Cardiomegaly'].value_counts())
# Out:
# train False    2220
# True     2220
# Name: Cardiomegaly, dtype: int64

# %%
from keras.preprocessing.image import ImageDataGenerator
##from keras.applications.resnet_v2 import ResNet50 as PreTrainedModel, preprocess_input
#from keras.applications.resnet_v2 import ResNet152V2, preprocess_input
from keras.applications.vgg16 import VGG16
from keras.applications.inception_v3 import InceptionV3 as PreTrainedModel, preprocess_input
IMG_SIZE = (299, 299) # size that ResNet152V2 expects
image_data_generator = ImageDataGenerator(samplewise_center=False, 
                              samplewise_std_normalization=False, 
                              horizontal_flip=False, 
                              vertical_flip=False, 
                              height_shift_range=0.1, 
                              width_shift_range=0.1, 
                              brightness_range=[0.7, 1.5],
                              rotation_range=3, 
                              shear_range=0.01,
                              fill_mode='nearest',
                              zoom_range=0.125,
                             preprocessing_function=preprocess_input)

# %%
def flow_from_dataframe(img_data_gen, in_df, path_col, y_col, **dflow_args):
    df_gen = img_data_gen.flow_from_dataframe(in_df,
                                              x_col=path_col,
                                              y_col=y_col,
                                     class_mode = 'raw',
                                    **dflow_args)
    return df_gen

# %%
train_gen = flow_from_dataframe(image_data_generator, train_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 16)

valid_gen = flow_from_dataframe(image_data_generator, valid_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 256) 
test_X, test_Y = next(flow_from_dataframe(image_data_generator, 
                               valid_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 1388)) # one big batch
# used a fixed dataset for final evaluation
final_test_X, final_test_Y = next(flow_from_dataframe(image_data_generator, 
                               test_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 1388)) # one big batch
# Out:
# Found 4440 validated image filenames.
# Found 1388 validated image filenames.
# Found 1388 validated image filenames.
# Found 1388 validated image filenames.

# %%
t_x, t_y = next(train_gen)
t_y
# Out:
# array([ True, False, False,  True,  True, False, False,  True, False,
#         True,  True, False, False,  True, False, False])

# %%
t_x, t_y = next(train_gen)
print(t_x.shape)
print(t_y)
fig, m_axs = plt.subplots(4, 4, figsize = (16, 8))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone', vmin = -127, vmax = 127)
    c_ax.set_title('%s' % ('Cardiomegaly' if c_y else 'Healthy'))
    c_ax.axis('off')
# Out:
# (16, 299, 299, 3)
# [False  True False  True  True False False False False False False False
#  False  True False  True]

# %%
base_pretrained_model = PreTrainedModel(input_shape =  t_x.shape[1:], 
                              include_top = False, weights = 'imagenet')
base_pretrained_model.trainable = False

# %%
base_pretrained_model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_5 (InputLayer)           [(None, 299, 299, 3  0           []
#                                 )]
#
#  conv2d_194 (Conv2D)            (None, 149, 149, 32  864         ['input_5[0][0]']
#                                 )
#
#  batch_normalization_188 (Batch  (None, 149, 149, 32  96         ['conv2d_194[0][0]']
#  Normalization)                 )
#
#  activation_188 (Activation)    (None, 149, 149, 32  0           ['batch_normalization_188[0][0]']
#                                 )
#
#  conv2d_195 (Conv2D)            (None, 147, 147, 32  9216        ['activation_188[0][0]']
#                                 )
#
#  batch_normalization_189 (Batch  (None, 147, 147, 32  96         ['conv2d_195[0][0]']
#  Normalization)                 )
#
#  activation_189 (Activation)    (None, 147, 147, 32  0           ['batch_normalization_189[0][0]']
#                                 )
#
#  conv2d_196 (Conv2D)            (None, 147, 147, 64  18432       ['activation_189[0][0]']
#                                 )
#
#  batch_normalization_190 (Batch  (None, 147, 147, 64  192        ['conv2d_196[0][0]']
#  Normalization)                 )
#
#  activation_190 (Activation)    (None, 147, 147, 64  0           ['batch_normalization_190[0][0]']
#                                 )
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 73, 73, 64)  0           ['activation_190[0][0]']
#
#  conv2d_197 (Conv2D)            (None, 73, 73, 80)   5120        ['max_pooling2d_8[0][0]']
#
#  batch_normalization_191 (Batch  (None, 73, 73, 80)  240         ['conv2d_197[0][0]']
#  Normalization)
#
#  activation_191 (Activation)    (None, 73, 73, 80)   0           ['batch_normalization_191[0][0]']
#
#  conv2d_198 (Conv2D)            (None, 71, 71, 192)  138240      ['activation_191[0][0]']
#
#  batch_normalization_192 (Batch  (None, 71, 71, 192)  576        ['conv2d_198[0][0]']
#  Normalization)
#
#  activation_192 (Activation)    (None, 71, 71, 192)  0           ['batch_normalization_192[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 35, 35, 192)  0          ['activation_192[0][0]']
#
#  conv2d_202 (Conv2D)            (None, 35, 35, 64)   12288       ['max_pooling2d_9[0][0]']
#
#  batch_normalization_196 (Batch  (None, 35, 35, 64)  192         ['conv2d_202[0][0]']
#  Normalization)
#
#  activation_196 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_196[0][0]']
#
#  conv2d_200 (Conv2D)            (None, 35, 35, 48)   9216        ['max_pooling2d_9[0][0]']
#
#  conv2d_203 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_196[0][0]']
#
#  batch_normalization_194 (Batch  (None, 35, 35, 48)  144         ['conv2d_200[0][0]']
#  Normalization)
#
#  batch_normalization_197 (Batch  (None, 35, 35, 96)  288         ['conv2d_203[0][0]']
#  Normalization)
#
#  activation_194 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_194[0][0]']
#
#  activation_197 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_197[0][0]']
#
#  average_pooling2d_20 (AverageP  (None, 35, 35, 192)  0          ['max_pooling2d_9[0][0]']
#  ooling2D)
#
#  conv2d_199 (Conv2D)            (None, 35, 35, 64)   12288       ['max_pooling2d_9[0][0]']
#
#  conv2d_201 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_194[0][0]']
#
#  conv2d_204 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_197[0][0]']
#
#  conv2d_205 (Conv2D)            (None, 35, 35, 32)   6144        ['average_pooling2d_20[0][0]']
#
#  batch_normalization_193 (Batch  (None, 35, 35, 64)  192         ['conv2d_199[0][0]']
#  Normalization)
#
#  batch_normalization_195 (Batch  (None, 35, 35, 64)  192         ['conv2d_201[0][0]']
#  Normalization)
#
#  batch_normalization_198 (Batch  (None, 35, 35, 96)  288         ['conv2d_204[0][0]']
#  Normalization)
#
#  batch_normalization_199 (Batch  (None, 35, 35, 32)  96          ['conv2d_205[0][0]']
#  Normalization)
#
#  activation_193 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_193[0][0]']
#
#  activation_195 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_195[0][0]']
#
#  activation_198 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_198[0][0]']
#
#  activation_199 (Activation)    (None, 35, 35, 32)   0           ['batch_normalization_199[0][0]']
#
#  mixed0 (Concatenate)           (None, 35, 35, 256)  0           ['activation_193[0][0]',
#                                                                   'activation_195[0][0]',
#                                                                   'activation_198[0][0]',
#                                                                   'activation_199[0][0]']
#
#  conv2d_209 (Conv2D)            (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_203 (Batch  (None, 35, 35, 64)  192         ['conv2d_209[0][0]']
#  Normalization)
#
#  activation_203 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_203[0][0]']
#
#  conv2d_207 (Conv2D)            (None, 35, 35, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_210 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_203[0][0]']
#
#  batch_normalization_201 (Batch  (None, 35, 35, 48)  144         ['conv2d_207[0][0]']
#  Normalization)
#
#  batch_normalization_204 (Batch  (None, 35, 35, 96)  288         ['conv2d_210[0][0]']
#  Normalization)
#
#  activation_201 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_201[0][0]']
#
#  activation_204 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_204[0][0]']
#
#  average_pooling2d_21 (AverageP  (None, 35, 35, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_206 (Conv2D)            (None, 35, 35, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_208 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_201[0][0]']
#
#  conv2d_211 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_204[0][0]']
#
#  conv2d_212 (Conv2D)            (None, 35, 35, 64)   16384       ['average_pooling2d_21[0][0]']
#
#  batch_normalization_200 (Batch  (None, 35, 35, 64)  192         ['conv2d_206[0][0]']
#  Normalization)
#
#  batch_normalization_202 (Batch  (None, 35, 35, 64)  192         ['conv2d_208[0][0]']
#  Normalization)
#
#  batch_normalization_205 (Batch  (None, 35, 35, 96)  288         ['conv2d_211[0][0]']
#  Normalization)
#
#  batch_normalization_206 (Batch  (None, 35, 35, 64)  192         ['conv2d_212[0][0]']
#  Normalization)
#
#  activation_200 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_200[0][0]']
#
#  activation_202 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_202[0][0]']
#
#  activation_205 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_205[0][0]']
#
#  activation_206 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_206[0][0]']
#
#  mixed1 (Concatenate)           (None, 35, 35, 288)  0           ['activation_200[0][0]',
#                                                                   'activation_202[0][0]',
#                                                                   'activation_205[0][0]',
#                                                                   'activation_206[0][0]']
#
#  conv2d_216 (Conv2D)            (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_210 (Batch  (None, 35, 35, 64)  192         ['conv2d_216[0][0]']
#  Normalization)
#
#  activation_210 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_210[0][0]']
#
#  conv2d_214 (Conv2D)            (None, 35, 35, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_217 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_210[0][0]']
#
#  batch_normalization_208 (Batch  (None, 35, 35, 48)  144         ['conv2d_214[0][0]']
#  Normalization)
#
#  batch_normalization_211 (Batch  (None, 35, 35, 96)  288         ['conv2d_217[0][0]']
#  Normalization)
#
#  activation_208 (Activation)    (None, 35, 35, 48)   0           ['batch_normalization_208[0][0]']
#
#  activation_211 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_211[0][0]']
#
#  average_pooling2d_22 (AverageP  (None, 35, 35, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_213 (Conv2D)            (None, 35, 35, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_215 (Conv2D)            (None, 35, 35, 64)   76800       ['activation_208[0][0]']
#
#  conv2d_218 (Conv2D)            (None, 35, 35, 96)   82944       ['activation_211[0][0]']
#
#  conv2d_219 (Conv2D)            (None, 35, 35, 64)   18432       ['average_pooling2d_22[0][0]']
#
#  batch_normalization_207 (Batch  (None, 35, 35, 64)  192         ['conv2d_213[0][0]']
#  Normalization)
#
#  batch_normalization_209 (Batch  (None, 35, 35, 64)  192         ['conv2d_215[0][0]']
#  Normalization)
#
#  batch_normalization_212 (Batch  (None, 35, 35, 96)  288         ['conv2d_218[0][0]']
#  Normalization)
#
#  batch_normalization_213 (Batch  (None, 35, 35, 64)  192         ['conv2d_219[0][0]']
#  Normalization)
#
#  activation_207 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_207[0][0]']
#
#  activation_209 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_209[0][0]']
#
#  activation_212 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_212[0][0]']
#
#  activation_213 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_213[0][0]']
#
#  mixed2 (Concatenate)           (None, 35, 35, 288)  0           ['activation_207[0][0]',
#                                                                   'activation_209[0][0]',
#                                                                   'activation_212[0][0]',
#                                                                   'activation_213[0][0]']
#
#  conv2d_221 (Conv2D)            (None, 35, 35, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_215 (Batch  (None, 35, 35, 64)  192         ['conv2d_221[0][0]']
#  Normalization)
#
#  activation_215 (Activation)    (None, 35, 35, 64)   0           ['batch_normalization_215[0][0]']
#
#  conv2d_222 (Conv2D)            (None, 35, 35, 96)   55296       ['activation_215[0][0]']
#
#  batch_normalization_216 (Batch  (None, 35, 35, 96)  288         ['conv2d_222[0][0]']
#  Normalization)
#
#  activation_216 (Activation)    (None, 35, 35, 96)   0           ['batch_normalization_216[0][0]']
#
#  conv2d_220 (Conv2D)            (None, 17, 17, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_223 (Conv2D)            (None, 17, 17, 96)   82944       ['activation_216[0][0]']
#
#  batch_normalization_214 (Batch  (None, 17, 17, 384)  1152       ['conv2d_220[0][0]']
#  Normalization)
#
#  batch_normalization_217 (Batch  (None, 17, 17, 96)  288         ['conv2d_223[0][0]']
#  Normalization)
#
#  activation_214 (Activation)    (None, 17, 17, 384)  0           ['batch_normalization_214[0][0]']
#
#  activation_217 (Activation)    (None, 17, 17, 96)   0           ['batch_normalization_217[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 17, 17, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 17, 17, 768)  0           ['activation_214[0][0]',
#                                                                   'activation_217[0][0]',
#                                                                   'max_pooling2d_10[0][0]']
#
#  conv2d_228 (Conv2D)            (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_222 (Batch  (None, 17, 17, 128)  384        ['conv2d_228[0][0]']
#  Normalization)
#
#  activation_222 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_222[0][0]']
#
#  conv2d_229 (Conv2D)            (None, 17, 17, 128)  114688      ['activation_222[0][0]']
#
#  batch_normalization_223 (Batch  (None, 17, 17, 128)  384        ['conv2d_229[0][0]']
#  Normalization)
#
#  activation_223 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_223[0][0]']
#
#  conv2d_225 (Conv2D)            (None, 17, 17, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_230 (Conv2D)            (None, 17, 17, 128)  114688      ['activation_223[0][0]']
#
#  batch_normalization_219 (Batch  (None, 17, 17, 128)  384        ['conv2d_225[0][0]']
#  Normalization)
#
#  batch_normalization_224 (Batch  (None, 17, 17, 128)  384        ['conv2d_230[0][0]']
#  Normalization)
#
#  activation_219 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_219[0][0]']
#
#  activation_224 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_224[0][0]']
#
#  conv2d_226 (Conv2D)            (None, 17, 17, 128)  114688      ['activation_219[0][0]']
#
#  conv2d_231 (Conv2D)            (None, 17, 17, 128)  114688      ['activation_224[0][0]']
#
#  batch_normalization_220 (Batch  (None, 17, 17, 128)  384        ['conv2d_226[0][0]']
#  Normalization)
#
#  batch_normalization_225 (Batch  (None, 17, 17, 128)  384        ['conv2d_231[0][0]']
#  Normalization)
#
#  activation_220 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_220[0][0]']
#
#  activation_225 (Activation)    (None, 17, 17, 128)  0           ['batch_normalization_225[0][0]']
#
#  average_pooling2d_23 (AverageP  (None, 17, 17, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_224 (Conv2D)            (None, 17, 17, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_227 (Conv2D)            (None, 17, 17, 192)  172032      ['activation_220[0][0]']
#
#  conv2d_232 (Conv2D)            (None, 17, 17, 192)  172032      ['activation_225[0][0]']
#
#  conv2d_233 (Conv2D)            (None, 17, 17, 192)  147456      ['average_pooling2d_23[0][0]']
#
#  batch_normalization_218 (Batch  (None, 17, 17, 192)  576        ['conv2d_224[0][0]']
#  Normalization)
#
#  batch_normalization_221 (Batch  (None, 17, 17, 192)  576        ['conv2d_227[0][0]']
#  Normalization)
#
#  batch_normalization_226 (Batch  (None, 17, 17, 192)  576        ['conv2d_232[0][0]']
#  Normalization)
#
#  batch_normalization_227 (Batch  (None, 17, 17, 192)  576        ['conv2d_233[0][0]']
#  Normalization)
#
#  activation_218 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_218[0][0]']
#
#  activation_221 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_221[0][0]']
#
#  activation_226 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_226[0][0]']
#
#  activation_227 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_227[0][0]']
#
#  mixed4 (Concatenate)           (None, 17, 17, 768)  0           ['activation_218[0][0]',
#                                                                   'activation_221[0][0]',
#                                                                   'activation_226[0][0]',
#                                                                   'activation_227[0][0]']
#
#  conv2d_238 (Conv2D)            (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_232 (Batch  (None, 17, 17, 160)  480        ['conv2d_238[0][0]']
#  Normalization)
#
#  activation_232 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_232[0][0]']
#
#  conv2d_239 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_232[0][0]']
#
#  batch_normalization_233 (Batch  (None, 17, 17, 160)  480        ['conv2d_239[0][0]']
#  Normalization)
#
#  activation_233 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_233[0][0]']
#
#  conv2d_235 (Conv2D)            (None, 17, 17, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_240 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_233[0][0]']
#
#  batch_normalization_229 (Batch  (None, 17, 17, 160)  480        ['conv2d_235[0][0]']
#  Normalization)
#
#  batch_normalization_234 (Batch  (None, 17, 17, 160)  480        ['conv2d_240[0][0]']
#  Normalization)
#
#  activation_229 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_229[0][0]']
#
#  activation_234 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_234[0][0]']
#
#  conv2d_236 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_229[0][0]']
#
#  conv2d_241 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_234[0][0]']
#
#  batch_normalization_230 (Batch  (None, 17, 17, 160)  480        ['conv2d_236[0][0]']
#  Normalization)
#
#  batch_normalization_235 (Batch  (None, 17, 17, 160)  480        ['conv2d_241[0][0]']
#  Normalization)
#
#  activation_230 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_230[0][0]']
#
#  activation_235 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_235[0][0]']
#
#  average_pooling2d_24 (AverageP  (None, 17, 17, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_234 (Conv2D)            (None, 17, 17, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_237 (Conv2D)            (None, 17, 17, 192)  215040      ['activation_230[0][0]']
#
#  conv2d_242 (Conv2D)            (None, 17, 17, 192)  215040      ['activation_235[0][0]']
#
#  conv2d_243 (Conv2D)            (None, 17, 17, 192)  147456      ['average_pooling2d_24[0][0]']
#
#  batch_normalization_228 (Batch  (None, 17, 17, 192)  576        ['conv2d_234[0][0]']
#  Normalization)
#
#  batch_normalization_231 (Batch  (None, 17, 17, 192)  576        ['conv2d_237[0][0]']
#  Normalization)
#
#  batch_normalization_236 (Batch  (None, 17, 17, 192)  576        ['conv2d_242[0][0]']
#  Normalization)
#
#  batch_normalization_237 (Batch  (None, 17, 17, 192)  576        ['conv2d_243[0][0]']
#  Normalization)
#
#  activation_228 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_228[0][0]']
#
#  activation_231 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_231[0][0]']
#
#  activation_236 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_236[0][0]']
#
#  activation_237 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_237[0][0]']
#
#  mixed5 (Concatenate)           (None, 17, 17, 768)  0           ['activation_228[0][0]',
#                                                                   'activation_231[0][0]',
#                                                                   'activation_236[0][0]',
#                                                                   'activation_237[0][0]']
#
#  conv2d_248 (Conv2D)            (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_242 (Batch  (None, 17, 17, 160)  480        ['conv2d_248[0][0]']
#  Normalization)
#
#  activation_242 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_242[0][0]']
#
#  conv2d_249 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_242[0][0]']
#
#  batch_normalization_243 (Batch  (None, 17, 17, 160)  480        ['conv2d_249[0][0]']
#  Normalization)
#
#  activation_243 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_243[0][0]']
#
#  conv2d_245 (Conv2D)            (None, 17, 17, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_250 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_243[0][0]']
#
#  batch_normalization_239 (Batch  (None, 17, 17, 160)  480        ['conv2d_245[0][0]']
#  Normalization)
#
#  batch_normalization_244 (Batch  (None, 17, 17, 160)  480        ['conv2d_250[0][0]']
#  Normalization)
#
#  activation_239 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_239[0][0]']
#
#  activation_244 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_244[0][0]']
#
#  conv2d_246 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_239[0][0]']
#
#  conv2d_251 (Conv2D)            (None, 17, 17, 160)  179200      ['activation_244[0][0]']
#
#  batch_normalization_240 (Batch  (None, 17, 17, 160)  480        ['conv2d_246[0][0]']
#  Normalization)
#
#  batch_normalization_245 (Batch  (None, 17, 17, 160)  480        ['conv2d_251[0][0]']
#  Normalization)
#
#  activation_240 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_240[0][0]']
#
#  activation_245 (Activation)    (None, 17, 17, 160)  0           ['batch_normalization_245[0][0]']
#
#  average_pooling2d_25 (AverageP  (None, 17, 17, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_244 (Conv2D)            (None, 17, 17, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_247 (Conv2D)            (None, 17, 17, 192)  215040      ['activation_240[0][0]']
#
#  conv2d_252 (Conv2D)            (None, 17, 17, 192)  215040      ['activation_245[0][0]']
#
#  conv2d_253 (Conv2D)            (None, 17, 17, 192)  147456      ['average_pooling2d_25[0][0]']
#
#  batch_normalization_238 (Batch  (None, 17, 17, 192)  576        ['conv2d_244[0][0]']
#  Normalization)
#
#  batch_normalization_241 (Batch  (None, 17, 17, 192)  576        ['conv2d_247[0][0]']
#  Normalization)
#
#  batch_normalization_246 (Batch  (None, 17, 17, 192)  576        ['conv2d_252[0][0]']
#  Normalization)
#
#  batch_normalization_247 (Batch  (None, 17, 17, 192)  576        ['conv2d_253[0][0]']
#  Normalization)
#
#  activation_238 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_238[0][0]']
#
#  activation_241 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_241[0][0]']
#
#  activation_246 (Activation)    (None, 17, 17, 192)  0           ['batch_normalization_246[0][0]']
#
# ...
#  mixed8 (Concatenate)           (None, 8, 8, 1280)   0           ['activation_259[0][0]',
#                                                                   'activation_263[0][0]',
#                                                                   'max_pooling2d_11[0][0]']
#
#  conv2d_274 (Conv2D)            (None, 8, 8, 448)    573440      ['mixed8[0][0]']
#
#  batch_normalization_268 (Batch  (None, 8, 8, 448)   1344        ['conv2d_274[0][0]']
#  Normalization)
#
#  activation_268 (Activation)    (None, 8, 8, 448)    0           ['batch_normalization_268[0][0]']
#
#  conv2d_271 (Conv2D)            (None, 8, 8, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_275 (Conv2D)            (None, 8, 8, 384)    1548288     ['activation_268[0][0]']
#
#  batch_normalization_265 (Batch  (None, 8, 8, 384)   1152        ['conv2d_271[0][0]']
#  Normalization)
#
#  batch_normalization_269 (Batch  (None, 8, 8, 384)   1152        ['conv2d_275[0][0]']
#  Normalization)
#
#  activation_265 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_265[0][0]']
#
#  activation_269 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_269[0][0]']
#
#  conv2d_272 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_265[0][0]']
#
#  conv2d_273 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_265[0][0]']
#
#  conv2d_276 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_269[0][0]']
#
#  conv2d_277 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_269[0][0]']
#
#  average_pooling2d_27 (AverageP  (None, 8, 8, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_270 (Conv2D)            (None, 8, 8, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_266 (Batch  (None, 8, 8, 384)   1152        ['conv2d_272[0][0]']
#  Normalization)
#
#  batch_normalization_267 (Batch  (None, 8, 8, 384)   1152        ['conv2d_273[0][0]']
#  Normalization)
#
#  batch_normalization_270 (Batch  (None, 8, 8, 384)   1152        ['conv2d_276[0][0]']
#  Normalization)
#
#  batch_normalization_271 (Batch  (None, 8, 8, 384)   1152        ['conv2d_277[0][0]']
#  Normalization)
#
#  conv2d_278 (Conv2D)            (None, 8, 8, 192)    245760      ['average_pooling2d_27[0][0]']
#
#  batch_normalization_264 (Batch  (None, 8, 8, 320)   960         ['conv2d_270[0][0]']
#  Normalization)
#
#  activation_266 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_266[0][0]']
#
#  activation_267 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_267[0][0]']
#
#  activation_270 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_270[0][0]']
#
#  activation_271 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_271[0][0]']
#
#  batch_normalization_272 (Batch  (None, 8, 8, 192)   576         ['conv2d_278[0][0]']
#  Normalization)
#
#  activation_264 (Activation)    (None, 8, 8, 320)    0           ['batch_normalization_264[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 8, 8, 768)    0           ['activation_266[0][0]',
#                                                                   'activation_267[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 8, 8, 768)    0           ['activation_270[0][0]',
#                                                                   'activation_271[0][0]']
#
#  activation_272 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_272[0][0]']
#
#  mixed9 (Concatenate)           (None, 8, 8, 2048)   0           ['activation_264[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_4[0][0]',
#                                                                   'activation_272[0][0]']
#
#  conv2d_283 (Conv2D)            (None, 8, 8, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_277 (Batch  (None, 8, 8, 448)   1344        ['conv2d_283[0][0]']
#  Normalization)
#
#  activation_277 (Activation)    (None, 8, 8, 448)    0           ['batch_normalization_277[0][0]']
#
#  conv2d_280 (Conv2D)            (None, 8, 8, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_284 (Conv2D)            (None, 8, 8, 384)    1548288     ['activation_277[0][0]']
#
#  batch_normalization_274 (Batch  (None, 8, 8, 384)   1152        ['conv2d_280[0][0]']
#  Normalization)
#
#  batch_normalization_278 (Batch  (None, 8, 8, 384)   1152        ['conv2d_284[0][0]']
#  Normalization)
#
#  activation_274 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_274[0][0]']
#
#  activation_278 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_278[0][0]']
#
#  conv2d_281 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_274[0][0]']
#
#  conv2d_282 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_274[0][0]']
#
#  conv2d_285 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_278[0][0]']
#
#  conv2d_286 (Conv2D)            (None, 8, 8, 384)    442368      ['activation_278[0][0]']
#
#  average_pooling2d_28 (AverageP  (None, 8, 8, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_279 (Conv2D)            (None, 8, 8, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_275 (Batch  (None, 8, 8, 384)   1152        ['conv2d_281[0][0]']
#  Normalization)
#
#  batch_normalization_276 (Batch  (None, 8, 8, 384)   1152        ['conv2d_282[0][0]']
#  Normalization)
#
#  batch_normalization_279 (Batch  (None, 8, 8, 384)   1152        ['conv2d_285[0][0]']
#  Normalization)
#
#  batch_normalization_280 (Batch  (None, 8, 8, 384)   1152        ['conv2d_286[0][0]']
#  Normalization)
#
#  conv2d_287 (Conv2D)            (None, 8, 8, 192)    393216      ['average_pooling2d_28[0][0]']
#
#  batch_normalization_273 (Batch  (None, 8, 8, 320)   960         ['conv2d_279[0][0]']
#  Normalization)
#
#  activation_275 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_275[0][0]']
#
#  activation_276 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_276[0][0]']
#
#  activation_279 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_279[0][0]']
#
#  activation_280 (Activation)    (None, 8, 8, 384)    0           ['batch_normalization_280[0][0]']
#
#  batch_normalization_281 (Batch  (None, 8, 8, 192)   576         ['conv2d_287[0][0]']
#  Normalization)
#
#  activation_273 (Activation)    (None, 8, 8, 320)    0           ['batch_normalization_273[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 8, 8, 768)    0           ['activation_275[0][0]',
#                                                                   'activation_276[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 8, 8, 768)    0           ['activation_279[0][0]',
#                                                                   'activation_280[0][0]']
#
#  activation_281 (Activation)    (None, 8, 8, 192)    0           ['batch_normalization_281[0][0]']
#
#  mixed10 (Concatenate)          (None, 8, 8, 2048)   0           ['activation_273[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_5[0][0]',
#                                                                   'activation_281[0][0]']
#
# ==================================================================================================
# Total params: 21,802,784
# Trainable params: 0
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %%
model = keras.models.Sequential()
model.add(base_pretrained_model)
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(100, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(optimizer = Adam(learning_rate = 1e-3), loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy'])
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  flatten_2 (Flatten)         (None, 131072)            0
#
#  dropout_8 (Dropout)         (None, 131072)            0
#
#  dense_10 (Dense)            (None, 100)               13107300
#
#  dropout_9 (Dropout)         (None, 100)               0
#
#  dense_11 (Dense)            (None, 10)                1010
#
#  dense_12 (Dense)            (None, 1)                 11
#
# =================================================================
# Total params: 34,911,105
# Trainable params: 13,108,321
# Non-trainable params: 21,802,784
# _________________________________________________________________

# %%
from keras.utils.vis_utils import model_to_dot
from IPython.display import Image
Image(model_to_dot(model, show_shapes=True).create_png())

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cardio_attn_test_valid')

modelCheckPoint = ModelCheckpoint(weight_path, monitor='val_binary_accuracy', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)


reduceLROnPlateau = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=10, verbose=1, mode='auto', epsilon=0.0001, cooldown=5, min_lr=0.0001)
early = EarlyStopping(monitor="val_binary_accuracy", 
                      mode="max", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [modelCheckPoint, early, reduceLROnPlateau]

# %% [markdown]
# # No improvement in learning

# %% [markdown]
# ## Attention Model

# %% [markdown]
# The basic idea is that a Global Average Pooling is too simplistic since some of the regions are more relevant than others. So we build an attention mechanism to turn pixels in the GAP on an off before the pooling and then rescale (Lambda layer) the results based on the number of pixels. The model could be seen as a sort of 'global weighted average' pooling. There is probably something published about it and it is very similar to the kind of attention models used in NLP. It is largely based on the insight that the winning solution annotated and trained a UNET model to segmenting the hand and transforming it. This seems very tedious if we could just learn attention.

# %% [markdown]
# ## Basic Preprocessing
# Here we take the output of the pretrained model and apply BatchNormalization

# %%
t_x.shape[1:]
# Out:
# (299, 299, 3)

# %%
base_pretrained_model(tf.keras.Input(t_x.shape[1:]))
# Out:
# <KerasTensor: shape=(None, 8, 8, 2048) dtype=float32 (created by layer 'inception_v3')>

# %%
pretrained_features = Input(base_pretrained_model.get_output_shape_at(0)[1:], name = 'feature_input')
pretrained_depth = base_pretrained_model.get_output_shape_at(0)[-1]
from keras.layers import BatchNormalization
batchNormalised_features = BatchNormalization(name='Features_BN')(pretrained_features)

# %%
attention_layer = Conv2D(128, kernel_size = (1,1), padding = 'same', activation = 'elu')(batchNormalised_features)
attention_layer = Conv2D(32, kernel_size = (1,1), padding = 'same', activation = 'elu')(attention_layer)
attention_layer = Conv2D(16, kernel_size = (1,1), padding = 'same', activation = 'elu')(attention_layer)
attention_layer = AvgPool2D((2,2), strides = (1,1), padding = 'same')(attention_layer) # smooth results
attention_layer = Conv2D(1, 
                    kernel_size = (1,1), 
                    padding = 'valid', 
                    activation = 'sigmoid',
                   name='AttentionMap2D')(attention_layer)

# %% [markdown]
# ## Rescale Attention
# We rescale the feature dimension back out to the original number of features (instead of just 1) by using a hard-coded convolution.

# %%
up_c2_w = np.ones((1, 1, 1, pretrained_depth))
up_c2 = Conv2D(pretrained_depth, kernel_size = (1,1), padding = 'same', name='UpscaleAttention',
               activation = 'linear', use_bias = False, weights = [up_c2_w])
up_c2.trainable = False
attention_layer = up_c2(attention_layer)

# %% [markdown]
# # Global Weighted Average Pooling
# We now want to use the attention layer to weight the regions we want during the average pooling. A standard average pooling layer is poorly suited to this task since many of the values (presumably) will be zero and they will be counted. So we hand-rig a 'weighted average pooling' where we multiply the attention by the features and then divide by the sum of the attention
# The formula for weighted average from [Wikipedia](https://en.wikipedia.org/wiki/Weighted_arithmetic_mean)
# $$ \bar{x} = \frac{ \sum\limits_{i=1}^n w_i x_i}{\sum\limits_{i=1}^n w_i} $$
# What we do is
# $$ \text{GWAP}(x, y, d) = \frac{ \sum\limits_{x}\sum\limits_{y} \text{Attention}(x,y,d) \text{Feature}(x,y,d)} {\sum\limits_{x}\sum\limits_{y} \text{Attention}(x,y,d)} $$

# %%
mask_features = multiply([attention_layer, batchNormalised_features])
gap_features = GlobalAveragePooling2D()(mask_features)
gap_mask = GlobalAveragePooling2D()(attention_layer)
# to account for missing values from the attention model
gap = Lambda(lambda x: x[0]/x[1], name = 'RescaleGAP')([gap_features, gap_mask])

# %% [markdown]
# ## Dropout and Classification
# We know take the output of this global weighted-average pooling and go to a classification with dropout and two fully connected layers

# %%
gap_dr = Dropout(0.5)(gap)
dr_steps = Dropout(0.5)(Dense(128, activation = 'elu')(gap_dr))
out_layer = Dense(1, activation = 'sigmoid')(dr_steps)

attention_model = Model(inputs = [pretrained_features], outputs = [out_layer], name = 'attention_model')

attention_model.compile(optimizer = 'adam', loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy'])

attention_model.summary()
# Out:
# Model: "attention_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  feature_input (InputLayer)     [(None, 8, 8, 2048)  0           []
#                                 ]
#
#  Features_BN (BatchNormalizatio  (None, 8, 8, 2048)  8192        ['feature_input[0][0]']
#  n)
#
#  conv2d_94 (Conv2D)             (None, 8, 8, 128)    262272      ['Features_BN[0][0]']
#
#  conv2d_95 (Conv2D)             (None, 8, 8, 32)     4128        ['conv2d_94[0][0]']
#
#  conv2d_96 (Conv2D)             (None, 8, 8, 16)     528         ['conv2d_95[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 8, 8, 16)    0           ['conv2d_96[0][0]']
#  oling2D)
#
#  AttentionMap2D (Conv2D)        (None, 8, 8, 1)      17          ['average_pooling2d_9[0][0]']
#
#  UpscaleAttention (Conv2D)      (None, 8, 8, 2048)   2048        ['AttentionMap2D[0][0]']
#
#  multiply (Multiply)            (None, 8, 8, 2048)   0           ['UpscaleAttention[0][0]',
#                                                                   'Features_BN[0][0]']
#
#  global_average_pooling2d (Glob  (None, 2048)        0           ['multiply[0][0]']
#  alAveragePooling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 2048)        0           ['UpscaleAttention[0][0]']
#  obalAveragePooling2D)
#
#  RescaleGAP (Lambda)            (None, 2048)         0           ['global_average_pooling2d[0][0]'
#                                                                  , 'global_average_pooling2d_1[0][
#                                                                  0]']
#
#  dropout (Dropout)              (None, 2048)         0           ['RescaleGAP[0][0]']
#
#  dense (Dense)                  (None, 128)          262272      ['dropout[0][0]']
#
#  dropout_1 (Dropout)            (None, 128)          0           ['dense[0][0]']
#
#  dense_1 (Dense)                (None, 1)            129         ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 539,586
# Trainable params: 533,442
# Non-trainable params: 6,144
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model Architecture
# We can show the whole model below

# %%
from keras.utils.vis_utils import model_to_dot
from IPython.display import Image
Image(model_to_dot(attention_model, show_shapes=True).create_png())

# %% [markdown]
# ## Build the whole model
# We build the whole model and fine-tune the results (much lower learning rate)

# %%
from keras.models import Sequential
from keras.optimizers import Adam
combined_Model = Sequential(name = 'combined_model')
base_pretrained_model.trainable = False
combined_Model.add(base_pretrained_model)
combined_Model.add(attention_model)
combined_Model.compile(optimizer = Adam(learning_rate = 1e-3), loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy'])
combined_Model.summary()
# Out:
# Model: "combined_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 8, 8, 2048)        21802784
#
#  attention_model (Functional  (None, 1)                539586
#  )
#
# =================================================================
# Total params: 22,342,370
# Trainable params: 533,442
# Non-trainable params: 21,808,928
# _________________________________________________________________

# %% [markdown]
# # Image Size & training set manipulation to see if it has any effect

# %%
train_gen.batch_size = 24
history = combined_Model.fit_generator(train_gen, 
                      validation_data = (test_X, test_Y), 
                       steps_per_epoch=train_gen.n//train_gen.batch_size,
                      epochs = 100, 
                      callbacks = callbacks_list,
                      workers = 3)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/100
# 185/185 [==============================] - ETA: 0s - loss: 0.7544 - binary_accuracy: 0.5980
# Epoch 1: val_binary_accuracy improved from -inf to 0.64841, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 142s 731ms/step - loss: 0.7544 - binary_accuracy: 0.5980 - val_loss: 0.6053 - val_binary_accuracy: 0.6484 - lr: 0.0010
# Epoch 2/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6631 - binary_accuracy: 0.6381
# Epoch 2: val_binary_accuracy did not improve from 0.64841
# 185/185 [==============================] - 125s 673ms/step - loss: 0.6631 - binary_accuracy: 0.6381 - val_loss: 0.6917 - val_binary_accuracy: 0.6088 - lr: 0.0010
# Epoch 3/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6224 - binary_accuracy: 0.6700
# Epoch 3: val_binary_accuracy did not improve from 0.64841
# 185/185 [==============================] - 127s 673ms/step - loss: 0.6224 - binary_accuracy: 0.6700 - val_loss: 0.6183 - val_binary_accuracy: 0.6463 - lr: 0.0010
# Epoch 4/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6067 - binary_accuracy: 0.6714
# Epoch 4: val_binary_accuracy did not improve from 0.64841
# 185/185 [==============================] - 125s 664ms/step - loss: 0.6067 - binary_accuracy: 0.6714 - val_loss: 0.6208 - val_binary_accuracy: 0.6419 - lr: 0.0010
# Epoch 5/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5956 - binary_accuracy: 0.6766
# Epoch 5: val_binary_accuracy improved from 0.64841 to 0.68588, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 126s 675ms/step - loss: 0.5956 - binary_accuracy: 0.6766 - val_loss: 0.5637 - val_binary_accuracy: 0.6859 - lr: 0.0010
# Epoch 6/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5784 - binary_accuracy: 0.6966
# Epoch 6: val_binary_accuracy did not improve from 0.68588
# 185/185 [==============================] - 129s 685ms/step - loss: 0.5784 - binary_accuracy: 0.6966 - val_loss: 0.5785 - val_binary_accuracy: 0.6859 - lr: 0.0010
# Epoch 7/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5648 - binary_accuracy: 0.7016
# Epoch 7: val_binary_accuracy improved from 0.68588 to 0.70173, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 127s 680ms/step - loss: 0.5648 - binary_accuracy: 0.7016 - val_loss: 0.5522 - val_binary_accuracy: 0.7017 - lr: 0.0010
# Epoch 8/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5559 - binary_accuracy: 0.7077
# Epoch 8: val_binary_accuracy improved from 0.70173 to 0.71830, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 128s 688ms/step - loss: 0.5559 - binary_accuracy: 0.7077 - val_loss: 0.5395 - val_binary_accuracy: 0.7183 - lr: 0.0010
# Epoch 9/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5455 - binary_accuracy: 0.7176
# Epoch 9: val_binary_accuracy did not improve from 0.71830
# 185/185 [==============================] - 128s 684ms/step - loss: 0.5455 - binary_accuracy: 0.7176 - val_loss: 0.5544 - val_binary_accuracy: 0.6996 - lr: 0.0010
# Epoch 10/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5377 - binary_accuracy: 0.7241
# Epoch 10: val_binary_accuracy did not improve from 0.71830
# 185/185 [==============================] - 127s 680ms/step - loss: 0.5377 - binary_accuracy: 0.7241 - val_loss: 0.6146 - val_binary_accuracy: 0.6376 - lr: 0.0010
# Epoch 11/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5367 - binary_accuracy: 0.7273
# Epoch 11: val_binary_accuracy did not improve from 0.71830
# 185/185 [==============================] - 126s 676ms/step - loss: 0.5367 - binary_accuracy: 0.7273 - val_loss: 0.5804 - val_binary_accuracy: 0.6967 - lr: 0.0010
# Epoch 12/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5329 - binary_accuracy: 0.7313
# Epoch 12: val_binary_accuracy did not improve from 0.71830
# 185/185 [==============================] - 126s 675ms/step - loss: 0.5329 - binary_accuracy: 0.7313 - val_loss: 0.5829 - val_binary_accuracy: 0.6888 - lr: 0.0010
# Epoch 13/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5176 - binary_accuracy: 0.7342
# Epoch 13: val_binary_accuracy did not improve from 0.71830
# 185/185 [==============================] - 125s 670ms/step - loss: 0.5176 - binary_accuracy: 0.7342 - val_loss: 0.6039 - val_binary_accuracy: 0.6571 - lr: 0.0010
# Epoch 14/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5212 - binary_accuracy: 0.7367
# Epoch 14: val_binary_accuracy did not improve from 0.71830
# 185/185 [==============================] - 125s 670ms/step - loss: 0.5212 - binary_accuracy: 0.7367 - val_loss: 0.6018 - val_binary_accuracy: 0.6628 - lr: 0.0010
# Epoch 15/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5071 - binary_accuracy: 0.7550
# Epoch 15: val_binary_accuracy improved from 0.71830 to 0.73775, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 124s 665ms/step - loss: 0.5071 - binary_accuracy: 0.7550 - val_loss: 0.5232 - val_binary_accuracy: 0.7378 - lr: 0.0010
# Epoch 16/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5008 - binary_accuracy: 0.7572
# Epoch 16: val_binary_accuracy did not improve from 0.73775
# 185/185 [==============================] - 124s 656ms/step - loss: 0.5008 - binary_accuracy: 0.7572 - val_loss: 0.6166 - val_binary_accuracy: 0.6780 - lr: 0.0010
# Epoch 17/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4877 - binary_accuracy: 0.7592
# Epoch 17: val_binary_accuracy did not improve from 0.73775
# 185/185 [==============================] - 125s 668ms/step - loss: 0.4877 - binary_accuracy: 0.7592 - val_loss: 0.5725 - val_binary_accuracy: 0.7111 - lr: 0.0010
# Epoch 18/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4889 - binary_accuracy: 0.7586
# Epoch 18: val_binary_accuracy did not improve from 0.73775
# 185/185 [==============================] - 125s 669ms/step - loss: 0.4889 - binary_accuracy: 0.7586 - val_loss: 0.5381 - val_binary_accuracy: 0.7233 - lr: 0.0010
# Epoch 19/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4829 - binary_accuracy: 0.7631
# Epoch 19: val_binary_accuracy did not improve from 0.73775
# 185/185 [==============================] - 123s 658ms/step - loss: 0.4829 - binary_accuracy: 0.7631 - val_loss: 0.5682 - val_binary_accuracy: 0.6981 - lr: 0.0010
# Epoch 20/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4679 - binary_accuracy: 0.7694
# Epoch 20: val_binary_accuracy did not improve from 0.73775
# 185/185 [==============================] - 127s 676ms/step - loss: 0.4679 - binary_accuracy: 0.7694 - val_loss: 0.5837 - val_binary_accuracy: 0.7161 - lr: 0.0010
# Epoch 21/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4637 - binary_accuracy: 0.7777
# Epoch 21: val_binary_accuracy did not improve from 0.73775
# 185/185 [==============================] - 123s 658ms/step - loss: 0.4637 - binary_accuracy: 0.7777 - val_loss: 0.5319 - val_binary_accuracy: 0.7197 - lr: 0.0010
# Epoch 22/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4585 - binary_accuracy: 0.7791
# Epoch 22: val_binary_accuracy did not improve from 0.73775
# 185/185 [==============================] - 124s 664ms/step - loss: 0.4585 - binary_accuracy: 0.7791 - val_loss: 0.6970 - val_binary_accuracy: 0.6434 - lr: 0.0010
# Epoch 23/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4590 - binary_accuracy: 0.7838
# Epoch 23: val_binary_accuracy did not improve from 0.73775
# 185/185 [==============================] - 124s 660ms/step - loss: 0.4590 - binary_accuracy: 0.7838 - val_loss: 0.6656 - val_binary_accuracy: 0.6535 - lr: 0.0010
# Epoch 24/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4470 - binary_accuracy: 0.7890
# Epoch 24: val_binary_accuracy did not improve from 0.73775
# 185/185 [==============================] - 123s 656ms/step - loss: 0.4470 - binary_accuracy: 0.7890 - val_loss: 0.5434 - val_binary_accuracy: 0.7154 - lr: 0.0010
# Epoch 25/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4459 - binary_accuracy: 0.7939
# Epoch 25: val_binary_accuracy did not improve from 0.73775
#
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 185/185 [==============================] - 124s 661ms/step - loss: 0.4459 - binary_accuracy: 0.7939 - val_loss: 0.6241 - val_binary_accuracy: 0.7147 - lr: 0.0010
# Epoch 26/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4441 - binary_accuracy: 0.7890
# Epoch 26: val_binary_accuracy did not improve from 0.73775
# 185/185 [==============================] - 122s 650ms/step - loss: 0.4441 - binary_accuracy: 0.7890 - val_loss: 0.6122 - val_binary_accuracy: 0.6729 - lr: 8.0000e-04
# Epoch 27/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4160 - binary_accuracy: 0.8092
# Epoch 27: val_binary_accuracy improved from 0.73775 to 0.75504, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 124s 657ms/step - loss: 0.4160 - binary_accuracy: 0.8092 - val_loss: 0.5051 - val_binary_accuracy: 0.7550 - lr: 8.0000e-04
# Epoch 28/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4127 - binary_accuracy: 0.8099
# Epoch 28: val_binary_accuracy did not improve from 0.75504
# 185/185 [==============================] - 123s 656ms/step - loss: 0.4127 - binary_accuracy: 0.8099 - val_loss: 0.5113 - val_binary_accuracy: 0.7378 - lr: 8.0000e-04
# Epoch 29/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4135 - binary_accuracy: 0.8108
# Epoch 29: val_binary_accuracy did not improve from 0.75504
# 185/185 [==============================] - 121s 648ms/step - loss: 0.4135 - binary_accuracy: 0.8108 - val_loss: 0.5148 - val_binary_accuracy: 0.7471 - lr: 8.0000e-04
# Epoch 30/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4043 - binary_accuracy: 0.8106
# Epoch 30: val_binary_accuracy did not improve from 0.75504
# 185/185 [==============================] - 124s 663ms/step - loss: 0.4043 - binary_accuracy: 0.8106 - val_loss: 0.6475 - val_binary_accuracy: 0.6924 - lr: 8.0000e-04
# Epoch 31/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3960 - binary_accuracy: 0.8173
# Epoch 31: val_binary_accuracy did not improve from 0.75504
# 185/185 [==============================] - 124s 660ms/step - loss: 0.3960 - binary_accuracy: 0.8173 - val_loss: 0.5311 - val_binary_accuracy: 0.7363 - lr: 8.0000e-04
# Epoch 32/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3994 - binary_accuracy: 0.8225
# Epoch 32: val_binary_accuracy improved from 0.75504 to 0.75793, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 125s 670ms/step - loss: 0.3994 - binary_accuracy: 0.8225 - val_loss: 0.5246 - val_binary_accuracy: 0.7579 - lr: 8.0000e-04
# Epoch 33/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3957 - binary_accuracy: 0.8158
# Epoch 33: val_binary_accuracy improved from 0.75793 to 0.76513, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 127s 679ms/step - loss: 0.3957 - binary_accuracy: 0.8158 - val_loss: 0.5111 - val_binary_accuracy: 0.7651 - lr: 8.0000e-04
# Epoch 34/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3824 - binary_accuracy: 0.8223
# Epoch 34: val_binary_accuracy did not improve from 0.76513
# 185/185 [==============================] - 126s 674ms/step - loss: 0.3824 - binary_accuracy: 0.8223 - val_loss: 0.6692 - val_binary_accuracy: 0.6794 - lr: 8.0000e-04
# Epoch 35/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3713 - binary_accuracy: 0.8374
# Epoch 35: val_binary_accuracy did not improve from 0.76513
# 185/185 [==============================] - 121s 650ms/step - loss: 0.3713 - binary_accuracy: 0.8374 - val_loss: 0.6179 - val_binary_accuracy: 0.7212 - lr: 8.0000e-04
# Epoch 36/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3943 - binary_accuracy: 0.8245
# Epoch 36: val_binary_accuracy did not improve from 0.76513
# 185/185 [==============================] - 124s 654ms/step - loss: 0.3943 - binary_accuracy: 0.8245 - val_loss: 0.5914 - val_binary_accuracy: 0.7255 - lr: 8.0000e-04
# Epoch 37/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3776 - binary_accuracy: 0.8304
# Epoch 37: val_binary_accuracy did not improve from 0.76513
# 185/185 [==============================] - 126s 672ms/step - loss: 0.3776 - binary_accuracy: 0.8304 - val_loss: 0.5325 - val_binary_accuracy: 0.7500 - lr: 8.0000e-04
# Epoch 38/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3538 - binary_accuracy: 0.8419
# Epoch 38: val_binary_accuracy did not improve from 0.76513
# 185/185 [==============================] - 125s 665ms/step - loss: 0.3538 - binary_accuracy: 0.8419 - val_loss: 0.5298 - val_binary_accuracy: 0.7637 - lr: 8.0000e-04
# Epoch 39/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3443 - binary_accuracy: 0.8473
# Epoch 39: val_binary_accuracy did not improve from 0.76513
#
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 185/185 [==============================] - 124s 661ms/step - loss: 0.3443 - binary_accuracy: 0.8473 - val_loss: 0.6605 - val_binary_accuracy: 0.7248 - lr: 8.0000e-04
# Epoch 40/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3505 - binary_accuracy: 0.8453
# Epoch 40: val_binary_accuracy improved from 0.76513 to 0.76657, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 123s 657ms/step - loss: 0.3505 - binary_accuracy: 0.8453 - val_loss: 0.5467 - val_binary_accuracy: 0.7666 - lr: 6.4000e-04
# Epoch 41/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3327 - binary_accuracy: 0.8563
# Epoch 41: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 124s 664ms/step - loss: 0.3327 - binary_accuracy: 0.8563 - val_loss: 0.5607 - val_binary_accuracy: 0.7522 - lr: 6.4000e-04
# Epoch 42/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3414 - binary_accuracy: 0.8514
# Epoch 42: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 122s 650ms/step - loss: 0.3414 - binary_accuracy: 0.8514 - val_loss: 0.5557 - val_binary_accuracy: 0.7435 - lr: 6.4000e-04
# Epoch 43/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3407 - binary_accuracy: 0.8554
# Epoch 43: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 124s 657ms/step - loss: 0.3407 - binary_accuracy: 0.8554 - val_loss: 0.5844 - val_binary_accuracy: 0.7464 - lr: 6.4000e-04
# Epoch 44/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3182 - binary_accuracy: 0.8651
# Epoch 44: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 122s 655ms/step - loss: 0.3182 - binary_accuracy: 0.8651 - val_loss: 0.6165 - val_binary_accuracy: 0.7522 - lr: 6.4000e-04
# Epoch 45/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3150 - binary_accuracy: 0.8622
# Epoch 45: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 122s 652ms/step - loss: 0.3150 - binary_accuracy: 0.8622 - val_loss: 0.6151 - val_binary_accuracy: 0.7226 - lr: 6.4000e-04
# Epoch 46/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3229 - binary_accuracy: 0.8604
# Epoch 46: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 125s 669ms/step - loss: 0.3229 - binary_accuracy: 0.8604 - val_loss: 0.6314 - val_binary_accuracy: 0.7183 - lr: 6.4000e-04
# Epoch 47/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3118 - binary_accuracy: 0.8664
# Epoch 47: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 122s 651ms/step - loss: 0.3118 - binary_accuracy: 0.8664 - val_loss: 0.6595 - val_binary_accuracy: 0.7154 - lr: 6.4000e-04
# Epoch 48/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3175 - binary_accuracy: 0.8662
# Epoch 48: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 126s 671ms/step - loss: 0.3175 - binary_accuracy: 0.8662 - val_loss: 0.6850 - val_binary_accuracy: 0.6974 - lr: 6.4000e-04
# Epoch 49/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3066 - binary_accuracy: 0.8730
# Epoch 49: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 124s 664ms/step - loss: 0.3066 - binary_accuracy: 0.8730 - val_loss: 0.6637 - val_binary_accuracy: 0.7125 - lr: 6.4000e-04
# Epoch 50/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3065 - binary_accuracy: 0.8734
# Epoch 50: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 124s 659ms/step - loss: 0.3065 - binary_accuracy: 0.8734 - val_loss: 0.6436 - val_binary_accuracy: 0.7392 - lr: 6.4000e-04
# Epoch 51/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3003 - binary_accuracy: 0.8671
# Epoch 51: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 125s 670ms/step - loss: 0.3003 - binary_accuracy: 0.8671 - val_loss: 0.6459 - val_binary_accuracy: 0.7269 - lr: 6.4000e-04
# Epoch 52/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2998 - binary_accuracy: 0.8775
# Epoch 52: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 124s 663ms/step - loss: 0.2998 - binary_accuracy: 0.8775 - val_loss: 0.5667 - val_binary_accuracy: 0.7478 - lr: 6.4000e-04
# Epoch 53/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2975 - binary_accuracy: 0.8689
# Epoch 53: val_binary_accuracy did not improve from 0.76657
#
# Epoch 53: ReduceLROnPlateau reducing learning rate to 0.0005120000336319208.
# 185/185 [==============================] - 125s 664ms/step - loss: 0.2975 - binary_accuracy: 0.8689 - val_loss: 0.6150 - val_binary_accuracy: 0.7421 - lr: 6.4000e-04
# Epoch 54/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2796 - binary_accuracy: 0.8833
# Epoch 54: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 127s 677ms/step - loss: 0.2796 - binary_accuracy: 0.8833 - val_loss: 0.6877 - val_binary_accuracy: 0.7176 - lr: 5.1200e-04
# Epoch 55/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2826 - binary_accuracy: 0.8797
# Epoch 55: val_binary_accuracy did not improve from 0.76657
# 185/185 [==============================] - 123s 658ms/step - loss: 0.2826 - binary_accuracy: 0.8797 - val_loss: 0.6696 - val_binary_accuracy: 0.7241 - lr: 5.1200e-04

# %%
np.save('history.npy',history.history)

# %%
combined_Model.load_weights(weight_path)

# %%
history1=np.load('/kaggle/working/history.npy',allow_pickle='TRUE').item()

# %%
pred_Y = combined_Model.predict(test_X, 
                          batch_size = 32, 
                          verbose = True)
# Out:
# 44/44 [==============================] - 6s 86ms/step

# %%
plt.matshow(confusion_matrix(test_Y, pred_Y>0.5))
print(classification_report(test_Y, pred_Y>0.5, target_names = ['Healthy', 'Cardiomegaly']))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.92      0.76      0.83      1110
# Cardiomegaly       0.44      0.73      0.55       278
#
#     accuracy                           0.76      1388
#    macro avg       0.68      0.75      0.69      1388
# weighted avg       0.82      0.76      0.78      1388

# %%
plt.plot(history1['binary_accuracy'])
plt.plot(history1['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history1['loss'])
plt.plot(history1['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## Test Results

# %%
final_pred_Y = combined_Model.predict(final_test_X, 
                                verbose = True, 
                                batch_size = 4)
# Out:
# 347/347 [==============================] - 13s 19ms/step

# %%
plt.matshow(confusion_matrix(final_test_Y, final_pred_Y>0.5))
print(classification_report(final_test_Y, final_pred_Y>0.5, target_names = ['Healthy', 'Cardiomegaly']))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.92      0.77      0.84      1110
# Cardiomegaly       0.44      0.72      0.54       278
#
#     accuracy                           0.76      1388
#    macro avg       0.68      0.74      0.69      1388
# weighted avg       0.82      0.76      0.78      1388

# %%
def getPerformanceMetrics(real_values,pred_values,format):
    CM = confusion_matrix(real_values,pred_values)
    TN = CM[0][0]
    FN = CM[1][0] 
    TP = CM[1][1]
    FP = CM[0][1]
    Population = TN+FN+TP+FP
    Accuracy   = round( (TP+TN) / Population,4)
    PPV        = round( TP / (TP+FP),4 )
    NPV        = round( TN / (TN+FN),4 )
    Sensitivity= round( TP / (TP+FN),4 )
    Specificity= round( TN / (TN+FP),4 )
    if format==1:
        performance_metrics = pd.DataFrame({'Metric': ['Accuracy','PPV','NPV','Sensitivity','Specificity'],
                                            'Value':[Accuracy,PPV,NPV,Sensitivity,Specificity]})
    else:
        performance_metrics = pd.DataFrame({'Accuracy':[Accuracy],'PPV':[PPV],'NPV':[NPV],'Sensitivity':[Sensitivity],'Specificity':[Specificity]})
        
    return performance_metrics

# %% [markdown]
# ## Validation Metrics

# %%
print(getPerformanceMetrics(test_Y, pred_Y>0.5,2))
# Out:
#    Accuracy     PPV     NPV  Sensitivity  Specificity
# 0    0.7579  0.4378  0.9197       0.7338        0.764

# %% [markdown]
# ## Test Metrics

# %%
print(getPerformanceMetrics(final_test_Y,final_pred_Y>0.5,2))
# Out:
#    Accuracy     PPV     NPV  Sensitivity  Specificity
# 0    0.7586  0.4376  0.9162       0.7194       0.7685
