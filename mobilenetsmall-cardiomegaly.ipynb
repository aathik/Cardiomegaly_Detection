# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os 
from glob import glob 
import matplotlib.pyplot as plt
import keras
from skimage.util import montage as montage2d
from skimage.io import imread
import seaborn as sns
from keras.optimizers import Adam
import tensorflow as tf
from keras import Input
from keras.models import Model
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.applications import ResNet152V2, InceptionV3, EfficientNetB0, MobileNetV3Small
from keras.layers import Dense, Flatten, Activation, Conv2D, MaxPooling2D, Dropout, Conv2D,MaxPooling2D,GlobalAveragePooling2D,AvgPool2D,multiply, LocallyConnected2D, Lambda, AvgPool2D


# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
        

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
base_dir = os.path.join('..', 'input', 'pulmonary-chest-xray-abnormalities')
all_xray_images_dataframe = pd.read_csv('../input/data/Data_Entry_2017.csv')
all_xray_images_dataframe.sample(5)
# Out:
#              Image Index       Finding Labels  Follow-up #  Patient ID  \
# 22778   00006022_005.png  Infiltration|Nodule            5        6022
# 97118   00025621_010.png    Infiltration|Mass           10       25621
# 53462   00013499_004.png                 Mass            4       13499
# 2454    00000631_006.png           No Finding            6         631
# 107728  00029112_000.png           No Finding            0       29112
#
#         Patient Age Patient Gender View Position  OriginalImage[Width  \
# 22778            49              M            PA                 2992
# 97118            65              F            PA                 2992
# 53462            33              M            AP                 2500
# 2454             25              M            PA                 2694
# 107728           64              M            PA                 2021
#
#         Height]  OriginalImagePixelSpacing[x        y]  Unnamed: 11
# 22778      2991                     0.143000  0.143000          NaN
# 97118      2991                     0.143000  0.143000          NaN
# 53462      2048                     0.168000  0.168000          NaN
# 2454       2991                     0.143000  0.143000          NaN
# 107728     2021                     0.194311  0.194311          NaN

# %%
all_xray_images_dataframe['Finding Labels']
# Out:
# 0                   Cardiomegaly
# 1         Cardiomegaly|Emphysema
# 2          Cardiomegaly|Effusion
# 3                     No Finding
# 4                         Hernia
#                    ...
# 112115            Mass|Pneumonia
# 112116                No Finding
# 112117                No Finding
# 112118                No Finding
# 112119                No Finding
# Name: Finding Labels, Length: 112120, dtype: object

# %% [markdown]
# # Preprocessing
# Organize the files by cases with and without cardiomegaly

# %%
all_xray_images_dataframe = pd.read_csv('../input/data/Data_Entry_2017.csv')
all_images_paths = {os.path.basename(x): x for x in 
                   glob(os.path.join('..', 'input', 'data',  'images*', '*', '*.png'))}
print('Scans found:', len(all_images_paths), ', Total Headers', all_xray_images_dataframe.shape[0])
all_xray_images_dataframe['path'] = all_xray_images_dataframe['Image Index'].map(all_images_paths.get)
all_xray_images_dataframe['Cardiomegaly'] = all_xray_images_dataframe['Finding Labels'].map(lambda x: 'Cardiomegaly' in x)
all_xray_images_dataframe['Patient Age'] = np.clip(all_xray_images_dataframe['Patient Age'], 5, 100)
all_xray_images_dataframe['Patient Male'] = all_xray_images_dataframe['Patient Gender'].map(lambda x: x.upper()=='M').astype('float32')
all_xray_images_dataframe.sample(3)
# Out:
# Scans found: 112120 , Total Headers 112120
#             Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 3414   00000909_002.png     No Finding            2         909           33
# 42590  00010966_000.png     No Finding            0       10966           56
# 63273  00015628_020.png     No Finding           20       15628           49
#
#       Patient Gender View Position  OriginalImage[Width  Height]  \
# 3414               F            AP                 2500     2048
# 42590              M            PA                 2992     2991
# 63273              M            AP                 2500     2048
#
#        OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 3414                         0.168  0.168          NaN
# 42590                        0.143  0.143          NaN
# 63273                        0.168  0.168          NaN
#
#                                                    path  Cardiomegaly  \
# 3414   ../input/data/images_001/images/00000909_002.png         False
# 42590  ../input/data/images_005/images/00010966_000.png         False
# 63273  ../input/data/images_007/images/00015628_020.png         False
#
#        Patient Male
# 3414            0.0
# 42590           1.0
# 63273           1.0

# %% [markdown]
# # Examine the distributions
# Show how the data is distributed and why we need to balance it

# %%
sns.pairplot(all_xray_images_dataframe[['Patient Age', 'Patient Male', 'Cardiomegaly']], hue='Cardiomegaly')

# %% [markdown]
# # Split Data into Training and Validation

# %%
positive_cases = np.sum(all_xray_images_dataframe['Cardiomegaly']==True)//2
oversample_factor = 4 # maximum number of cases in negative group so it isn't super rare
more_balanced_df = all_xray_images_dataframe.groupby(['Patient Gender', 'Cardiomegaly']).apply(lambda x: x.sample(min(oversample_factor*positive_cases, x.shape[0]), 
                                                                                   replace = False)
                                                      ).reset_index(drop = True)

print(more_balanced_df['Cardiomegaly'].value_counts())
sns.pairplot(more_balanced_df[['Patient Age', 'Cardiomegaly']], hue='Cardiomegaly')
# Out:
# False    11104
# True      2776
# Name: Cardiomegaly, dtype: int64

# %%
more_balanced_df
# Out:
#             Image Index                      Finding Labels  Follow-up #  \
# 0      00020821_000.png                                Mass            0
# 1      00016732_011.png              Consolidation|Effusion           11
# 2      00008570_003.png                              Nodule            3
# 3      00006044_003.png                          No Finding            3
# 4      00022459_001.png                          No Finding            1
# ...                 ...                                 ...          ...
# 13875  00021599_002.png               Cardiomegaly|Effusion            2
# 13876  00010536_000.png              Cardiomegaly|Emphysema            0
# 13877  00006481_023.png           Cardiomegaly|Infiltration           23
# 13878  00022815_031.png  Cardiomegaly|Effusion|Infiltration           31
# 13879  00030764_000.png                        Cardiomegaly            0
#
#        Patient ID  Patient Age Patient Gender View Position  \
# 0           20821           46              F            AP
# 1           16732           80              F            AP
# 2            8570           24              F            PA
# 3            6044           39              F            PA
# 4           22459           65              F            PA
# ...           ...          ...            ...           ...
# 13875       21599           64              M            AP
# 13876       10536           77              M            PA
# 13877        6481           52              M            AP
# 13878       22815            9              M            AP
# 13879       30764           36              M            PA
#
#        OriginalImage[Width  Height]  OriginalImagePixelSpacing[x        y]  \
# 0                     3028     2544                     0.139000  0.139000
# 1                     2500     2048                     0.168000  0.168000
# 2                     2048     2500                     0.168000  0.168000
# 3                     2048     2500                     0.171000  0.171000
# 4                     2476     3056                     0.139000  0.139000
# ...                    ...      ...                          ...       ...
# 13875                 3056     2544                     0.139000  0.139000
# 13876                 2936     2991                     0.143000  0.143000
# 13877                 2500     2048                     0.168000  0.168000
# 13878                 3056     2544                     0.139000  0.139000
# 13879                 2021     2021                     0.194311  0.194311
#
#        Unnamed: 11                                              path  \
# 0              NaN  ../input/data/images_009/images/00020821_000.png
# 1              NaN  ../input/data/images_008/images/00016732_011.png
# 2              NaN  ../input/data/images_004/images/00008570_003.png
# 3              NaN  ../input/data/images_003/images/00006044_003.png
# 4              NaN  ../input/data/images_010/images/00022459_001.png
# ...            ...                                               ...
# 13875          NaN  ../input/data/images_010/images/00021599_002.png
# 13876          NaN  ../input/data/images_005/images/00010536_000.png
# 13877          NaN  ../input/data/images_003/images/00006481_023.png
# 13878          NaN  ../input/data/images_010/images/00022815_031.png
# 13879          NaN  ../input/data/images_012/images/00030764_000.png
#
#        Cardiomegaly  Patient Male
# 0             False           0.0
# 1             False           0.0
# 2             False           0.0
# 3             False           0.0
# 4             False           0.0
# ...             ...           ...
# 13875          True           1.0
# 13876          True           1.0
# 13877          True           1.0
# 13878          True           1.0
# 13879          True           1.0
#
# [13880 rows x 15 columns]

# %%
from sklearn.model_selection import train_test_split
raw_train_df, test_valid_df = train_test_split(more_balanced_df, 
                                   test_size = 0.20, 
                                   random_state = 2018,
                                   stratify = more_balanced_df[['Cardiomegaly', 'Patient Gender']])
valid_df, test_df = train_test_split(test_valid_df, 
                                   test_size = 0.40, 
                                   random_state = 2018,
                                   stratify = test_valid_df[['Cardiomegaly', 'Patient Gender']])
print('train', raw_train_df.shape[0], 'validation', valid_df.shape[0], 'test', test_df.shape[0])
print('train', raw_train_df['Cardiomegaly'].value_counts())
print('test', test_df['Cardiomegaly'].value_counts())
raw_train_df.sample(1)
# Out:
# train 11104 validation 1665 test 1111
# train False    8884
# True     2220
# Name: Cardiomegaly, dtype: int64
# test False    888
# True     223
# Name: Cardiomegaly, dtype: int64
#            Image Index                     Finding Labels  Follow-up #  \
# 5601  00025685_001.png  Atelectasis|Cardiomegaly|Effusion            1
#
#       Patient ID  Patient Age Patient Gender View Position  \
# 5601       25685           52              F            AP
#
#       OriginalImage[Width  Height]  OriginalImagePixelSpacing[x     y]  \
# 5601                 3056     2544                        0.139  0.139
#
#       Unnamed: 11                                              path  \
# 5601          NaN  ../input/data/images_011/images/00025685_001.png
#
#       Cardiomegaly  Patient Male
# 5601          True           0.0

# %%
from sklearn.model_selection import train_test_split
raw_train_df, test_valid_df = train_test_split(more_balanced_df, 
                                   test_size = 0.20, 
                                   random_state = 2018,
                                   stratify = more_balanced_df[['Cardiomegaly', 'Patient Gender']])
valid_df, test_df = train_test_split(test_valid_df, 
                                   test_size = 0.50, 
                                   random_state = 2018,
                                   stratify = test_valid_df[['Cardiomegaly', 'Patient Gender']])
print('train', raw_train_df.shape[0], 'validation', valid_df.shape[0], 'test', test_df.shape[0])
print('train', raw_train_df['Cardiomegaly'].value_counts())
print('test', test_df['Cardiomegaly'].value_counts())
raw_train_df.sample(1)
# Out:
# train 11104 validation 1388 test 1388
# train False    8884
# True     2220
# Name: Cardiomegaly, dtype: int64
# test False    1110
# True      278
# Name: Cardiomegaly, dtype: int64
#            Image Index Finding Labels  Follow-up #  Patient ID  Patient Age  \
# 9092  00000914_003.png     No Finding            3         914           66
#
#      Patient Gender View Position  OriginalImage[Width  Height]  \
# 9092              M            PA                 2500     2048
#
#       OriginalImagePixelSpacing[x     y]  Unnamed: 11  \
# 9092                        0.168  0.168          NaN
#
#                                                   path  Cardiomegaly  \
# 9092  ../input/data/images_001/images/00000914_003.png         False
#
#       Patient Male
# 9092           1.0

# %% [markdown]
# # Balance the distribution in the training set

# %%
train_df = raw_train_df.groupby(['Cardiomegaly']).apply(lambda x: x.sample(2220, replace = True)
                                                      ).reset_index(drop = True)
print('New Data Size:', train_df.shape[0], 'Old Size:', raw_train_df.shape[0])
# Out:
# New Data Size: 4440 Old Size: 11104

# %%
print('train', train_df['Cardiomegaly'].value_counts())
# Out:
# train False    2220
# True     2220
# Name: Cardiomegaly, dtype: int64

# %%
from keras.preprocessing.image import ImageDataGenerator
##from keras.applications.resnet_v2 import ResNet50 as PreTrainedModel, preprocess_input
#from keras.applications.resnet_v2 import ResNet152V2, preprocess_input
from keras.applications.mobilenet import MobileNet as PreTrainedModel, preprocess_input
IMG_SIZE = (224, 224) # size that EfficientNetB7 expects
image_data_generator = ImageDataGenerator(samplewise_center=False, 
                              samplewise_std_normalization=False, 
                              horizontal_flip=False, 
                              vertical_flip=False, 
                              height_shift_range=0.1, 
                              width_shift_range=0.1, 
                              brightness_range=[0.7, 1.5],
                              rotation_range=3, 
                              shear_range=0.01,
                              fill_mode='nearest',
                              zoom_range=0.125,
                             preprocessing_function=preprocess_input)

# %%
def flow_from_dataframe(img_data_gen, in_df, path_col, y_col, **dflow_args):
    df_gen = img_data_gen.flow_from_dataframe(in_df,
                                              x_col=path_col,
                                              y_col=y_col,
                                     class_mode = 'raw',
                                    **dflow_args)
    return df_gen

# %%
train_gen = flow_from_dataframe(image_data_generator, train_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 16)

valid_gen = flow_from_dataframe(image_data_generator, valid_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 256) 
test_X, test_Y = next(flow_from_dataframe(image_data_generator, 
                               valid_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 1388)) # one big batch
# used a fixed dataset for final evaluation
final_test_X, final_test_Y = next(flow_from_dataframe(image_data_generator, 
                               test_df, 
                             path_col = 'path',
                            y_col = 'Cardiomegaly', 
                            target_size = IMG_SIZE,
                             color_mode = 'rgb',
                            batch_size = 1388)) # one big batch
# Out:
# Found 4440 validated image filenames.
# Found 1388 validated image filenames.
# Found 1388 validated image filenames.
# Found 1388 validated image filenames.

# %%
t_x, t_y = next(train_gen)
t_y
# Out:
# array([False, False, False, False, False,  True, False,  True, False,
#         True, False,  True, False,  True, False,  True])

# %%
t_x, t_y = next(train_gen)
print(t_x.shape)
print(t_y)
fig, m_axs = plt.subplots(4, 4, figsize = (16, 8))
for (c_x, c_y, c_ax) in zip(t_x, t_y, m_axs.flatten()):
    c_ax.imshow(c_x[:,:,0], cmap = 'bone', vmin = -127, vmax = 127)
    c_ax.set_title('%s' % ('Cardiomegaly' if c_y else 'Healthy'))
    c_ax.axis('off')
# Out:
# (16, 224, 224, 3)
# [False  True False False False False  True False False  True False False
#  False False  True False]

# %%
base_pretrained_model = PreTrainedModel(input_shape =  t_x.shape[1:], 
                              include_top = False, weights = 'imagenet')
base_pretrained_model.trainable = False
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17225924/17225924 [==============================] - 1s 0us/step

# %%
base_pretrained_model.summary()
# Out:
# Model: "mobilenet_1.00_224"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  conv1 (Conv2D)              (None, 112, 112, 32)      864
#
#  conv1_bn (BatchNormalizatio  (None, 112, 112, 32)     128
#  n)
#
#  conv1_relu (ReLU)           (None, 112, 112, 32)      0
#
#  conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)     288
#
#  conv_dw_1_bn (BatchNormaliz  (None, 112, 112, 32)     128
#  ation)
#
#  conv_dw_1_relu (ReLU)       (None, 112, 112, 32)      0
#
#  conv_pw_1 (Conv2D)          (None, 112, 112, 64)      2048
#
#  conv_pw_1_bn (BatchNormaliz  (None, 112, 112, 64)     256
#  ation)
#
#  conv_pw_1_relu (ReLU)       (None, 112, 112, 64)      0
#
#  conv_pad_2 (ZeroPadding2D)  (None, 113, 113, 64)      0
#
#  conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)       576
#
#  conv_dw_2_bn (BatchNormaliz  (None, 56, 56, 64)       256
#  ation)
#
#  conv_dw_2_relu (ReLU)       (None, 56, 56, 64)        0
#
#  conv_pw_2 (Conv2D)          (None, 56, 56, 128)       8192
#
#  conv_pw_2_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_2_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)      1152
#
#  conv_dw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_dw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pw_3 (Conv2D)          (None, 56, 56, 128)       16384
#
#  conv_pw_3_bn (BatchNormaliz  (None, 56, 56, 128)      512
#  ation)
#
#  conv_pw_3_relu (ReLU)       (None, 56, 56, 128)       0
#
#  conv_pad_4 (ZeroPadding2D)  (None, 57, 57, 128)       0
#
#  conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)      1152
#
#  conv_dw_4_bn (BatchNormaliz  (None, 28, 28, 128)      512
#  ation)
#
#  conv_dw_4_relu (ReLU)       (None, 28, 28, 128)       0
#
#  conv_pw_4 (Conv2D)          (None, 28, 28, 256)       32768
#
#  conv_pw_4_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_4_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)      2304
#
#  conv_dw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_dw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pw_5 (Conv2D)          (None, 28, 28, 256)       65536
#
#  conv_pw_5_bn (BatchNormaliz  (None, 28, 28, 256)      1024
#  ation)
#
#  conv_pw_5_relu (ReLU)       (None, 28, 28, 256)       0
#
#  conv_pad_6 (ZeroPadding2D)  (None, 29, 29, 256)       0
#
#  conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)      2304
#
#  conv_dw_6_bn (BatchNormaliz  (None, 14, 14, 256)      1024
#  ation)
#
#  conv_dw_6_relu (ReLU)       (None, 14, 14, 256)       0
#
#  conv_pw_6 (Conv2D)          (None, 14, 14, 512)       131072
#
#  conv_pw_6_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_6_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_7 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_7_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_7_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_8 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_8_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_8_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)      4608
#
#  conv_dw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_dw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_pw_9 (Conv2D)          (None, 14, 14, 512)       262144
#
#  conv_pw_9_bn (BatchNormaliz  (None, 14, 14, 512)      2048
#  ation)
#
#  conv_pw_9_relu (ReLU)       (None, 14, 14, 512)       0
#
#  conv_dw_10 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_10 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_10_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_10_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_dw_11 (DepthwiseConv2D  (None, 14, 14, 512)      4608
#  )
#
#  conv_dw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_dw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pw_11 (Conv2D)         (None, 14, 14, 512)       262144
#
#  conv_pw_11_bn (BatchNormali  (None, 14, 14, 512)      2048
#  zation)
#
#  conv_pw_11_relu (ReLU)      (None, 14, 14, 512)       0
#
#  conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)      0
#
#  conv_dw_12 (DepthwiseConv2D  (None, 7, 7, 512)        4608
#  )
#
#  conv_dw_12_bn (BatchNormali  (None, 7, 7, 512)        2048
#  zation)
#
#  conv_dw_12_relu (ReLU)      (None, 7, 7, 512)         0
#
#  conv_pw_12 (Conv2D)         (None, 7, 7, 1024)        524288
#
#  conv_pw_12_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_12_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_dw_13 (DepthwiseConv2D  (None, 7, 7, 1024)       9216
#  )
#
#  conv_dw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_dw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
#  conv_pw_13 (Conv2D)         (None, 7, 7, 1024)        1048576
#
#  conv_pw_13_bn (BatchNormali  (None, 7, 7, 1024)       4096
#  zation)
#
#  conv_pw_13_relu (ReLU)      (None, 7, 7, 1024)        0
#
# =================================================================
# Total params: 3,228,864
# Trainable params: 0
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
model = keras.models.Sequential()
model.add(base_pretrained_model)
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(100, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))
model.compile(optimizer = Adam(learning_rate = 1e-3), loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dropout (Dropout)           (None, 50176)             0
#
#  dense (Dense)               (None, 100)               5017700
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense_1 (Dense)             (None, 10)                1010
#
#  dense_2 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 8,247,585
# Trainable params: 5,018,721
# Non-trainable params: 3,228,864
# _________________________________________________________________

# %%
from keras.utils.vis_utils import model_to_dot
from IPython.display import Image
Image(model_to_dot(model, show_shapes=True).create_png())

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cardio_attn_test_valid')

modelCheckPoint = ModelCheckpoint(weight_path, monitor='val_binary_accuracy', verbose=1, 
                             save_best_only=True, mode='max', save_weights_only = True)


reduceLROnPlateau = ReduceLROnPlateau(monitor='val_loss', factor=0.8, patience=10, verbose=1, mode='auto', epsilon=0.0001, cooldown=5, min_lr=0.0001)
early = EarlyStopping(monitor="val_binary_accuracy", 
                      mode="max", 
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [modelCheckPoint, early, reduceLROnPlateau]

# %% [markdown]
# # No improvement in learning

# %% [markdown]
# ## Attention Model

# %% [markdown]
# The basic idea is that a Global Average Pooling is too simplistic since some of the regions are more relevant than others. So we build an attention mechanism to turn pixels in the GAP on an off before the pooling and then rescale (Lambda layer) the results based on the number of pixels. The model could be seen as a sort of 'global weighted average' pooling. There is probably something published about it and it is very similar to the kind of attention models used in NLP. It is largely based on the insight that the winning solution annotated and trained a UNET model to segmenting the hand and transforming it. This seems very tedious if we could just learn attention.

# %% [markdown]
# ## Basic Preprocessing
# Here we take the output of the pretrained model and apply BatchNormalization

# %%
t_x.shape[1:]
# Out:
# (224, 224, 3)

# %%
base_pretrained_model(tf.keras.Input(t_x.shape[1:]))
# Out:
# <KerasTensor: shape=(None, 7, 7, 1024) dtype=float32 (created by layer 'mobilenet_1.00_224')>

# %%
pretrained_features = Input(base_pretrained_model.get_output_shape_at(0)[1:], name = 'feature_input')
pretrained_depth = base_pretrained_model.get_output_shape_at(0)[-1]
from keras.layers import BatchNormalization
batchNormalised_features = BatchNormalization(name='Features_BN')(pretrained_features)

# %%
attention_layer = Conv2D(128, kernel_size = (1,1), padding = 'same', activation = 'elu')(batchNormalised_features)
attention_layer = Conv2D(32, kernel_size = (1,1), padding = 'same', activation = 'elu')(attention_layer)
attention_layer = Conv2D(16, kernel_size = (1,1), padding = 'same', activation = 'elu')(attention_layer)
attention_layer = AvgPool2D((2,2), strides = (1,1), padding = 'same')(attention_layer) # smooth results
attention_layer = Conv2D(1, 
                    kernel_size = (1,1), 
                    padding = 'valid', 
                    activation = 'sigmoid',
                   name='AttentionMap2D')(attention_layer)

# %% [markdown]
# ## Rescale Attention
# We rescale the feature dimension back out to the original number of features (instead of just 1) by using a hard-coded convolution.

# %%
up_c2_w = np.ones((1, 1, 1, pretrained_depth))
up_c2 = Conv2D(pretrained_depth, kernel_size = (1,1), padding = 'same', name='UpscaleAttention',
               activation = 'linear', use_bias = False, weights = [up_c2_w])
up_c2.trainable = False
attention_layer = up_c2(attention_layer)

# %% [markdown]
# # Global Weighted Average Pooling
# We now want to use the attention layer to weight the regions we want during the average pooling. A standard average pooling layer is poorly suited to this task since many of the values (presumably) will be zero and they will be counted. So we hand-rig a 'weighted average pooling' where we multiply the attention by the features and then divide by the sum of the attention
# The formula for weighted average from [Wikipedia](https://en.wikipedia.org/wiki/Weighted_arithmetic_mean)
# $$ \bar{x} = \frac{ \sum\limits_{i=1}^n w_i x_i}{\sum\limits_{i=1}^n w_i} $$
# What we do is
# $$ \text{GWAP}(x, y, d) = \frac{ \sum\limits_{x}\sum\limits_{y} \text{Attention}(x,y,d) \text{Feature}(x,y,d)} {\sum\limits_{x}\sum\limits_{y} \text{Attention}(x,y,d)} $$

# %%
mask_features = multiply([attention_layer, batchNormalised_features])
gap_features = GlobalAveragePooling2D()(mask_features)
gap_mask = GlobalAveragePooling2D()(attention_layer)
# to account for missing values from the attention model
gap = Lambda(lambda x: x[0]/x[1], name = 'RescaleGAP')([gap_features, gap_mask])

# %% [markdown]
# ## Dropout and Classification
# We know take the output of this global weighted-average pooling and go to a classification with dropout and two fully connected layers

# %%
gap_dr = Dropout(0.5)(gap)
dr_steps = Dropout(0.5)(Dense(128, activation = 'elu')(gap_dr))
out_layer = Dense(1, activation = 'sigmoid')(dr_steps)

attention_model = Model(inputs = [pretrained_features], outputs = [out_layer], name = 'attention_model')

attention_model.compile(optimizer = 'adam', loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy'])

attention_model.summary()
# Out:
# Model: "attention_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  feature_input (InputLayer)     [(None, 7, 7, 1024)  0           []
#                                 ]
#
#  Features_BN (BatchNormalizatio  (None, 7, 7, 1024)  4096        ['feature_input[0][0]']
#  n)
#
#  conv2d (Conv2D)                (None, 7, 7, 128)    131200      ['Features_BN[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 7, 7, 32)     4128        ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 7, 7, 16)     528         ['conv2d_1[0][0]']
#
#  average_pooling2d (AveragePool  (None, 7, 7, 16)    0           ['conv2d_2[0][0]']
#  ing2D)
#
#  AttentionMap2D (Conv2D)        (None, 7, 7, 1)      17          ['average_pooling2d[0][0]']
#
#  UpscaleAttention (Conv2D)      (None, 7, 7, 1024)   1024        ['AttentionMap2D[0][0]']
#
#  multiply (Multiply)            (None, 7, 7, 1024)   0           ['UpscaleAttention[0][0]',
#                                                                   'Features_BN[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['multiply[0][0]']
#  alAveragePooling2D)
#
#  global_average_pooling2d_1 (Gl  (None, 1024)        0           ['UpscaleAttention[0][0]']
#  obalAveragePooling2D)
#
#  RescaleGAP (Lambda)            (None, 1024)         0           ['global_average_pooling2d[0][0]'
#                                                                  , 'global_average_pooling2d_1[0][
#                                                                  0]']
#
#  dropout_2 (Dropout)            (None, 1024)         0           ['RescaleGAP[0][0]']
#
#  dense_3 (Dense)                (None, 128)          131200      ['dropout_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 128)          0           ['dense_3[0][0]']
#
#  dense_4 (Dense)                (None, 1)            129         ['dropout_3[0][0]']
#
# ==================================================================================================
# Total params: 272,322
# Trainable params: 269,250
# Non-trainable params: 3,072
# __________________________________________________________________________________________________

# %% [markdown]
# ## Model Architecture
# We can show the whole model below

# %%
from keras.utils.vis_utils import model_to_dot
from IPython.display import Image
Image(model_to_dot(attention_model, show_shapes=True).create_png())

# %% [markdown]
# ## Build the whole model
# We build the whole model and fine-tune the results (much lower learning rate)

# %%
from keras.models import Sequential
from keras.optimizers import Adam
combined_Model = Sequential(name = 'combined_model')
base_pretrained_model.trainable = False
combined_Model.add(base_pretrained_model)
combined_Model.add(attention_model)
combined_Model.compile(optimizer = Adam(learning_rate = 1e-3), loss = 'binary_crossentropy',
                           metrics = ['binary_accuracy'])
combined_Model.summary()
# Out:
# Model: "combined_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, 7, 7, 1024)       3228864
#  nal)
#
#  attention_model (Functional  (None, 1)                272322
#  )
#
# =================================================================
# Total params: 3,501,186
# Trainable params: 269,250
# Non-trainable params: 3,231,936
# _________________________________________________________________

# %% [markdown]
# # Image Size & training set manipulation to see if it has any effect

# %%
train_gen.batch_size = 24
history = combined_Model.fit_generator(train_gen, 
                      validation_data = (test_X, test_Y), 
                       steps_per_epoch=train_gen.n//train_gen.batch_size,
                      epochs = 100, 
                      callbacks = callbacks_list,
                      workers = 3)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:7: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   import sys
# Epoch 1/100
# 185/185 [==============================] - ETA: 0s - loss: 0.6501 - binary_accuracy: 0.6523
# Epoch 1: val_binary_accuracy improved from -inf to 0.74928, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 104s 512ms/step - loss: 0.6501 - binary_accuracy: 0.6523 - val_loss: 0.5042 - val_binary_accuracy: 0.7493 - lr: 0.0010
# Epoch 2/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5824 - binary_accuracy: 0.6932
# Epoch 2: val_binary_accuracy did not improve from 0.74928
# 185/185 [==============================] - 89s 474ms/step - loss: 0.5824 - binary_accuracy: 0.6932 - val_loss: 0.5619 - val_binary_accuracy: 0.7104 - lr: 0.0010
# Epoch 3/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5414 - binary_accuracy: 0.7169
# Epoch 3: val_binary_accuracy did not improve from 0.74928
# 185/185 [==============================] - 89s 474ms/step - loss: 0.5414 - binary_accuracy: 0.7169 - val_loss: 0.5334 - val_binary_accuracy: 0.7349 - lr: 0.0010
# Epoch 4/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5345 - binary_accuracy: 0.7257
# Epoch 4: val_binary_accuracy did not improve from 0.74928
# 185/185 [==============================] - 89s 473ms/step - loss: 0.5345 - binary_accuracy: 0.7257 - val_loss: 0.5609 - val_binary_accuracy: 0.6880 - lr: 0.0010
# Epoch 5/100
# 185/185 [==============================] - ETA: 0s - loss: 0.5036 - binary_accuracy: 0.7529
# Epoch 5: val_binary_accuracy did not improve from 0.74928
# 185/185 [==============================] - 88s 472ms/step - loss: 0.5036 - binary_accuracy: 0.7529 - val_loss: 0.5256 - val_binary_accuracy: 0.7169 - lr: 0.0010
# Epoch 6/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.4988 - binary_accuracy: 0.7459
# Epoch 6: val_binary_accuracy improved from 0.74928 to 0.76801, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 90s 482ms/step - loss: 0.4990 - binary_accuracy: 0.7457 - val_loss: 0.4676 - val_binary_accuracy: 0.7680 - lr: 0.0010
# Epoch 7/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4849 - binary_accuracy: 0.7642
# Epoch 7: val_binary_accuracy did not improve from 0.76801
# 185/185 [==============================] - 89s 470ms/step - loss: 0.4849 - binary_accuracy: 0.7642 - val_loss: 0.5450 - val_binary_accuracy: 0.7277 - lr: 0.0010
# Epoch 8/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.4763 - binary_accuracy: 0.7690
# Epoch 8: val_binary_accuracy improved from 0.76801 to 0.78386, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 89s 475ms/step - loss: 0.4756 - binary_accuracy: 0.7694 - val_loss: 0.4574 - val_binary_accuracy: 0.7839 - lr: 0.0010
# Epoch 9/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4587 - binary_accuracy: 0.7770
# Epoch 9: val_binary_accuracy did not improve from 0.78386
# 185/185 [==============================] - 90s 483ms/step - loss: 0.4587 - binary_accuracy: 0.7770 - val_loss: 0.5828 - val_binary_accuracy: 0.6924 - lr: 0.0010
# Epoch 10/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4442 - binary_accuracy: 0.7815
# Epoch 10: val_binary_accuracy did not improve from 0.78386
# 185/185 [==============================] - 89s 478ms/step - loss: 0.4442 - binary_accuracy: 0.7815 - val_loss: 0.4693 - val_binary_accuracy: 0.7695 - lr: 0.0010
# Epoch 11/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4312 - binary_accuracy: 0.7948
# Epoch 11: val_binary_accuracy did not improve from 0.78386
# 185/185 [==============================] - 88s 473ms/step - loss: 0.4312 - binary_accuracy: 0.7948 - val_loss: 0.4547 - val_binary_accuracy: 0.7824 - lr: 0.0010
# Epoch 12/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4316 - binary_accuracy: 0.7989
# Epoch 12: val_binary_accuracy did not improve from 0.78386
# 185/185 [==============================] - 90s 484ms/step - loss: 0.4316 - binary_accuracy: 0.7989 - val_loss: 0.4783 - val_binary_accuracy: 0.7622 - lr: 0.0010
# Epoch 13/100
# 185/185 [==============================] - ETA: 0s - loss: 0.4238 - binary_accuracy: 0.8083
# Epoch 13: val_binary_accuracy did not improve from 0.78386
# 185/185 [==============================] - 92s 491ms/step - loss: 0.4238 - binary_accuracy: 0.8083 - val_loss: 0.5079 - val_binary_accuracy: 0.7536 - lr: 0.0010
# Epoch 14/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3998 - binary_accuracy: 0.8218
# Epoch 14: val_binary_accuracy did not improve from 0.78386
# 185/185 [==============================] - 90s 481ms/step - loss: 0.3998 - binary_accuracy: 0.8218 - val_loss: 0.5072 - val_binary_accuracy: 0.7565 - lr: 0.0010
# Epoch 15/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.4016 - binary_accuracy: 0.8166
# Epoch 15: val_binary_accuracy did not improve from 0.78386
# 185/185 [==============================] - 89s 475ms/step - loss: 0.4018 - binary_accuracy: 0.8167 - val_loss: 0.5280 - val_binary_accuracy: 0.7478 - lr: 0.0010
# Epoch 16/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3773 - binary_accuracy: 0.8288
# Epoch 16: val_binary_accuracy did not improve from 0.78386
# 185/185 [==============================] - 90s 483ms/step - loss: 0.3773 - binary_accuracy: 0.8288 - val_loss: 0.5319 - val_binary_accuracy: 0.7558 - lr: 0.0010
# Epoch 17/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3796 - binary_accuracy: 0.8385
# Epoch 17: val_binary_accuracy did not improve from 0.78386
# 185/185 [==============================] - 88s 474ms/step - loss: 0.3796 - binary_accuracy: 0.8385 - val_loss: 0.5580 - val_binary_accuracy: 0.7370 - lr: 0.0010
# Epoch 18/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.3683 - binary_accuracy: 0.8385
# Epoch 18: val_binary_accuracy improved from 0.78386 to 0.78530, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 90s 485ms/step - loss: 0.3690 - binary_accuracy: 0.8387 - val_loss: 0.4783 - val_binary_accuracy: 0.7853 - lr: 0.0010
# Epoch 19/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3462 - binary_accuracy: 0.8495
# Epoch 19: val_binary_accuracy did not improve from 0.78530
# 185/185 [==============================] - 91s 483ms/step - loss: 0.3462 - binary_accuracy: 0.8495 - val_loss: 0.5544 - val_binary_accuracy: 0.7414 - lr: 0.0010
# Epoch 20/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3591 - binary_accuracy: 0.8435
# Epoch 20: val_binary_accuracy did not improve from 0.78530
# 185/185 [==============================] - 92s 489ms/step - loss: 0.3591 - binary_accuracy: 0.8435 - val_loss: 0.5119 - val_binary_accuracy: 0.7493 - lr: 0.0010
# Epoch 21/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3542 - binary_accuracy: 0.8439
# Epoch 21: val_binary_accuracy did not improve from 0.78530
#
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.000800000037997961.
# 185/185 [==============================] - 91s 487ms/step - loss: 0.3542 - binary_accuracy: 0.8439 - val_loss: 0.5024 - val_binary_accuracy: 0.7759 - lr: 0.0010
# Epoch 22/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3193 - binary_accuracy: 0.8635
# Epoch 22: val_binary_accuracy did not improve from 0.78530
# 185/185 [==============================] - 90s 482ms/step - loss: 0.3193 - binary_accuracy: 0.8635 - val_loss: 0.5632 - val_binary_accuracy: 0.7414 - lr: 8.0000e-04
# Epoch 23/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3243 - binary_accuracy: 0.8628
# Epoch 23: val_binary_accuracy did not improve from 0.78530
# 185/185 [==============================] - 89s 474ms/step - loss: 0.3243 - binary_accuracy: 0.8628 - val_loss: 0.4916 - val_binary_accuracy: 0.7788 - lr: 8.0000e-04
# Epoch 24/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.3114 - binary_accuracy: 0.8675
# Epoch 24: val_binary_accuracy did not improve from 0.78530
# 185/185 [==============================] - 90s 480ms/step - loss: 0.3116 - binary_accuracy: 0.8676 - val_loss: 0.5552 - val_binary_accuracy: 0.7435 - lr: 8.0000e-04
# Epoch 25/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3104 - binary_accuracy: 0.8694
# Epoch 25: val_binary_accuracy did not improve from 0.78530
# 185/185 [==============================] - 89s 474ms/step - loss: 0.3104 - binary_accuracy: 0.8694 - val_loss: 0.5905 - val_binary_accuracy: 0.7442 - lr: 8.0000e-04
# Epoch 26/100
# 185/185 [==============================] - ETA: 0s - loss: 0.3146 - binary_accuracy: 0.8680
# Epoch 26: val_binary_accuracy did not improve from 0.78530
# 185/185 [==============================] - 88s 473ms/step - loss: 0.3146 - binary_accuracy: 0.8680 - val_loss: 0.5194 - val_binary_accuracy: 0.7630 - lr: 8.0000e-04
# Epoch 27/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2917 - binary_accuracy: 0.8757
# Epoch 27: val_binary_accuracy did not improve from 0.78530
# 185/185 [==============================] - 88s 473ms/step - loss: 0.2917 - binary_accuracy: 0.8757 - val_loss: 0.5413 - val_binary_accuracy: 0.7709 - lr: 8.0000e-04
# Epoch 28/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2784 - binary_accuracy: 0.8876
# Epoch 28: val_binary_accuracy did not improve from 0.78530
# 185/185 [==============================] - 88s 472ms/step - loss: 0.2784 - binary_accuracy: 0.8876 - val_loss: 0.6214 - val_binary_accuracy: 0.7277 - lr: 8.0000e-04
# Epoch 29/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2783 - binary_accuracy: 0.8854
# Epoch 29: val_binary_accuracy did not improve from 0.78530
# 185/185 [==============================] - 90s 480ms/step - loss: 0.2783 - binary_accuracy: 0.8854 - val_loss: 0.5814 - val_binary_accuracy: 0.7550 - lr: 8.0000e-04
# Epoch 30/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2698 - binary_accuracy: 0.8912
# Epoch 30: val_binary_accuracy did not improve from 0.78530
# 185/185 [==============================] - 89s 473ms/step - loss: 0.2698 - binary_accuracy: 0.8912 - val_loss: 0.5858 - val_binary_accuracy: 0.7435 - lr: 8.0000e-04
# Epoch 31/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2579 - binary_accuracy: 0.8948
# Epoch 31: val_binary_accuracy improved from 0.78530 to 0.79683, saving model to cardio_attn_test_valid_weights.best.hdf5
# 185/185 [==============================] - 90s 481ms/step - loss: 0.2579 - binary_accuracy: 0.8948 - val_loss: 0.5104 - val_binary_accuracy: 0.7968 - lr: 8.0000e-04
# Epoch 32/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2675 - binary_accuracy: 0.8912
# Epoch 32: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 90s 483ms/step - loss: 0.2675 - binary_accuracy: 0.8912 - val_loss: 0.5281 - val_binary_accuracy: 0.7896 - lr: 8.0000e-04
# Epoch 33/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2660 - binary_accuracy: 0.8921
# Epoch 33: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 90s 477ms/step - loss: 0.2660 - binary_accuracy: 0.8921 - val_loss: 0.6121 - val_binary_accuracy: 0.7406 - lr: 8.0000e-04
# Epoch 34/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2567 - binary_accuracy: 0.9007
# Epoch 34: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 88s 472ms/step - loss: 0.2567 - binary_accuracy: 0.9007 - val_loss: 0.6456 - val_binary_accuracy: 0.7161 - lr: 8.0000e-04
# Epoch 35/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2592 - binary_accuracy: 0.8968
# Epoch 35: val_binary_accuracy did not improve from 0.79683
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 0.0006400000303983689.
# 185/185 [==============================] - 89s 472ms/step - loss: 0.2592 - binary_accuracy: 0.8968 - val_loss: 0.6520 - val_binary_accuracy: 0.7255 - lr: 8.0000e-04
# Epoch 36/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2323 - binary_accuracy: 0.9068
# Epoch 36: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 89s 479ms/step - loss: 0.2323 - binary_accuracy: 0.9068 - val_loss: 0.7149 - val_binary_accuracy: 0.7262 - lr: 6.4000e-04
# Epoch 37/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.2272 - binary_accuracy: 0.9117
# Epoch 37: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 88s 469ms/step - loss: 0.2268 - binary_accuracy: 0.9119 - val_loss: 0.6792 - val_binary_accuracy: 0.7291 - lr: 6.4000e-04
# Epoch 38/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2371 - binary_accuracy: 0.9119
# Epoch 38: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 87s 464ms/step - loss: 0.2371 - binary_accuracy: 0.9119 - val_loss: 0.6219 - val_binary_accuracy: 0.7500 - lr: 6.4000e-04
# Epoch 39/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2128 - binary_accuracy: 0.9185
# Epoch 39: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 86s 461ms/step - loss: 0.2128 - binary_accuracy: 0.9185 - val_loss: 0.6032 - val_binary_accuracy: 0.7810 - lr: 6.4000e-04
# Epoch 40/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2280 - binary_accuracy: 0.9090
# Epoch 40: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 88s 468ms/step - loss: 0.2280 - binary_accuracy: 0.9090 - val_loss: 0.6310 - val_binary_accuracy: 0.7507 - lr: 6.4000e-04
# Epoch 41/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2190 - binary_accuracy: 0.9126
# Epoch 41: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 86s 463ms/step - loss: 0.2190 - binary_accuracy: 0.9126 - val_loss: 0.7275 - val_binary_accuracy: 0.7255 - lr: 6.4000e-04
# Epoch 42/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2204 - binary_accuracy: 0.9108
# Epoch 42: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 86s 460ms/step - loss: 0.2204 - binary_accuracy: 0.9108 - val_loss: 0.6411 - val_binary_accuracy: 0.7507 - lr: 6.4000e-04
# Epoch 43/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2056 - binary_accuracy: 0.9182
# Epoch 43: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 88s 471ms/step - loss: 0.2056 - binary_accuracy: 0.9182 - val_loss: 0.7305 - val_binary_accuracy: 0.7457 - lr: 6.4000e-04
# Epoch 44/100
# 185/185 [==============================] - ETA: 0s - loss: 0.2116 - binary_accuracy: 0.9221
# Epoch 44: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 87s 466ms/step - loss: 0.2116 - binary_accuracy: 0.9221 - val_loss: 0.6510 - val_binary_accuracy: 0.7630 - lr: 6.4000e-04
# Epoch 45/100
# 184/185 [============================>.] - ETA: 0s - loss: 0.1976 - binary_accuracy: 0.9219
# Epoch 45: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 86s 461ms/step - loss: 0.1972 - binary_accuracy: 0.9218 - val_loss: 0.6301 - val_binary_accuracy: 0.7601 - lr: 6.4000e-04
# Epoch 46/100
# 185/185 [==============================] - ETA: 0s - loss: 0.1882 - binary_accuracy: 0.9268
# Epoch 46: val_binary_accuracy did not improve from 0.79683
# 185/185 [==============================] - 88s 471ms/step - loss: 0.1882 - binary_accuracy: 0.9268 - val_loss: 0.6573 - val_binary_accuracy: 0.7522 - lr: 6.4000e-04

# %%
np.save('history.npy',history.history)

# %%
combined_Model.load_weights(weight_path)

# %%
history1=np.load('/kaggle/working/history.npy',allow_pickle='TRUE').item()

# %%
pred_Y = combined_Model.predict(test_X, 
                          batch_size = 32, 
                          verbose = True)
# Out:
# 44/44 [==============================] - 1s 27ms/step

# %%
plt.matshow(confusion_matrix(test_Y, pred_Y>0.5))
print(classification_report(test_Y, pred_Y>0.5, target_names = ['Healthy', 'Cardiomegaly']))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.91      0.83      0.87      1110
# Cardiomegaly       0.49      0.65      0.56       278
#
#     accuracy                           0.80      1388
#    macro avg       0.70      0.74      0.71      1388
# weighted avg       0.82      0.80      0.81      1388

# %%
plt.plot(history1['binary_accuracy'])
plt.plot(history1['val_binary_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
plt.plot(history1['loss'])
plt.plot(history1['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %% [markdown]
# ## Test Results

# %%
final_pred_Y = combined_Model.predict(final_test_X, 
                                verbose = True, 
                                batch_size = 4)
# Out:
# 347/347 [==============================] - 2s 5ms/step

# %%
plt.matshow(confusion_matrix(final_test_Y, final_pred_Y>0.5))
print(classification_report(final_test_Y, final_pred_Y>0.5, target_names = ['Healthy', 'Cardiomegaly']))
# Out:
#               precision    recall  f1-score   support
#
#      Healthy       0.91      0.81      0.86      1110
# Cardiomegaly       0.47      0.67      0.55       278
#
#     accuracy                           0.78      1388
#    macro avg       0.69      0.74      0.70      1388
# weighted avg       0.82      0.78      0.79      1388

# %%
def getPerformanceMetrics(real_values,pred_values,format):
    CM = confusion_matrix(real_values,pred_values)
    TN = CM[0][0]
    FN = CM[1][0] 
    TP = CM[1][1]
    FP = CM[0][1]
    Population = TN+FN+TP+FP
    Accuracy   = round( (TP+TN) / Population,4)
    PPV        = round( TP / (TP+FP),4 )
    NPV        = round( TN / (TN+FN),4 )
    Sensitivity= round( TP / (TP+FN),4 )
    Specificity= round( TN / (TN+FP),4 )
    if format==1:
        performance_metrics = pd.DataFrame({'Metric': ['Accuracy','PPV','NPV','Sensitivity','Specificity'],
                                            'Value':[Accuracy,PPV,NPV,Sensitivity,Specificity]})
    else:
        performance_metrics = pd.DataFrame({'Accuracy':[Accuracy],'PPV':[PPV],'NPV':[NPV],'Sensitivity':[Sensitivity],'Specificity':[Specificity]})
        
    return performance_metrics

# %% [markdown]
# ## Validation Metrics

# %%
print(getPerformanceMetrics(test_Y, pred_Y>0.5,2))
# Out:
#    Accuracy     PPV     NPV  Sensitivity  Specificity
# 0    0.7968  0.4945  0.9051       0.6511       0.8333

# %% [markdown]
# ## Test Metrics

# %%
print(getPerformanceMetrics(final_test_Y,final_pred_Y>0.5,2))
# Out:
#    Accuracy     PPV     NPV  Sensitivity  Specificity
# 0     0.781  0.4672  0.9062       0.6655       0.8099
